# %%
import pandas as pd
import io
import numpy as np
from urllib.request import urlopen
import json
from math import *
from gastrodon import RemoteEndpoint,QName,ttl,URIRef,inline
from scipy import spatial
from matplotlib import pyplot

# %%
# helper function to replace None with ''
def none2str(string):
    if string is None:
        return ''
    else:
        return string

# %%
# helper to compute distances on the globe
def spherical_dist(pos1, pos2, r=6371000):
    pos1 = pos1 * np.pi / 180
    pos2 = pos2 * np.pi / 180
    cos_lat1 = np.cos(pos1[..., 0])
    cos_lat2 = np.cos(pos2[..., 0])
    cos_lat_d = np.cos(pos1[..., 0] - pos2[..., 0])
    cos_lon_d = np.cos(pos1[..., 1] - pos2[..., 1])
    return r * np.arccos(cos_lat_d - cos_lat1 * cos_lat2 * (1 - cos_lon_d))

# %%
#@prefix wikibase: <wikibase: <http://wikiba.se/ontology#> .
prefixes=inline("""
   @prefix wd: <http://www.wikidata.org/entity/> .
   @prefix wdt: <http://www.wikidata.org/prop/direct/> .
   @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
   @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
""").graph
endpoint=RemoteEndpoint(
   "http://query.wikidata.org/sparql"
   ,prefixes=prefixes
)

# %% [markdown]
# ## Load data

# %%
data_url = 'https://data.stadt-zuerich.ch/dataset/brunnen/resource/d741cf9c-63be-495f-8c3e-9418168fcdbf/download/brunnen.json'

# %%
data_js = json.loads(urlopen(data_url).read())

# %% [markdown]
# ## Modify columns

# %%
# convert to dataframe
df = pd.io.json.json_normalize(data_js['features'])
# extract coords
df['X'] = df['geometry.coordinates'].apply(lambda crds:crds[0])
df['Y'] = df['geometry.coordinates'].apply(lambda crds:crds[1])
# remove not needed columns
df = df.drop(columns=['geometry.coordinates', 'geometry.type', 'properties.objectid', 'type'])
# rename columns
df = df.rename(index=str, columns=
               {"properties.bezeichnung": "label_de", 
                "properties.brunnenart_txt": "fountain_type", 
                "properties.wasserart_txt": "water_type", 
                "properties.nummer":"operator_id",
                "properties.historisches_baujahr": "date"
               })
# remove "None" from appelation column
df['label_de'] = df['label_de'].apply(lambda a:none2str(a))
df.head()
# Out:
#            label_de         fountain_type    date operator_id   water_type  \
# 0     Aussichtsturm  öffentlicher Brunnen  1970.0         510  Verteilnetz
# 1                    öffentlicher Brunnen  1933.0         349  Verteilnetz
# 2  Biberlinterrasse  öffentlicher Brunnen  1965.0         365  Quellwasser
# 3                    öffentlicher Brunnen  1910.0         338  Quellwasser
# 4                        Notwasserbrunnen  1988.0        6069  Quellwasser
#
#           X          Y
# 0  8.599255  47.369752
# 1  8.590811  47.369293
# 2  8.575754  47.366130
# 3  8.564845  47.370993
# 4  8.564390  47.369327

# %% [markdown]
# ## Identify duplicates

# %%
# Get bounding box of data
buffer = 0.0003  #(about 20-30 meters)
bounds = {
    'minX': df['X'].min() - buffer,
    'minY': df['Y'].min() - buffer,
    'maxX': df['X'].max() + buffer,
    'maxY': df['Y'].max() + buffer
}

# %%
# query fountains within bounding box
query_string = """ SELECT ?place ?placeLabel ?location
WHERE
{{
  # Enter coordinates
  SERVICE wikibase:box {{
    # ?place wdt:P625 ?location .
    bd:serviceParam wikibase:cornerWest "Point({minX} {minY})"^^geo:wktLiteral.
    bd:serviceParam wikibase:cornerEast "Point({maxX} {maxY})"^^geo:wktLiteral.
  }} .
  # Is a water well or fountain or subclass of fountain
  FILTER (EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q43483 }} || EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q483453 }}).
  SERVICE wikibase:label {{
    bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .
  }} 
}}
  """.format(**bounds)

# Perform query
query_result = endpoint.select(query)

# %%
# Extract lat and lon
query_result['X'] = query_result['location'].apply(lambda l:float(l.split('(')[1].split(' ')[0]))
query_result['Y'] = query_result['location'].apply(lambda l:float(l.split(' ')[1].split(')')[0]))

# %%
# compute distance matrix
# distances = spatial.distance_matrix(df.as_matrix(['X','Y']), query_result.as_matrix(['X','Y']))
distances = spherical_dist(df[['X','Y']].values[:, None], query_result[['X','Y']].values)
# find nearest existing fountain for each fountain to import
#indexes of nearest
nearest_idx = np.argmin(distances, axis=1).tolist()
df['nearest_qid'] = query_result.iloc[nearest_idx]['place'].apply(lambda id:id[3:]).tolist()
df['nearest_distance'] = np.min(distances, axis=1).tolist()
#indexes of second nearest
# first increase the distance of the nearest
i_line=0
for i_col in nearest_idx:
    distances[i_line, i_col] = 100000
    i_line += 1
df['2nd_nearest_distance'] = np.min(distances, axis=1).tolist()

df.head()
# Out:
#            label_de         fountain_type    date operator_id   water_type  \
# 0     Aussichtsturm  öffentlicher Brunnen  1970.0         510  Verteilnetz
# 1                    öffentlicher Brunnen  1933.0         349  Verteilnetz
# 2  Biberlinterrasse  öffentlicher Brunnen  1965.0         365  Quellwasser
# 3                    öffentlicher Brunnen  1910.0         338  Quellwasser
# 4                        Notwasserbrunnen  1988.0        6069  Quellwasser
#
#           X          Y nearest_qid  nearest_distance  2nd_nearest_distance
# 0  8.599255  47.369752   Q27229822       1572.747666           1713.116545
# 1  8.590811  47.369293   Q27229822       1175.673373           1485.271348
# 2  8.575754  47.366130   Q27230070        456.499616            634.066324
# 3  8.564845  47.370993   Q27230192          1.980033            226.992084
# 4  8.564390  47.369327   Q27230192        188.767471            284.923890

# %%
# use the identified qid only if criteria are met: 
# - no further than 10 m away
# - next closest fountain at neares least 50% further away
def validate_proposal(qid, d1, d2, dmax=10, ratio_min=0.5):
    
    if d1 == 0 or (d1<=dmax and d2/d1-1 >= ratio_min):
        return qid
    else:
        return ''

# %%
for index, row in df.iterrows():
    df.loc[index, 'qid'] = validate_proposal(
        row['nearest_qid'], 
        row['nearest_distance'], 
        row['2nd_nearest_distance'],
        dmax=15
    )
dffinal = df.drop(columns=['nearest_qid', 'nearest_distance', '2nd_nearest_distance'])

# %%
dffinal
# Out:
#                      label_de                        fountain_type    date  \
# 0               Aussichtsturm                 öffentlicher Brunnen  1970.0
# 1                                             öffentlicher Brunnen  1933.0
# 2            Biberlinterrasse                 öffentlicher Brunnen  1965.0
# 3                                             öffentlicher Brunnen  1910.0
# 4                                                 Notwasserbrunnen  1988.0
# 5                                             öffentlicher Brunnen  1903.0
# 6                                             öffentlicher Brunnen  1907.0
# 7                                             öffentlicher Brunnen  1906.0
# 8                                             öffentlicher Brunnen  1903.0
# 9                                             öffentlicher Brunnen  1892.0
# 10                                                Notwasserbrunnen  1978.0
# 11                                            öffentlicher Brunnen  1948.0
# 12                                                privater Brunnen  1905.0
# 13                                            öffentlicher Brunnen  1928.0
# 14                                            öffentlicher Brunnen  1880.0
# 15                                                Notwasserbrunnen  1986.0
# 16                  Klusplatz                 öffentlicher Brunnen  1951.0
# 17                                            öffentlicher Brunnen  1905.0
# 18                                            öffentlicher Brunnen  1892.0
# 19          bei der Turnhalle                     privater Brunnen  1905.0
# 24           746        Verteilnetz  8.552027  47.365913
# 25           339        Verteilnetz  8.569773  47.364485
# 26          1054        Verteilnetz  8.570770  47.369013  Q27229879
# 27           712        Quellwasser  8.580996  47.366000
# 28            61        Quellwasser  8.545250  47.365585  Q27230145
# 29            59        Quellwasser  8.545497  47.366748  Q27229960
# ...          ...                ...       ...        ...        ...
# 1251        1280        Verteilnetz  8.537252  47.420033
# 1252         184        Verteilnetz  8.522144  47.362642
# 1253        1273        Quellwasser  8.532709  47.400276
# 1254        1272        Verteilnetz  8.480366  47.387291
# 1255        1279        Verteilnetz  8.490691  47.392266
# 1256        1278        Verteilnetz  8.490338  47.392453
# 1257        1209        Verteilnetz  8.550577  47.410858
# 1258        1281        Verteilnetz  8.524053  47.355549
# 1259       683.2        Verteilnetz  8.575043  47.401437
# 1260        1284        Verteilnetz  8.545873  47.366305
# 1261        1282        Verteilnetz  8.589088  47.403173
# 1262        1285        Quellwasser  8.545806  47.365621
# 1263        1286        Verteilnetz  8.536592  47.392483
# 1264        1287        Verteilnetz  8.602833  47.359403
# 1265         733  eigene Versorgung  8.509876  47.337004
# 1266         389        Quellwasser  8.571930  47.358221
# 1267        1288        Quellwasser  8.497353  47.366228
# 1268        1290        Quellwasser  8.512693  47.388196
# 1269        1289        Verteilnetz  8.512327  47.387257
# 1270        1293        Verteilnetz  8.559821  47.413866
# 1271       759.2        Quellwasser  8.538765  47.373206
# 1272        1292        Quellwasser  8.540596  47.370083
# 1273        1291        Quellwasser  8.540647  47.370076
# 1274        1294        Verteilnetz  8.479166  47.406639
# 1275        6089        Quellwasser  8.490960  47.404185
# 1276        1296        Verteilnetz  8.539208  47.369731
# 1277        1295        Verteilnetz  8.543556  47.412309
# 1278        1297        Verteilnetz  8.519513  47.337353
# 1279        1109        Verteilnetz  8.537986  47.365809
# 1280        1298        Verteilnetz  8.510081  47.379575
#
# [1281 rows x 8 columns]

# %% [markdown]
# ## Format for wikidata import

# %%
def process_coordinates(x, y):
    return '@{1:1.8f}/{0:1.8f}'.format(x,y)

def process_year(date):
    if np.isnan(date):
        return ''
    else:
        return '+{0:4d}-00-00T00:00:00Z/9.'.format(int(date))

fountain_type_map = {
    'öffentlicher Brunnen': 'Q53628296',
    'Notwasserbrunnen': 'Q53628522',
    'privater Brunnen': 'Q53629707',
    'Brunnen in städtischer Liegenschaft': 'Q53628618',
    'Brunnen des Verschönerungsvereins': 'Q53628761',
    'Brunnen mit eigener Versorgung': 'Q53630002'
}

def process_fountain_type(type):
    return fountain_type_map[type]

def createline(item, prop, value):
    return '{}\t{}\t{}\n'.format(item, prop, value)

# %%
lines = []

for index, row in dffinal.iterrows():
    if row['qid'] == '':
        # create a new fountain
        lines.append('CREATE\n')
        item = 'LAST'
    else:
        # update existing fountain
        item = row['qid']
        
    # label in german
    lines.append(createline(item, 'Lde', row['label_de']))
    
    # instance of drinking fountain
    lines.append(createline(item, 'P31', 'Q1630622'))
    
    # instance of specific water fountain type
    lines.append(createline(item, 'P31', process_fountain_type(row['fountain_type'])))
    
    # coordinates
    lines.append(createline(item, 'P625', process_coordinates(row['X'], row['Y'])))
    
    # creation date
    lines.append(createline(item, 'P571', process_year(row['date'])))

# %% [markdown]
# # Write commands to file

# %%
with io.open("quickstatement_commands.txt", "w", encoding='utf8') as f:
    f.writelines(lines)
