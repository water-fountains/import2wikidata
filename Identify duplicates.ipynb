# %% [markdown]
# Read dataset, find preexisting fountains in WikiData, and write the QIDs to the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
import re
from scipy import spatial
# %matplotlib inline
import sys
# import gastrodon
from gastrodon import RemoteEndpoint,QName,ttl,URIRef,inline
pd.options.display.width=120
pd.options.display.max_colwidth=100

#@prefix wikibase: <wikibase: <http://wikiba.se/ontology#> .
prefixes=inline("""
   @prefix wd: <http://www.wikidata.org/entity/> .
   @prefix wdt: <http://www.wikidata.org/prop/direct/> .
   @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
   @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
""").graph

# %%
endpoint=RemoteEndpoint(
   "http://query.wikidata.org/sparql"
   ,prefixes=prefixes
)

# %%
query = """ SELECT ?place ?placeLabel ?location
WHERE
{
  # Enter coordinates
  SERVICE wikibase:around {
    # ?place wdt:P625 ?location .
    bd:serviceParam wikibase:center "Point(%s %s)"^^geo:wktLiteral.
    bd:serviceParam wikibase:radius "%s" .
  } .
  # Is a water well or fountain or subclass of fountain
  FILTER (EXISTS { ?place wdt:P31/wdt:P279* wd:Q43483 } || EXISTS { ?place wdt:P31/wdt:P279* wd:Q483453 }).
  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .
  } 
}
  """

# %% [markdown]
# # Load data

# %%
data_raw=pd.read_csv("20170918_brunnen_zuerich.csv")

# %%
data_raw.head()
# Out:
#           X          Y         X_dms          Y-dms  primaryind  nummer            brunnenart  historisch  \
# 0  8.599255  47.369752  E8°35'57.31"  N47°22'11.10"           1   510.0  öffentlicher Brunnen      1970.0
# 1  8.590811  47.369293  E8°35'26.92"  N47°22'9.453"           2   349.0  öffentlicher Brunnen      1933.0
# 2  8.575754  47.366130  E8°34'32.71"  N47°21'58.06"           3   365.0  öffentlicher Brunnen      1965.0
# 3  8.564845  47.370993  E8°33'53.44"  N47°22'15.57"           4   338.0  öffentlicher Brunnen      1910.0
# 4  8.564390  47.369327  E8°33'51.80"  N47°22'9.576"           5  6069.0      Notwasserbrunnen      1988.0
#
#     wasserart_        bezeichnun
# 0  Verteilnetz     Aussichtsturm
# 1  Verteilnetz               NaN
# 2  Quellwasser  Biberlinterrasse
# 3  Quellwasser               NaN
# 4  Quellwasser               NaN

# %%
data_raw['qid'] = ''

# %%
for index, fountain in data_raw.iterrows():
    # search within 5 meters
    while True:
        try:
            query_result = endpoint.select(query % (fountain.X, fountain.Y, 0.005))
        except:
            print ('caught a timeout. fountain number: ', fountain.nummer)
            continue
        
        if query_result.shape[0] == 1:
            print('fountain found')
            data_raw.loc[index, 'qid'] = query_result.loc[0,'place'].split(':')[1]
        elif query_result.shape[0]>1:
            data_raw.loc[index, 'qid'] = 'conflicting'

        break
# Out:
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  745.0
# fountain found
# fountain found
# caught a timeout. fountain number:  22.0
# caught a timeout. fountain number:  12.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1004.0
# fountain found
# caught a timeout. fountain number:  208.0
# caught a timeout. fountain number:  6030.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  54.0
# caught a timeout. fountain number:  54.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  132.0
# fountain found
# caught a timeout. fountain number:  100.0
# fountain found
# caught a timeout. fountain number:  457.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1041.0
# caught a timeout. fountain number:  440.0
# caught a timeout. fountain number:  440.0
# fountain found
# fountain found
# caught a timeout. fountain number:  578.0
# fountain found
# fountain found
# caught a timeout. fountain number:  1150.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1081.0
# fountain found
# caught a timeout. fountain number:  66.0
# fountain found
# fountain found
# caught a timeout. fountain number:  220.0
# fountain found
# fountain found
# caught a timeout. fountain number:  432.0
# fountain found
# fountain found
# caught a timeout. fountain number:  508.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  703.2
# caught a timeout. fountain number:  703.3
# fountain found
# caught a timeout. fountain number:  502.0
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  512.0
# fountain found
# caught a timeout. fountain number:  6049.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  701.0
# caught a timeout. fountain number:  701.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  657.0
# caught a timeout. fountain number:  657.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  589.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1072.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  67.0
# fountain found
# caught a timeout. fountain number:  32.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1177.0
# caught a timeout. fountain number:  1177.0
# caught a timeout. fountain number:  6042.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  176.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  953.0
# caught a timeout. fountain number:  1112.3
# caught a timeout. fountain number:  1112.1
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  459.0
# caught a timeout. fountain number:  639.1
# caught a timeout. fountain number:  778.0
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  1155.0
# fountain found
# caught a timeout. fountain number:  318.0
# caught a timeout. fountain number:  318.0
# caught a timeout. fountain number:  175.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  6086.0
# caught a timeout. fountain number:  435.0
# caught a timeout. fountain number:  261.0
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  391.0
# fountain found
# fountain found
# caught a timeout. fountain number:  363.0
# caught a timeout. fountain number:  363.0
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  6029.0
# caught a timeout. fountain number:  6052.0
# caught a timeout. fountain number:  6057.0
# fountain found
# caught a timeout. fountain number:  665.0
# fountain found
# fountain found
# caught a timeout. fountain number:  1016.0
# caught a timeout. fountain number:  1028.0
# caught a timeout. fountain number:  1029.0
# fountain found
# fountain found
# caught a timeout. fountain number:  1062.0
# caught a timeout. fountain number:  1074.0
# caught a timeout. fountain number:  1074.0
# caught a timeout. fountain number:  1166.0
# caught a timeout. fountain number:  1183.5
# caught a timeout. fountain number:  1183.7
# caught a timeout. fountain number:  1183.7
# fountain found
# caught a timeout. fountain number:  1193.0
# caught a timeout. fountain number:  1198.0
# caught a timeout. fountain number:  1198.0
# caught a timeout. fountain number:  1218.0
# caught a timeout. fountain number:  1227.0
# fountain found
# caught a timeout. fountain number:  364.0
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  53.0
# caught a timeout. fountain number:  533.0
# fountain found
# caught a timeout. fountain number:  620.0
# caught a timeout. fountain number:  633.2
# fountain found
# caught a timeout. fountain number:  732.0
# caught a timeout. fountain number:  732.0
# caught a timeout. fountain number:  744.0
# caught a timeout. fountain number:  812.0
# caught a timeout. fountain number:  827.0
# caught a timeout. fountain number:  839.0
# caught a timeout. fountain number:  869.2
# caught a timeout. fountain number:  902.0
# caught a timeout. fountain number:  913.0
# caught a timeout. fountain number:  930.0
# caught a timeout. fountain number:  943.1
# caught a timeout. fountain number:  959.3
# caught a timeout. fountain number:  959.1
# caught a timeout. fountain number:  983.2
# caught a timeout. fountain number:  991.0
# caught a timeout. fountain number:  991.0
# caught a timeout. fountain number:  544.2
# caught a timeout. fountain number:  563.2
# caught a timeout. fountain number:  675.1
# fountain found
# caught a timeout. fountain number:  1249.1
# caught a timeout. fountain number:  252.1
# fountain found
# fountain found
# caught a timeout. fountain number:  1075.0
# caught a timeout. fountain number:  759.1
# caught a timeout. fountain number:  6084.0
# fountain found
# caught a timeout. fountain number:  1200.0
# fountain found
# fountain found
# caught a timeout. fountain number:  1245.0
# fountain found
# caught a timeout. fountain number:  1247.0
# caught a timeout. fountain number:  585.5
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# fountain found
# caught a timeout. fountain number:  922.0
# caught a timeout. fountain number:  880.3
# caught a timeout. fountain number:  677.0
# fountain found
# caught a timeout. fountain number:  671.1
# fountain found
# fountain found
# caught a timeout. fountain number:  1259.0
# caught a timeout. fountain number:  1259.0
# fountain found
# fountain found
# caught a timeout. fountain number:  1268.0
# caught a timeout. fountain number:  1283.0
# caught a timeout. fountain number:  982.2
# caught a timeout. fountain number:  1285.0
# caught a timeout. fountain number:  6089.0
# caught a timeout. fountain number:  6089.0
# fountain found

# %%
len(data_raw['qid'].unique())
# Out:
# 185

# %%
data_raw.to_csv('data_out.csv')
