# %% [markdown]
# # Automatic import of Rome drinking fountains data to Wikidata
# The following script downloads fountain data from osm as per https://github.com/water-fountains/proximap/issues/133, compares it to existing fountains in Wikidata for the same region, and creates Wikidata Quickstatement commands to complete the entries in Wikidata. New entities are created if no matching fountains are found.

# %% [markdown]
# ## Initialize environment

# %%
from datetime import datetime as dt
dtFmt = "%y%m%d_%H%M%S"
print (dt.now().strftime(dtFmt))
import pandas as pd
import io
import numpy as np
from urllib.request import urlopen
import json
from math import *
from platform import python_version
print("Python v "+python_version())
#https://github.com/paulhoule/gastrodon/issues/7 
from gastrodon import RemoteEndpoint,QName,ttl,URIRef,inline
from matplotlib import pyplot
# Out:
# 191202_060659
# Python v 3.6.5

# %%
#@prefix wikibase: <wikibase: <http://wikiba.se/ontology#> .
prefixes=inline("""
   @prefix wd: <http://www.wikidata.org/entity/> .
   @prefix wdt: <http://www.wikidata.org/prop/direct/> .
   @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
   @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
""").graph
endpoint=RemoteEndpoint(
   #"https://query.wikidata.org/sparql"
    "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
   ,prefixes=prefixes
)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("osmFountainsRome191201_082705.csv")

# %%
df.head()
# Out:
#    type         id        lat        lon         amenity fountain created_by  \
# 0  node  246569213  41.824508  12.485546  drinking_water   nasone        NaN
# 1  node  246569214  41.852621  12.478328  drinking_water   nasone        NaN
# 2  node  246569215  41.854102  12.476834  drinking_water   nasone        NaN
# 3  node  246569216  41.863749  12.478948  drinking_water   nasone        NaN
# 4  node  246571139  41.904287  12.513278  drinking_water      NaN       JOSM
#
#   wheelchair flow architect  ... operator designation level location covered  \
# 0        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 1        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 2        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 3        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 4        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
#
#   description:de website artwork_type subject:wikidata drinking_water:legal
# 0            NaN     NaN          NaN              NaN                  NaN
# 1            NaN     NaN          NaN              NaN                  NaN
# 2            NaN     NaN          NaN              NaN                  NaN
# 3            NaN     NaN          NaN              NaN                  NaN
# 4            NaN     NaN          NaN              NaN                  NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# ### Rename columns to make them easier to work with

# %%
# remove not needed columns
df = df.drop(columns=['type','id'])

# %%
# rename columns
df = df.rename(index=str, columns=
               {"lat": "Y"})

# %%
# rename columns
df = df.rename(index=str, columns=
               {"lon": "X"})

# %%
df.head()
# Out:
#            Y          X         amenity fountain created_by wheelchair flow  \
# 0  41.824508  12.485546  drinking_water   nasone        NaN        NaN  NaN
# 1  41.852621  12.478328  drinking_water   nasone        NaN        NaN  NaN
# 2  41.854102  12.476834  drinking_water   nasone        NaN        NaN  NaN
# 3  41.863749  12.478948  drinking_water   nasone        NaN        NaN  NaN
# 4  41.904287  12.513278  drinking_water      NaN       JOSM        NaN  NaN
#
#   architect description drinking_water  ... drinking_water:legal nearest_qid  \
# 0       NaN         NaN            NaN  ...                  NaN   Q76937644
# 1       NaN         NaN            NaN  ...                  NaN   Q76937896
# 2       NaN         NaN            NaN  ...                  NaN   Q76937912
# 3       NaN         NaN            NaN  ...                  NaN   Q76937931
# 4       NaN         NaN            NaN  ...                  NaN   Q76937949
#
#   nearest_distance 2nd_nearest_distance nearest_has_label_de nearest_has_date  \
# 0              0.0           424.336166                 True            False
# 1              0.0           129.883666                 True            False
# 2              0.0           102.431975                 True            False
# 3              0.0           254.841443                 True            False
# 4              0.0           116.905101                 True            False
#
#   nearest_has_operator nearest_has_code  nearest_has_water_type match_found
# 0                False            False                   False       match
# 1                False            False                   False       match
# 2                False            False                   False       match
# 3                False            False                   False       match
# 4                False            False                   False       match
#
# [5 rows x 83 columns]

# %%
len(df)
# Out:
# 1645

# %% [markdown]
# ## Identify already existing fountains
# ### Query fountains from Wikidata

# %%
# Find the geographic extent of the data

buffer = 0.0003  # in degrees, corresponds to about 20-30 meters)
bounds = {
    'minX': df['X'].min() - buffer,
    'minY': df['Y'].min() - buffer,
    'maxX': df['X'].max() + buffer,
    'maxY': df['Y'].max() + buffer
}
print("bounds: ")
for key,value in bounds.items():
    print(key+ ": "+str(value))
# Out:
# bounds:
# minX: 12.3238906
# minY: 41.802459999999996
# maxX: 12.6220409
# maxY: 41.99526720000001

# %%
# Query fountains (both water wells and fountains) from Wikidata within bounding box found above
# placeLabel 

query_string = """SELECT ?place ?placeLabel ?location ?date ?catalog_code ?catalogLabel ?operator ?water_supply_type
WHERE
{{
  # Enter coordinates
  SERVICE wikibase:box {{
    # ?place wdt:P625 ?location .
    bd:serviceParam wikibase:cornerWest "Point({minX} {minY})"^^geo:wktLiteral.
    bd:serviceParam wikibase:cornerEast "Point({maxX} {maxY})"^^geo:wktLiteral.
  }} .
  # Is a water well or fountain or subclass of fountain
  FILTER (EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q43483 }} || EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q483453 }}).
  SERVICE wikibase:label {{
    bd:serviceParam wikibase:language "[AUTO_LANGUAGE],de" .
  }} 
  OPTIONAL {{ ?place p:P528 ?catalog_code.
            # ?catalog_code pq:P972 ?catalog.}}
  OPTIONAL {{ ?place wdt:P571 ?date.}}
  OPTIONAL {{ ?place wdt:P5623 ?water_supply_type}}
  OPTIONAL {{ ?place wdt:P137 ?operator.}}
  OPTIONAL {{ ?place rdfs:placeLabel ?placeLabel}}
}}
  """.format(**bounds)

print(query_string)
# Out:
# SELECT ?place ?placeLabel ?location ?date ?catalog_code ?catalogLabel ?operator ?water_supply_type
# WHERE
# {
#   # Enter coordinates
#   SERVICE wikibase:box {
#     ?place wdt:P625 ?location .
#     bd:serviceParam wikibase:cornerWest "Point(12.3238906 41.802459999999996)"^^geo:wktLiteral.
#     bd:serviceParam wikibase:cornerEast "Point(12.6220409 41.99526720000001)"^^geo:wktLiteral.
#   } .
#   # Is a water well or fountain or subclass of fountain
#   FILTER (EXISTS { ?place wdt:P31/wdt:P279* wd:Q43483 } || EXISTS { ?place wdt:P31/wdt:P279* wd:Q483453 }).
#   SERVICE wikibase:label {
#     bd:serviceParam wikibase:language "[AUTO_LANGUAGE],de" .
#   }
#   OPTIONAL { ?place p:P528 ?catalog_code.
#             ?catalog_code pq:P972 ?catalog.}
#   OPTIONAL { ?place wdt:P571 ?date.}
#   OPTIONAL { ?place wdt:P5623 ?water_supply_type}
#   OPTIONAL { ?place wdt:P137 ?operator.}
#   OPTIONAL { ?place rdfs:placeLabel ?placeLabel}
# }

# %%
# Perform query
query_result = endpoint.select(query_string)

# %%
#print(query_string)
print("\n\nTotal number of rows incl. duplicates "+str(len(query_result))+" size "+str(query_result.size))
# Out:
# Total number of rows incl. duplicates 1682 size 13456

# %% [markdown]
# ### Tidy up data

# %%
# Extract coordinates from Wikidata results

query_result['X'] = query_result['location'].apply(lambda l:float(l.split('(')[1].split(' ')[0]))
query_result['Y'] = query_result['location'].apply(lambda l:float(l.split(' ')[1].split(')')[0]))

# %%
query_result.head(100)
# Out:
#            place placeLabel                      location  date catalog_code  \
# 0   wd:Q74574057    Brunnen   Point(12.519195 41.8814447)  None         None
# 1   wd:Q76937644    Brunnen   Point(12.485546 41.8245081)  None         None
# 2   wd:Q76937896    Brunnen  Point(12.4783285 41.8526205)  None         None
# 3   wd:Q76937912    Brunnen  Point(12.4768335 41.8541022)  None         None
# 4   wd:Q76937931    Brunnen  Point(12.4789476 41.8637486)  None         None
# ..           ...        ...                           ...   ...          ...
# 95  wd:Q76939564    Brunnen  Point(12.4849325 41.9013552)  None         None
# 96  wd:Q76939583    Brunnen   Point(12.485754 41.9016622)  None         None
# 97  wd:Q76939597    Brunnen   Point(12.487827 41.9114186)  None         None
# 98  wd:Q76939614    Brunnen  Point(12.5126101 41.8923832)  None         None
# 99  wd:Q76939633    Brunnen  Point(12.5094467 41.8932112)  None         None
#
#    catalogLabel operator water_supply_type          X          Y
# 0          None     None              None  12.519195  41.881445
# 1          None     None              None  12.485546  41.824508
# 2          None     None              None  12.478328  41.852621
# 3          None     None              None  12.476833  41.854102
# 4          None     None              None  12.478948  41.863749
# ..          ...      ...               ...        ...        ...
# 95         None     None              None  12.484932  41.901355
# 96         None     None              None  12.485754  41.901662
# 97         None     None              None  12.487827  41.911419
# 98         None     None              None  12.512610  41.892383
# 99         None     None              None  12.509447  41.893211
#
# [100 rows x 10 columns]

# %%
# show duplicates
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html#pandas.DataFrame.duplicated

ids = query_result['placeLabel']
#ids = query_result['label']
duplicates = query_result[ids.isin(ids[ids.duplicated(keep=False)])]
dupli = duplicates.drop(columns=['catalog_code', 'catalogLabel', 'water_supply_type', 'date', 'catalogLabel', 'location', 'operator'])
dupli.sort_values(by=['placeLabel'],inplace=True)
print ("Duplicates: "+str(len(dupli))+"\n\n")
print(dupli.to_string())
# Out:
# Duplicates: 1602
#
#
#              place                               placeLabel          X          Y
# 0     wd:Q74574057                                  Brunnen  12.519195  41.881445
# 1079  wd:Q76975647                                  Brunnen  12.456227  41.900388
# 1078  wd:Q76968477                                  Brunnen  12.600466  41.805598
                lineDup = "MERGE\t"+prevQ[3:]+"\t"+row['place'][3:]+"\n"
                linesDup.append(lineDup)
            else:
                prevX=row['X']
                prevY=row['Y']
                prevQ=row['place']
        else:
            prevX=row['X']
            prevY=row['Y']
            prevQ=row['place']
            
    print("Merge commands"+extraText+" total: "+str(len(linesDup))+"\n\n")
    print(linesDup)
    
createMerge(dupli, "")
# Out:
# Merge commands total: 0
#
#
# []

# %%
#write MERGE command to File
quickStatDupliFileName = "quickstatement_commands_Hamburg_drink_DUPLI_"+dt.now().strftime(dtFmt)+".txt"
with io.open(quickStatDupliFileName, "w", encoding='utf8') as f:
    f.writelines(linesDup)
print("wrote '"+quickStatDupliFileName+"' with "+str(len(linesDup))+" lines")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-cf9cdb649497> in <module>
#       2 quickStatDupliFileName = "quickstatement_commands_Hamburg_drink_DUPLI_"+dt.now().strftime(dtFmt)+".txt"
#       3 with io.open(quickStatDupliFileName, "w", encoding='utf8') as f:
# ----> 4     f.writelines(linesDup)
#       5 print("wrote '"+quickStatDupliFileName+"' with "+str(len(linesDup))+" lines")
#
# NameError: name 'linesDup' is not defined

# %%
# show duplicates STRICT
#idsS = query_result['placeLabel','X','Y'] #this does not work yet
#duplicatesS = query_result[ids.isin(ids[ids.duplicated(keep=False)])]
#dupliS = duplicatesS.drop(columns=['catalog_code', 'catalogLabel', 'water_supply_type', 'date', 'catalogLabel', 'location', 'operator'])
#dupliS.sort_values(by=['placeLabel'],inplace=True)
#print(dupliS.to_string())
#createMerge(dupliS, " - strict")

# %%
# remove duplicate entries

# duplicate entries are caused when e.g. a fountain has catalog codes from two catalogs
query_result = query_result.drop_duplicates('place')
print("\n\nTotal number of rows without duplicates "+str(len(query_result)))
# Out:
# Total number of rows without duplicates 130

# %%
query_result.head(100)
# Out:
#            place            placeLabel                       location  date  \
# 0    wd:Q1454814        Minervabrunnen  Point(9.95166667 53.54583333)  None
# 1     wd:Q814528           Behnbrunnen  Point(9.94194444 53.54805556)  None
# 2    wd:Q2358953      Stuhlmannbrunnen  Point(9.93527778 53.54972222)  None
# 3    wd:Q2651496         Alsterfontäne  Point(9.99495278 53.55461667)  None
# 4   wd:Q18632417  Vierländerin-Brunnen        Point(9.99014 53.54766)  None
# ..           ...                   ...                            ...   ...
# 95  wd:Q76308142             Q76308142   Point(10.2961728 53.4268728)  None
# 96  wd:Q76308157             Q76308157     Point(9.9418923 53.548183)  None
# 97  wd:Q76308173             Q76308173    Point(10.0831994 53.626006)  None
# 98  wd:Q76308188             Q76308188    Point(9.9919829 53.5509746)  None
# 99  wd:Q76308203             Q76308203    Point(9.9788922 53.5623873)  None
#
#    catalog_code catalogLabel operator water_supply_type          X          Y
# 0          None         None     None              None   9.951667  53.545833
# 1          None         None     None              None   9.941944  53.548056
# 2          None         None     None              None   9.935278  53.549722
# 3          None         None     None              None   9.994953  53.554617
# 4          None         None     None              None   9.990140  53.547660
# ..          ...          ...      ...               ...        ...        ...
# 95         None         None     None              None  10.296173  53.426873
# 96         None         None     None              None   9.941892  53.548183
# 97         None         None     None              None  10.083199  53.626006
# 98         None         None     None              None   9.991983  53.550975
# 99         None         None     None              None   9.978892  53.562387
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Compute distances between fountains

# %%
# helper function to compute distances on the globe, returns distances in meters
def spherical_dist(pos1, pos2, r=6371000):
    pos1 = pos1 * np.pi / 180
    pos2 = pos2 * np.pi / 180
    cos_lat1 = np.cos(pos1[..., 0])
    cos_lat2 = np.cos(pos2[..., 0])
    cos_lat_d = np.cos(pos1[..., 0] - pos2[..., 0])
    cos_lon_d = np.cos(pos1[..., 1] - pos2[..., 1])
    return r * np.arccos(cos_lat_d - cos_lat1 * cos_lat2 * (1 - cos_lon_d))


# compute distances from each ODZ fountain to each Wikidata fountain
distances = spherical_dist(df[['X','Y']].values[:, None], query_result[['X','Y']].values)

# %% [markdown]
# ### Identify nearest and second nearest matches for each osm fountain

# %%
# indexes of nearest fountains
nearest_idx = np.argmin(distances, axis=1).tolist()

# QID of nearest fountains
df['nearest_qid'] = query_result.iloc[nearest_idx]['place'].apply(lambda id:id[3:]).tolist()

# distance to nearest fountain
df['nearest_distance'] = np.min(distances, axis=1).tolist()


# then remove nearest
i_line=0
for i_col in nearest_idx:
    distances[i_line, i_col] = 100000
    i_line += 1
# find distance to second nearest
df['2nd_nearest_distance'] = np.min(distances, axis=1).tolist()

df.head(100)
# Out:
#             Y          X         amenity fountain created_by wheelchair  \
# 0   41.824508  12.485546  drinking_water   nasone        NaN        NaN
# 1   41.852621  12.478328  drinking_water   nasone        NaN        NaN
# 2   41.854102  12.476834  drinking_water   nasone        NaN        NaN
# 3   41.863749  12.478948  drinking_water   nasone        NaN        NaN
# 4   41.904287  12.513278  drinking_water      NaN       JOSM        NaN
# ..        ...        ...             ...      ...        ...        ...
# 95  41.901662  12.485754  drinking_water      NaN        NaN        NaN
# 96  41.911419  12.487827  drinking_water      NaN       JOSM        NaN
# 97  41.892383  12.512610  drinking_water   nasone        NaN        NaN
# 98  41.893211  12.509447  drinking_water   nasone        NaN        NaN
# 99  41.892285  12.508577  drinking_water   nasone        NaN        NaN
#
#            flow architect description drinking_water  ...  \
# 0           NaN       NaN         NaN            NaN  ...
# 1           NaN       NaN         NaN            NaN  ...
# 2           NaN       NaN         NaN            NaN  ...
# 3           NaN       NaN         NaN            NaN  ...
# 4           NaN       NaN         NaN            NaN  ...
# ..          ...       ...         ...            ...  ...
# 95          NaN       NaN         NaN            NaN  ...
# 96          NaN       NaN         NaN            NaN  ...
# 97          NaN       NaN         NaN            NaN  ...
# 98  push-button       NaN         NaN            NaN  ...
# 99     constant       NaN         NaN            NaN  ...
#
#    drinking_water:legal nearest_qid nearest_distance 2nd_nearest_distance  \
# 0                   NaN   Q76937644              0.0           424.336166
# 1                   NaN   Q76937896              0.0           129.883666
# 2                   NaN   Q76937912              0.0           102.431975
# 3                   NaN   Q76937931              0.0           254.841443
# 4                   NaN   Q76937949              0.0           116.905101
# ..                  ...         ...              ...                  ...
# 95                  NaN   Q76939583              0.0            93.295995
# 96                  NaN   Q76939597              0.0           338.638027
# 97                  NaN   Q76939614              0.0            79.473433
# 98                  NaN   Q76939633              0.0           139.503504
# 99                  NaN   Q76939653              0.0           120.798928
#
#    nearest_has_label_de nearest_has_date nearest_has_operator  \
# 0                  True            False                False
# 1                  True            False                False
# 2                  True            False                False
# 3                  True            False                False
# 4                  True            False                False
# ..                  ...              ...                  ...
# 95                 True            False                False
# 96                 True            False                False
# 97                 True            False                False
# 98                 True            False                False
# 99                 True            False                False
#
#    nearest_has_code  nearest_has_water_type match_found
# 0             False                   False       match
# 1             False                   False       match
# 2             False                   False       match
# 3             False                   False       match
# 4             False                   False       match
# ..              ...                     ...         ...
# 95            False                   False       match
# 96            False                   False       match
# 97            False                   False       match
# 98            False                   False       match
# 99            False                   False       match
#
# [100 rows x 83 columns]

# %% [markdown]
# ### Find out what information already exists for the nearest fountains

# %%
# does nearest have label in german?
df['nearest_has_label_de'] = (query_result.iloc[nearest_idx]['place'].apply(lambda p:p[3:]) != query_result.iloc[nearest_idx]['placeLabel']).tolist()

# does nearest have date?
df['nearest_has_date'] = query_result.iloc[nearest_idx]['date'].apply(lambda d:d is not None).tolist()

# does nearest have operator?
df['nearest_has_operator'] = query_result.iloc[nearest_idx]['operator'].apply(lambda id:id is not None).tolist()

# does nearest have catalog code?
df['nearest_has_code'] = query_result.iloc[nearest_idx]['catalog_code'].apply(lambda id:id is not None).tolist()

# does nearest have water type?
df['nearest_has_water_type'] = query_result.iloc[nearest_idx]['water_supply_type'].apply(lambda id:id is not None).tolist()

# %% [markdown]
# ### Decide on whether nearest fountain should be considered a match

# %%
# The nearest fountain is a match if: 
# - no further than x m away
# - 2nd nearest fountain at nearest least ratio_min further away than the nearest fountain
def validate_proposal(qid, d1, d2, dmax=10, ratio_min=0.5):
    
    if d1 == 0 or (d1<=dmax and d2/d1-1 >= ratio_min):
        return 'match'
    elif d1<=dmax and d2/d1-1 < ratio_min:
        return 'unclear'
    else:
        print("Q-# "+qid+"\td1 "+str(d1)+"\td2 "+str(d2))
        return 'no match'
    
for index, row in df.iterrows():
    df.loc[index, 'match_found'] = validate_proposal(
        row['nearest_qid'], 
        row['nearest_distance'], 
        row['2nd_nearest_distance'],
        dmax=15
    )
dffinal = df.drop(columns=['nearest_distance', '2nd_nearest_distance'])

# %%
len(dffinal)
# Out:
# 1645

# %%
dffinal
# Out:
#               Y          X         amenity fountain created_by wheelchair  \
# 0     41.824508  12.485546  drinking_water   nasone        NaN        NaN
# 1     41.852621  12.478328  drinking_water   nasone        NaN        NaN
# 2     41.854102  12.476834  drinking_water   nasone        NaN        NaN
# 3     41.863749  12.478948  drinking_water   nasone        NaN        NaN
# 4     41.904287  12.513278  drinking_water      NaN       JOSM        NaN
# ...         ...        ...             ...      ...        ...        ...
# 1640  41.913437  12.461680  drinking_water   nasone        NaN        NaN
# 1641  41.902114  12.590335  drinking_water      NaN        NaN        yes
# 1642  41.888007  12.461600  drinking_water   nasone        NaN        NaN
# 1643  41.903375  12.512719  drinking_water      NaN        NaN        NaN
# 1644  41.877493  12.474922  drinking_water   nasone        NaN        NaN
#
#      flow architect description drinking_water  ... artwork_type  \
# 0     NaN       NaN         NaN            NaN  ...          NaN
# 1     NaN       NaN         NaN            NaN  ...          NaN
# 2     NaN       NaN         NaN            NaN  ...          NaN
# 3     NaN       NaN         NaN            NaN  ...          NaN
# 4     NaN       NaN         NaN            NaN  ...          NaN
# ...   ...       ...         ...            ...  ...          ...
# 1640  NaN       NaN         NaN            NaN  ...          NaN
# 1641  NaN       NaN         NaN            NaN  ...          NaN
# 1642  NaN       NaN         NaN            NaN  ...          NaN
# 1643  NaN       NaN         NaN            NaN  ...          NaN
# 1644  NaN       NaN         NaN            NaN  ...          NaN
#
#      subject:wikidata drinking_water:legal nearest_qid nearest_has_label_de  \
# 0                 NaN                  NaN   Q76937644                 True
# 1                 NaN                  NaN   Q76937896                 True
# 2                 NaN                  NaN   Q76937912                 True
# 3                 NaN                  NaN   Q76937931                 True
# 4                 NaN                  NaN   Q76937949                 True
# ...               ...                  ...         ...                  ...
# 1640              NaN                  NaN   Q76978171                 True
# 1641              NaN                  NaN   Q76978191                 True
# 1642              NaN                  NaN   Q76978256                 True
# 1643              NaN                  NaN   Q76978310                 True
# 1644              NaN                  NaN   Q76978359                 True
#
#      nearest_has_date nearest_has_operator nearest_has_code  \
# 0               False                False            False
# 1               False                False            False
# 2               False                False            False
# 3               False                False            False
# 4               False                False            False
# ...               ...                  ...              ...
# 1640            False                False            False
# 1641            False                 True            False
# 1642            False                False            False
# 1643            False                False            False
# 1644            False                False            False
#
#       nearest_has_water_type match_found
# 0                      False       match
# 1                      False       match
# 2                      False       match
# 3                      False       match
# 4                      False       match
# ...                      ...         ...
# 1640                   False       match
# 1641                   False       match
# 1642                   False       match
# 1643                   False       match
# 1644                   False       match
#
# [1645 rows x 81 columns]

# %%
print("\n\nTotal number of rows "+str(len(dffinal)))
# Out:
# Total number of rows 1645

# %%
#write osm to csv
osmDumpFileName = "osm_dump_Rome_fountains_"+dt.now().strftime(dtFmt)+".csv"
dffinal.to_csv(osmDumpFileName)
print("wrote '"+osmDumpFileName+"' ")
# Out:
# wrote 'osm_dump_Rome_fountains_191202_061854.csv'

# %% [markdown]
# ## Create Quickstatement commands from data
# ### Helper functions to format content according to Quickstatements v1 syntax

# %%
def process_coordinates(x, y):
    # format geographic coordinates
    return '@{1:1.8f}/{0:1.8f}'.format(x,y)


def process_year(date):
    # format date
    if np.isnan(date):
        return ''
    else:
        return '+{0:4d}-00-00T00:00:00Z/9'.format(int(date))

    
fountain_type_map = {
    'öffentlicher Brunnen': 'Q53628296',
    'Notwasserbrunnen': 'Q53628522',
    'privater Brunnen': 'Q53629707',
    'Brunnen in städtischer Liegenschaft': 'Q53628618',
    'Brunnen des Verschönerungsvereins': 'Q53628761',
    'Brunnen mit eigener Versorgung': 'Q53630002'
}

water_type_map = {
    'Verteilnetz': 'Q53633635',
    'Quellwasser': 'Q1881858',
    'eigene Versorgung': 'Q53634173',
    'Grundwasser': 'Q161598'
}

def process_fountain_type(type):
    # translate fountain types to wikidata values
    return fountain_type_map[type]


def process_water_type(type):
    # translate water types to wikidata values
    return water_type_map[type]


def process_label(text, dfltLabel):
    # process German language labels
    #print (text + ' '+dfltLabel)
    if text is None:
        return dfltLabel
    elif 'nan' == text.lower():
        return '"'+dfltLabel+'"'
    elif 'none' == text.lower():
        return '"'+dfltLabel+'"'.format(text)
    elif 'brunnen' in text.lower():
        return '"{}"'.format(text)
    elif 'fountain' in text.lower():
        return '"{}"'.format(text)
    else:
        return '"'+dfltLabel+' ({})"'.format(text)

    
def process_label_de(text):
    dfltLabel = 'Brunnen'
    return process_label(text, dfltLabel)
    
def process_label_en(text):
    dfltLabel = 'Fountain'
    return process_label(text, dfltLabel)
    

def createline(lines, item, prop, value, extra, qualifiers=[]):
    # general function to create Quickstatement v1 commands
    if value != '' and value != '""':
        statement = '{}\t{}\t{}'.format(item, prop, value)
        if len(qualifiers):
            # append qualifiers if applicable
            for q in qualifiers:
                statement += '\t{}\t{}'.format(q['prop'], q['value'])
        statement += extra
        statement += '\n'
        lines.append(statement)
    return lines

# %% [markdown]
# ### Create statements, taking care not to overwrite existing data

# %%
# initialize command storage list
lines = []
statedId = "\tS248\tQ1224853"
i=0
for index, row in dffinal.iterrows():
    i+=1
    # either create new or edit existing entity
    if row['match_found'] == 'no match':
        # create a new fountain
        lines.append('CREATE\n')
        item = 'LAST'
    elif row['match_found'] == 'unclear':
        print('unclear match')
        print(row)
        continue
    elif row['match_found'] == 'match':
        # update existing fountain
        item = row['nearest_qid']
        
        
    # Add this basic information only if creating a new entity
    if item == 'LAST':
        # instance of  fountain
        lines = createline(lines, item, 'P31', 'Q483453',statedId)

        # coordinates
        lines = createline(lines, item, 'P625', process_coordinates(row['X'], row['Y']),statedId)
        
    # For other properties, add information if the entity is new or if property does not yet exist
    
    # label in german
    if item == 'LAST' or not row['nearest_has_label_de']:
        lines = createline(lines, item, 'Lde', process_label_de(str(row['name'])),statedId)

    # label in english
    #if item == 'LAST' or not row['nearest_has_label_en']:
    #    lines = createline(lines, item, 'Len', process_label_en(str(row['name'])),statedId)
        
    # creation date
    #if item == 'LAST' or not row['nearest_has_date']:
    #    lines = createline(lines, item, 'P571', process_year(row['date']))

    # operated by  Hamburg Wasser
    #print(str(i)+": "+str(row['operator']))
    if  pd.isna(row['operator']):
        print(str(i)+": "+"operator none")
    else:
         lines = createline(lines, item, 'P137', 'Q1572943',statedId)
            
    # catalog number can always be added (it is hard to check for)
    #lines = createline(lines, item, 'P528', '"{}"'.format(row['operator_id']), [{
    #    'prop': 'P972',
    #    'value': 'Q53629101'
    #}])
# Out:
# 1: operator none
# 2: operator none
# 3: operator none
# 4: operator none
# 5: operator none
# 6: operator none
# 7: operator none
# 8: operator none
# 9: operator none
# 10: operator none
# 11: operator none
# 12: operator none
# 13: operator none
# 14: operator none
# 15: operator none
# 16: operator none
# 17: operator none
# 18: operator none
# 19: operator none
# 20: operator none
# 21: operator none
# 22: operator none
# 23: operator none
# 24: operator none
# 25: operator none
# 26: operator none
# 27: operator none
# 28: operator none
# 29: operator none
# 30: operator none
# 31: operator none
# 32: operator none
# 33: operator none
# 34: operator none
# 35: operator none
# 36: operator none
# 37: operator none
# 38: operator none
# 39: operator none
# 40: operator none
# 41: operator none
# 42: operator none
# 43: operator none
# 44: operator none
# 45: operator none
# 46: operator none
# 47: operator none
# 48: operator none
# 49: operator none
# 50: operator none
# 51: operator none
# 52: operator none
# 53: operator none
# 54: operator none
# 55: operator none
# 56: operator none
# 57: operator none
# 58: operator none
# 59: operator none
# 60: operator none
# 61: operator none
# 62: operator none
# 63: operator none
# 64: operator none
# 65: operator none
# 66: operator none
# 67: operator none
# 68: operator none
# 69: operator none
# 70: operator none
# 71: operator none
# 72: operator none
# 73: operator none
# 74: operator none
# 75: operator none
# 76: operator none
# 77: operator none
# 78: operator none
# 79: operator none
# 80: operator none
# 81: operator none
# 82: operator none
# 83: operator none
# 84: operator none
# 85: operator none
# 86: operator none
# 87: operator none
# 88: operator none
# 89: operator none
# 90: operator none
# 91: operator none
# 92: operator none
# 93: operator none
# 94: operator none
# 95: operator none
# 96: operator none
# 97: operator none
# 98: operator none
# 99: operator none
# 100: operator none
# 101: operator none
# 102: operator none
# 103: operator none
# 104: operator none
# 105: operator none
# 106: operator none
# 107: operator none
# 108: operator none
# 109: operator none
# 110: operator none
# 111: operator none
# 112: operator none
# 113: operator none
# 114: operator none
# 115: operator none
# 116: operator none
# 117: operator none
# 118: operator none
# 119: operator none
# 120: operator none
# 121: operator none
# 122: operator none
# 123: operator none
# 124: operator none
# 125: operator none
# 126: operator none
# 127: operator none
# 128: operator none
# 129: operator none
# 130: operator none
# 131: operator none
# 132: operator none
# 133: operator none
# 134: operator none
# 135: operator none
# 136: operator none
# 137: operator none
# 138: operator none
# 139: operator none
# 140: operator none
# 141: operator none
# 142: operator none
# 143: operator none
# 144: operator none
# 145: operator none
# 146: operator none
# 147: operator none
# 148: operator none
# 149: operator none
# 150: operator none
# 151: operator none
# 152: operator none
# 153: operator none
# 154: operator none
# 155: operator none
# 156: operator none
# 157: operator none
# 158: operator none
# 159: operator none
# 160: operator none
# 161: operator none
# 162: operator none
# 163: operator none
# 164: operator none
# 165: operator none
# 166: operator none
# 167: operator none
# 168: operator none
# 169: operator none
# 170: operator none
# 171: operator none
# 172: operator none
# 173: operator none
# 174: operator none
# 175: operator none
# 176: operator none
# 177: operator none
# 178: operator none
# 179: operator none
# 180: operator none
# 181: operator none
# 182: operator none
# 183: operator none
# 184: operator none
# 185: operator none
# 186: operator none
# 187: operator none
# 188: operator none
# 189: operator none
# 190: operator none
# 191: operator none
# 192: operator none
# 193: operator none
# 194: operator none
# 195: operator none
# 196: operator none
# 197: operator none
# 198: operator none
# 199: operator none
# 200: operator none
# 201: operator none
# 202: operator none
# 203: operator none
# 204: operator none
# 205: operator none
# 206: operator none
# 207: operator none
# 208: operator none
# 209: operator none
# 210: operator none
# 211: operator none
# 212: operator none
# 213: operator none
# 214: operator none
# 215: operator none
# 216: operator none
# 217: operator none
# 218: operator none
# 219: operator none
# 220: operator none
# 221: operator none
# 222: operator none
# 223: operator none
# 224: operator none
# 225: operator none
# 226: operator none
# 227: operator none
# 228: operator none
# 229: operator none
# 230: operator none
# 231: operator none
# 232: operator none
# 233: operator none
# 234: operator none
# 235: operator none
# 236: operator none
# 237: operator none
# 238: operator none
# 239: operator none
# 240: operator none
# 241: operator none
# 242: operator none
# 243: operator none
# 244: operator none
# 245: operator none
# 246: operator none
# 247: operator none
# 248: operator none
# 249: operator none
# 250: operator none
# 251: operator none
# 252: operator none
# 253: operator none
# 254: operator none
# 255: operator none
# 256: operator none
# 257: operator none
# 258: operator none
# 259: operator none
# 260: operator none
# 261: operator none
# 262: operator none
# 263: operator none
# 264: operator none
# 265: operator none
# 266: operator none
# 267: operator none
# 268: operator none
# 269: operator none
# 270: operator none
# 271: operator none
# 272: operator none
# 273: operator none
# 274: operator none
# 275: operator none
# 276: operator none
# 277: operator none
# 278: operator none
# 279: operator none
# 280: operator none
# 281: operator none
# 282: operator none
# 283: operator none
# 284: operator none
# 285: operator none
# 286: operator none
# 287: operator none
# 288: operator none
# 289: operator none
# 290: operator none
# 291: operator none
# 292: operator none
# 293: operator none
# 294: operator none
# 295: operator none
# 296: operator none
# 297: operator none
# 298: operator none
# 299: operator none
# 300: operator none
# 301: operator none
# 302: operator none
# 303: operator none
# 304: operator none
# 305: operator none
# 306: operator none
# 307: operator none
# 308: operator none
# 309: operator none
# 310: operator none
# 311: operator none
# 312: operator none
# 313: operator none
# 314: operator none
# 315: operator none
# 316: operator none
# 317: operator none
# 318: operator none
# 319: operator none
# 320: operator none
# 321: operator none
# 322: operator none
# 323: operator none
# 324: operator none
# 325: operator none
# 326: operator none
# 327: operator none
# 328: operator none
# 329: operator none
# 330: operator none
# 331: operator none
# 332: operator none
# 333: operator none
# 334: operator none
# 335: operator none
# 336: operator none
# 337: operator none
# 338: operator none
# 339: operator none
# 340: operator none
# 341: operator none
# 342: operator none
# 343: operator none
# 344: operator none
# 345: operator none
# 346: operator none
# 347: operator none
# 348: operator none
# 349: operator none
# 350: operator none
# 351: operator none
# 352: operator none
# 353: operator none
# 354: operator none
# 355: operator none
# 356: operator none
# 357: operator none
# 358: operator none
# 359: operator none
# 360: operator none
# 361: operator none
# 362: operator none
# 363: operator none
# 364: operator none
# 365: operator none
# 366: operator none
# 367: operator none
# 368: operator none
# 369: operator none
# 370: operator none
# 371: operator none
# 372: operator none
# 373: operator none
# 374: operator none
# 375: operator none
# 376: operator none
# 377: operator none
# 378: operator none
# 379: operator none
# 380: operator none
# 381: operator none
# 382: operator none
# 383: operator none
# 384: operator none
# 385: operator none
# 386: operator none
# 387: operator none
# 388: operator none
# 389: operator none
# 390: operator none
# 391: operator none
# 392: operator none
# 393: operator none
# 394: operator none
# 395: operator none
# 396: operator none
# 397: operator none
# 398: operator none
# 399: operator none
# 400: operator none
# 401: operator none
# 402: operator none
# 403: operator none
# 404: operator none
# 405: operator none
# 406: operator none
# 407: operator none
# 408: operator none
# 409: operator none
# 410: operator none
# 411: operator none
# 412: operator none
# 413: operator none
# 414: operator none
# 415: operator none
# 416: operator none
# 417: operator none
# 418: operator none
# 419: operator none
# 420: operator none
# 421: operator none
# 422: operator none
# 423: operator none
# 424: operator none
# 425: operator none
# 426: operator none
# 427: operator none
# 428: operator none
# 429: operator none
# 430: operator none
# 431: operator none
# 432: operator none
# 433: operator none
# 434: operator none
# 435: operator none
# 436: operator none
# 437: operator none
# 438: operator none
# 439: operator none
# 440: operator none
# 441: operator none
# 442: operator none
# 443: operator none
# 444: operator none
# 445: operator none
# 446: operator none
# 447: operator none
# 448: operator none
# 449: operator none
# 450: operator none
# 451: operator none
# 452: operator none
# 453: operator none
# 454: operator none
# 455: operator none
# 456: operator none
# 457: operator none
# 458: operator none
# 459: operator none
# 460: operator none
# 461: operator none
# 462: operator none
# 463: operator none
# 464: operator none
# 465: operator none
# 466: operator none
# 467: operator none
# 468: operator none
# 469: operator none
# 470: operator none
# 471: operator none
# 472: operator none
# 473: operator none
# 474: operator none
# 475: operator none
# 476: operator none
# 477: operator none
# 478: operator none
# 479: operator none
# 480: operator none
# 481: operator none
# 482: operator none
# 483: operator none
# 484: operator none
# 485: operator none
# 486: operator none
# 487: operator none
# 488: operator none
# 489: operator none
# 490: operator none
# 491: operator none
# 492: operator none
# 493: operator none
# 494: operator none
# 495: operator none
# 496: operator none
# 497: operator none
# 498: operator none
# 499: operator none
# 500: operator none
# 501: operator none
# 502: operator none
# 503: operator none
# 504: operator none
# 505: operator none
# 506: operator none
# 507: operator none
# 508: operator none
# 509: operator none
# 510: operator none
# 511: operator none
# 512: operator none
# 513: operator none
# 514: operator none
# 515: operator none
# 516: operator none
# 517: operator none
# 518: operator none
# 519: operator none
# 520: operator none
# 521: operator none
# 522: operator none
# 523: operator none
# 524: operator none
# 525: operator none
# 526: operator none
# 527: operator none
# 528: operator none
# 529: operator none
# 530: operator none
# 531: operator none
# 532: operator none
# 533: operator none
# 534: operator none
# 535: operator none
# 536: operator none
# 537: operator none
# 538: operator none
# 539: operator none
# 540: operator none
# 541: operator none
# 542: operator none
# 543: operator none
# 544: operator none
# 545: operator none
# 546: operator none
# 547: operator none
# 548: operator none
# 549: operator none
# 550: operator none
# 551: operator none
# 552: operator none
# 553: operator none
# 554: operator none
# 555: operator none
# 556: operator none
# 557: operator none
# 558: operator none
# 559: operator none
# 560: operator none
# 561: operator none
# 562: operator none
# 563: operator none
# 564: operator none
# 565: operator none
# 566: operator none
# 567: operator none
# 568: operator none
# 569: operator none
# 570: operator none
# 571: operator none
# 572: operator none
# 573: operator none
# 574: operator none
# 575: operator none
# 576: operator none
# 577: operator none
# 578: operator none
# 579: operator none
# 580: operator none
# 581: operator none
# 582: operator none
# 583: operator none
# 584: operator none
# 585: operator none
# 586: operator none
# 587: operator none
# 588: operator none
# 589: operator none
# 590: operator none
# 591: operator none
# 592: operator none
# 593: operator none
# 594: operator none
# 595: operator none
# 596: operator none
# 597: operator none
# 598: operator none
# 599: operator none
# 600: operator none
# 601: operator none
# 602: operator none
# 603: operator none
# 604: operator none
# 605: operator none
# 606: operator none
# 607: operator none
# 608: operator none
# 609: operator none
# 610: operator none
# 611: operator none
# 612: operator none
# 613: operator none
# 614: operator none
# 615: operator none
# 616: operator none
# 617: operator none
# 618: operator none
# 619: operator none
# 620: operator none
# 621: operator none
# 622: operator none
# 623: operator none
# 624: operator none
# 625: operator none
# 626: operator none
# 627: operator none
# 628: operator none
# 629: operator none
# 630: operator none
# 631: operator none
# 632: operator none
# 633: operator none
# 634: operator none
# 635: operator none
# 636: operator none
# 637: operator none
# 638: operator none
# 639: operator none
# 640: operator none
# 641: operator none
# 642: operator none
# 643: operator none
# 644: operator none
# 645: operator none
# 646: operator none
# 647: operator none
# 648: operator none
# 649: operator none
# 650: operator none
# 651: operator none
# 652: operator none
# 653: operator none
# 654: operator none
# 655: operator none
# 656: operator none
# 657: operator none
# 658: operator none
# 659: operator none
# 660: operator none
# 661: operator none
# 662: operator none
# 663: operator none
# 664: operator none
# 665: operator none
# 666: operator none
# 667: operator none
# 668: operator none
# 669: operator none
# 670: operator none
# 671: operator none
# 672: operator none
# 673: operator none
# 674: operator none
# 675: operator none
# 676: operator none
# 677: operator none
# 678: operator none
# 679: operator none
# 680: operator none
# 681: operator none
# 682: operator none
# 683: operator none
# 684: operator none
# 685: operator none
# 686: operator none
# 687: operator none
# 688: operator none
# 689: operator none
# 690: operator none
# 691: operator none
# 692: operator none
# 693: operator none
# 694: operator none
# 695: operator none
# 696: operator none
# 697: operator none
# 698: operator none
# 699: operator none
# 700: operator none
# 701: operator none
# 702: operator none
# 703: operator none
# 704: operator none
# 705: operator none
# 706: operator none
# 707: operator none
# 708: operator none
# 709: operator none
# 710: operator none
# 711: operator none
# 712: operator none
# 713: operator none
# 714: operator none
# 715: operator none
# 716: operator none
# 717: operator none
# 718: operator none
# 719: operator none
# 720: operator none
# 721: operator none
# 722: operator none
# 723: operator none
# 724: operator none
# 725: operator none
# 726: operator none
# 727: operator none
# 728: operator none
# 729: operator none
# 730: operator none
# 731: operator none
# 732: operator none
# 733: operator none
# 734: operator none
# 735: operator none
# 736: operator none
# 737: operator none
# 738: operator none
# 739: operator none
# 740: operator none
# 741: operator none
# 742: operator none
# 743: operator none
# 744: operator none
# 745: operator none
# 746: operator none
# 747: operator none
# 748: operator none
# 749: operator none
# 750: operator none
# 751: operator none
# 752: operator none
# 753: operator none
# 754: operator none
# 755: operator none
# 756: operator none
# 757: operator none
# 758: operator none
# 759: operator none
# 760: operator none
# 761: operator none
# 762: operator none
# 763: operator none
# 764: operator none
# 765: operator none
# 766: operator none
# 767: operator none
# 768: operator none
# 769: operator none
# 770: operator none
# 771: operator none
# 772: operator none
# 773: operator none
# 774: operator none
# 775: operator none
# 776: operator none
# 777: operator none
# 778: operator none
# 779: operator none
# 780: operator none
# 781: operator none
# 782: operator none
# 783: operator none
# 784: operator none
# 785: operator none
# 786: operator none
# 787: operator none
# 788: operator none
# 789: operator none
# 790: operator none
# 791: operator none
# 792: operator none
# 793: operator none
# 794: operator none
# 795: operator none
# 796: operator none
# 797: operator none
# 798: operator none
# 799: operator none
# 800: operator none
# 801: operator none
# 802: operator none
# 803: operator none
# 804: operator none
# 805: operator none
# 806: operator none
# 807: operator none
# 808: operator none
# 809: operator none
# 810: operator none
# 811: operator none
# 812: operator none
# 813: operator none
# 814: operator none
# 815: operator none
# 816: operator none
# 817: operator none
# 818: operator none
# 819: operator none
# 820: operator none
# 821: operator none
# 822: operator none
# 823: operator none
# 824: operator none
# 825: operator none
# 826: operator none
# 827: operator none
# 828: operator none
# 829: operator none
# 830: operator none
# 831: operator none
# 832: operator none
# 833: operator none
# 834: operator none
# 835: operator none
# 836: operator none
# 837: operator none
# 838: operator none
# 839: operator none
# 840: operator none
# 841: operator none
# 842: operator none
# 843: operator none
# 844: operator none
# 845: operator none
# 846: operator none
# 847: operator none
# 848: operator none
# 849: operator none
# 850: operator none
# 851: operator none
# 852: operator none
# 853: operator none
# 854: operator none
# 855: operator none
# 856: operator none
# 857: operator none
# 858: operator none
# 859: operator none
# 860: operator none
# 861: operator none
# 862: operator none
# 863: operator none
# 864: operator none
# 865: operator none
# 866: operator none
# 867: operator none
# 868: operator none
# 869: operator none
# 870: operator none
# 871: operator none
# 872: operator none
# 873: operator none
# 874: operator none
# 875: operator none
# 876: operator none
# 877: operator none
# 878: operator none
# 879: operator none
# 880: operator none
# 881: operator none
# 882: operator none
# 883: operator none
# 884: operator none
# 885: operator none
# 886: operator none
# 887: operator none
# 888: operator none
# 889: operator none
# 890: operator none
# 891: operator none
# 892: operator none
# 893: operator none
# 894: operator none
# 895: operator none
# 896: operator none
# 897: operator none
# 898: operator none
# 899: operator none
# 900: operator none
# 901: operator none
# 902: operator none
# 903: operator none
# 904: operator none
# 905: operator none
# 906: operator none
# 907: operator none
# 908: operator none
# 909: operator none
# 910: operator none
# 911: operator none
# 912: operator none
# 913: operator none
# 914: operator none
# 915: operator none
# 916: operator none
# 917: operator none
# 918: operator none
# 919: operator none
# 920: operator none
# 921: operator none
# 922: operator none
# 923: operator none
# 924: operator none
# 925: operator none
# 926: operator none
# 927: operator none
# 928: operator none
# 929: operator none
# 930: operator none
# 931: operator none
# 932: operator none
# 933: operator none
# 934: operator none
# 935: operator none
# 936: operator none
# 937: operator none
# 938: operator none
# 939: operator none
# 940: operator none
# 941: operator none
# 942: operator none
# 943: operator none
# 944: operator none
# 945: operator none
# 946: operator none
# 947: operator none
# 948: operator none
# 949: operator none
# 950: operator none
# 951: operator none
# 952: operator none
# 953: operator none
# 954: operator none
# 955: operator none
# 956: operator none
# 957: operator none
# 958: operator none
# 959: operator none
# 960: operator none
# 961: operator none
# 962: operator none
# 963: operator none
# 964: operator none
# 965: operator none
# 966: operator none
# 967: operator none
# 968: operator none
# 969: operator none
# 970: operator none
# 971: operator none
# 972: operator none
# 973: operator none
# 974: operator none
# 975: operator none
# 976: operator none
# 977: operator none
# 978: operator none
# 979: operator none
# 980: operator none
# 981: operator none
# 982: operator none
# 983: operator none
# 984: operator none
# 985: operator none
# 986: operator none
# 987: operator none
# 988: operator none
# 989: operator none
# 990: operator none
# 991: operator none
# 992: operator none
# 993: operator none
# 994: operator none
# 995: operator none
# 996: operator none
# 997: operator none
# 998: operator none
# 999: operator none
# 1000: operator none
# 1001: operator none
# 1002: operator none
# 1003: operator none
# 1004: operator none
# 1005: operator none
# 1006: operator none
# 1007: operator none
# 1008: operator none
# 1009: operator none
# 1010: operator none
# 1011: operator none
# 1012: operator none
# 1013: operator none
# 1014: operator none
# 1015: operator none
# 1016: operator none
# 1017: operator none
# 1018: operator none
# 1019: operator none
# 1020: operator none
# 1021: operator none
# 1022: operator none
# 1023: operator none
# 1024: operator none
# 1025: operator none
# 1026: operator none
# 1027: operator none
# 1028: operator none
# 1029: operator none
# 1030: operator none
# 1031: operator none
# 1032: operator none
# 1033: operator none
# 1034: operator none
# 1035: operator none
# 1036: operator none
# 1037: operator none
# 1038: operator none
# 1039: operator none
# 1040: operator none
# 1041: operator none
# 1042: operator none
# 1043: operator none
# 1044: operator none
# 1045: operator none
# 1046: operator none
# 1047: operator none
# 1048: operator none
# 1049: operator none
# 1050: operator none
# 1051: operator none
# 1052: operator none
# 1053: operator none
# 1054: operator none
# 1055: operator none
# 1056: operator none
# 1057: operator none
# 1058: operator none
# 1059: operator none
# 1060: operator none
# 1061: operator none
# 1062: operator none
# 1063: operator none
# 1064: operator none
# 1065: operator none
# 1066: operator none
# 1067: operator none
# 1068: operator none
# 1069: operator none
# 1070: operator none
# 1071: operator none
# 1072: operator none
# 1073: operator none
# 1074: operator none
# 1075: operator none
# 1076: operator none
# 1077: operator none
# 1078: operator none
# 1079: operator none
# 1080: operator none
# 1081: operator none
# 1082: operator none
# 1083: operator none
# 1084: operator none
# 1085: operator none
# 1086: operator none
# 1087: operator none
# 1088: operator none
# 1089: operator none
# 1090: operator none
# 1091: operator none
# 1092: operator none
# 1093: operator none
# 1094: operator none
# 1095: operator none
# 1096: operator none
# 1097: operator none
# 1098: operator none
# 1099: operator none
# 1100: operator none
# 1101: operator none
# 1102: operator none
# 1103: operator none
# 1104: operator none
# 1105: operator none
# 1106: operator none
# 1107: operator none
# 1108: operator none
# 1109: operator none
# 1110: operator none
# 1111: operator none
# 1112: operator none
# 1113: operator none
# 1114: operator none
# 1115: operator none
# 1116: operator none
# 1117: operator none
# 1118: operator none
# 1119: operator none
# 1120: operator none
# 1121: operator none
# 1122: operator none
# 1123: operator none
# 1124: operator none
# 1125: operator none
# 1126: operator none
# 1127: operator none
# 1128: operator none
# 1129: operator none
# 1130: operator none
# 1131: operator none
# 1132: operator none
# 1133: operator none
# 1134: operator none
# 1135: operator none
# 1136: operator none
# 1137: operator none
# 1138: operator none
# 1139: operator none
# 1140: operator none
# 1141: operator none
# 1142: operator none
# 1143: operator none
# 1144: operator none
# 1145: operator none
# 1146: operator none
# 1147: operator none
# 1148: operator none
# 1149: operator none
# 1150: operator none
# 1151: operator none
# 1152: operator none
# 1153: operator none
# 1154: operator none
# 1155: operator none
# 1156: operator none
# 1157: operator none
# 1158: operator none
# 1159: operator none
# 1160: operator none
# 1161: operator none
# 1162: operator none
# 1163: operator none
# 1164: operator none
# 1165: operator none
# 1166: operator none
# 1167: operator none
# 1168: operator none
# 1169: operator none
# 1170: operator none
# 1171: operator none
# 1172: operator none
# 1173: operator none
# 1174: operator none
# 1175: operator none
# 1176: operator none
# 1177: operator none
# 1178: operator none
# 1179: operator none
# 1180: operator none
# 1181: operator none
# 1182: operator none
# 1183: operator none
# 1184: operator none
# 1185: operator none
# 1186: operator none
# 1187: operator none
# 1188: operator none
# 1189: operator none
# 1190: operator none
# 1191: operator none
# 1192: operator none
# 1193: operator none
# 1194: operator none
# 1195: operator none
# 1196: operator none
# 1197: operator none
# 1198: operator none
# 1199: operator none
# 1200: operator none
# 1201: operator none
# 1202: operator none
# 1203: operator none
# 1204: operator none
# 1205: operator none
# 1206: operator none
# 1207: operator none
# 1208: operator none
# 1209: operator none
# 1210: operator none
# 1211: operator none
# 1212: operator none
# 1213: operator none
# 1214: operator none
# 1215: operator none
# 1216: operator none
# 1217: operator none
# 1218: operator none
# 1219: operator none
# 1220: operator none
# 1221: operator none
# 1222: operator none
# 1223: operator none
# 1224: operator none
# 1225: operator none
# 1226: operator none
# 1227: operator none
# 1228: operator none
# 1229: operator none
# 1230: operator none
# 1231: operator none
# 1232: operator none
# 1233: operator none
# 1234: operator none
# 1235: operator none
# 1236: operator none
# 1237: operator none
# 1238: operator none
# 1239: operator none
# 1240: operator none
# 1241: operator none
# 1242: operator none
# 1243: operator none
# 1244: operator none
# 1245: operator none
# 1246: operator none
# 1247: operator none
# 1248: operator none
# 1249: operator none
# 1250: operator none
# 1251: operator none
# 1252: operator none
# 1253: operator none
# 1254: operator none
# 1255: operator none
# 1256: operator none
# 1257: operator none
# 1258: operator none
# 1259: operator none
# 1260: operator none
# 1261: operator none
# 1262: operator none
# 1263: operator none
# 1264: operator none
# 1265: operator none
# 1266: operator none
# 1267: operator none
# 1268: operator none
# 1269: operator none
# 1270: operator none
# 1271: operator none
# 1272: operator none
# 1273: operator none
# 1274: operator none
# 1275: operator none
# 1276: operator none
# 1277: operator none
# 1278: operator none
# 1279: operator none
# 1280: operator none
# 1281: operator none
# 1282: operator none
# 1283: operator none
# 1284: operator none
# 1285: operator none
# 1286: operator none
# 1287: operator none
# 1288: operator none
# 1289: operator none
# 1290: operator none
# 1291: operator none
# 1292: operator none
# 1293: operator none
# 1294: operator none
# 1295: operator none
# 1296: operator none
# 1297: operator none
# 1298: operator none
# 1299: operator none
# 1300: operator none
# 1301: operator none
# 1302: operator none
# 1303: operator none
# 1304: operator none
# 1305: operator none
# 1306: operator none
# 1307: operator none
# 1308: operator none
# 1309: operator none
# 1310: operator none
# 1311: operator none
# 1312: operator none
# 1313: operator none
# 1314: operator none
# 1315: operator none
# 1316: operator none
# 1317: operator none
# 1318: operator none
# 1319: operator none
# 1320: operator none
# 1321: operator none
# 1322: operator none
# 1323: operator none
# 1324: operator none
# 1325: operator none
# 1326: operator none
# 1327: operator none
# 1328: operator none
# 1329: operator none
# 1330: operator none
# 1331: operator none
# 1332: operator none
# 1333: operator none
# 1334: operator none
# 1335: operator none
# 1336: operator none
# 1337: operator none
# 1338: operator none
# 1339: operator none
# 1340: operator none
# 1341: operator none
# 1342: operator none
# 1343: operator none
# 1344: operator none
# 1345: operator none
# 1346: operator none
# 1347: operator none
# 1348: operator none
# 1349: operator none
# 1350: operator none
# 1351: operator none
# 1352: operator none
# 1353: operator none
# 1354: operator none
# 1355: operator none
# 1356: operator none
# 1357: operator none
# 1358: operator none
# 1359: operator none
# 1360: operator none
# 1361: operator none
# 1362: operator none
# 1363: operator none
# 1364: operator none
# 1365: operator none
# 1366: operator none
# 1367: operator none
# 1368: operator none
# 1369: operator none
# 1370: operator none
# 1371: operator none
# 1372: operator none
# 1373: operator none
# 1374: operator none
# 1375: operator none
# 1376: operator none
# 1378: operator none
# 1379: operator none
# 1380: operator none
# 1381: operator none
# 1382: operator none
# 1383: operator none
# 1384: operator none
# 1385: operator none
# 1386: operator none
# 1387: operator none
# 1388: operator none
# 1389: operator none
# 1390: operator none
# 1391: operator none
# 1392: operator none
# 1393: operator none
# 1394: operator none
# 1395: operator none
# 1396: operator none
# 1397: operator none
# 1398: operator none
# 1399: operator none
# 1400: operator none
# 1401: operator none
# 1402: operator none
# 1403: operator none
# 1404: operator none
# 1405: operator none
# 1406: operator none
# 1407: operator none
# 1408: operator none
# 1409: operator none
# 1410: operator none
# 1411: operator none
# 1412: operator none
# 1413: operator none
# 1414: operator none
# 1415: operator none
# 1416: operator none
# 1417: operator none
# 1418: operator none
# 1419: operator none
# 1420: operator none
# 1421: operator none
# 1422: operator none
# 1423: operator none
# 1425: operator none
# 1426: operator none
# 1427: operator none
# 1428: operator none
# 1429: operator none
# 1430: operator none
# 1431: operator none
# 1432: operator none
# 1433: operator none
# 1434: operator none
# 1435: operator none
# 1436: operator none
# 1437: operator none
# 1438: operator none
# 1439: operator none
# 1440: operator none
# 1441: operator none
# 1442: operator none
# 1443: operator none
# 1444: operator none
# 1445: operator none
# 1446: operator none
# 1447: operator none
# 1448: operator none
# 1449: operator none
# 1450: operator none
# 1451: operator none
# 1452: operator none
# 1453: operator none
# 1454: operator none
# 1455: operator none
# 1456: operator none
# 1457: operator none
# 1458: operator none
# 1459: operator none
# 1460: operator none
# 1461: operator none
# 1462: operator none
# 1463: operator none
# 1464: operator none
# 1465: operator none
# 1466: operator none
# 1467: operator none
# 1468: operator none
# 1469: operator none
# 1470: operator none
# 1471: operator none
# 1472: operator none
# 1473: operator none
# 1474: operator none
# 1475: operator none
# 1476: operator none
# 1477: operator none
# 1478: operator none
# 1479: operator none
# 1480: operator none
# 1481: operator none
# 1482: operator none
# 1483: operator none
# 1484: operator none
# 1485: operator none
# 1486: operator none
# 1487: operator none
# 1488: operator none
# 1489: operator none
# 1490: operator none
# 1491: operator none
# 1492: operator none
# 1493: operator none
# 1494: operator none
# 1495: operator none
# 1496: operator none
# 1497: operator none
# 1498: operator none
# 1499: operator none
# 1500: operator none
# 1501: operator none
# 1502: operator none
# 1503: operator none
# 1504: operator none
# 1505: operator none
# 1506: operator none
# 1507: operator none
# 1508: operator none
# 1509: operator none
# 1510: operator none
# 1511: operator none
# 1512: operator none
# 1513: operator none
# 1514: operator none
# 1515: operator none
# 1516: operator none
# 1517: operator none
# 1518: operator none
# 1519: operator none
# 1520: operator none
# 1521: operator none
# 1522: operator none
# 1523: operator none
# 1524: operator none
# 1525: operator none
# 1526: operator none
# 1527: operator none
# 1528: operator none
# 1529: operator none
# 1530: operator none
# 1531: operator none
# 1532: operator none
# 1533: operator none
# 1534: operator none
# 1535: operator none
# 1536: operator none
# 1537: operator none
# 1538: operator none
# 1539: operator none
# 1540: operator none
# 1541: operator none
# 1542: operator none
# 1543: operator none
# 1544: operator none
# 1545: operator none
# 1546: operator none
# 1547: operator none
# 1548: operator none
# 1549: operator none
# 1550: operator none
# 1551: operator none
# 1552: operator none
# 1553: operator none
# 1554: operator none
# 1555: operator none
# 1556: operator none
# 1557: operator none
# 1558: operator none
# 1559: operator none
# 1560: operator none
# 1561: operator none
# 1562: operator none
# 1563: operator none
# 1564: operator none
# 1565: operator none
# 1566: operator none
# 1567: operator none
# 1568: operator none
# 1569: operator none
# 1570: operator none
# 1571: operator none
# 1572: operator none
# 1573: operator none
# 1574: operator none
# 1575: operator none
# 1576: operator none
# 1577: operator none
# 1578: operator none
# 1579: operator none
# 1580: operator none
# 1581: operator none
# 1582: operator none
# 1583: operator none
# 1584: operator none
# 1585: operator none
# 1586: operator none
# 1587: operator none
# 1588: operator none
# 1589: operator none
# 1590: operator none
# 1591: operator none
# 1592: operator none
# 1593: operator none
# 1594: operator none
# 1595: operator none
# 1596: operator none
# 1597: operator none
# 1598: operator none
# 1599: operator none
# 1600: operator none
# 1602: operator none
# 1603: operator none
# 1604: operator none
# 1605: operator none
# 1606: operator none
# 1607: operator none
# 1608: operator none
# 1609: operator none
# 1610: operator none
# 1611: operator none
# 1612: operator none
# 1613: operator none
# 1614: operator none
# 1615: operator none
# 1616: operator none
# 1617: operator none
# 1618: operator none
# 1619: operator none
# 1620: operator none
# 1621: operator none
# 1622: operator none
# 1623: operator none
# 1624: operator none
# 1625: operator none
# 1626: operator none
# 1627: operator none
# 1628: operator none
# 1629: operator none
# 1630: operator none
# 1631: operator none
# 1632: operator none
# 1633: operator none
# 1634: operator none
# 1635: operator none
# 1636: operator none
# 1637: operator none
# 1638: operator none
# 1639: operator none
# 1640: operator none
# 1641: operator none
# 1643: operator none
# 1644: operator none
# 1645: operator none

# %% [markdown]
# # Write commands to file

# %%
quickStatFileName = "quickstatement_commands_Rome_fountain_"+dt.now().strftime(dtFmt)+".txt"
with io.open(quickStatFileName, "w", encoding='utf8') as f:
    f.writelines(lines)
print("wrote '"+quickStatFileName+"' with "+str(len(lines))+" lines")
# Out:
# wrote 'quickstatement_commands_Rome_fountain_191201_085501.txt' with 8191 lines

# %% [markdown]
# # Import into Wikidata
# - Go to https://tools.wmflabs.org/wikidata-todo/quick_statements.php.
# - Authenticate yourself with your Wikidata account.
# - Copy and paste the contents of quickstatement_commands*.txt into the blank field, and run the commands

# %% [markdown]
# see ../20191030_1600_import.png
#
# ...
# 58. Processing Q72935495 (Q72935495 Lde "Brunnen (Seelöwe-Planschbecken )")
# 59. Processing Q72935495 (Q72935495 P137 Q27229237)
#
# All done!.

# %%
# it may well take half an hour until it works https://query.wikidata.org/
