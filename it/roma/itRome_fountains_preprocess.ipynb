# %% [markdown]
# # Automatic import of Rome drinking fountains data to Wikidata
# The following script downloads fountain data from osm as per https://github.com/water-fountains/proximap/issues/133, compares it to existing fountains in Wikidata for the same region, and creates Wikidata Quickstatement commands to complete the entries in Wikidata. New entities are created if no matching fountains are found.

# %% [markdown]
# ## Initialize environment

# %%
from datetime import datetime as dt
dtFmt = "%y%m%d_%H%M%S"
print (dt.now().strftime(dtFmt))
import pandas as pd
import io
import numpy as np
from urllib.request import urlopen
import json
from math import *
from platform import python_version
print("Python v "+python_version())
#https://github.com/paulhoule/gastrodon/issues/7 
from gastrodon import RemoteEndpoint,QName,ttl,URIRef,inline
from matplotlib import pyplot
# Out:
# 191201_082918
# Python v 3.6.5

# %%
#@prefix wikibase: <wikibase: <http://wikiba.se/ontology#> .
prefixes=inline("""
   @prefix wd: <http://www.wikidata.org/entity/> .
   @prefix wdt: <http://www.wikidata.org/prop/direct/> .
   @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
   @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
""").graph
endpoint=RemoteEndpoint(
   #"https://query.wikidata.org/sparql"
    "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
   ,prefixes=prefixes
)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("osmFountainsRome191201_082705.csv")

# %%
df.head()
# Out:
#    type         id        lat        lon         amenity fountain created_by  \
# 0  node  246569213  41.824508  12.485546  drinking_water   nasone        NaN
# 1  node  246569214  41.852621  12.478328  drinking_water   nasone        NaN
# 2  node  246569215  41.854102  12.476834  drinking_water   nasone        NaN
# 3  node  246569216  41.863749  12.478948  drinking_water   nasone        NaN
# 4  node  246571139  41.904287  12.513278  drinking_water      NaN       JOSM
#
#   wheelchair flow architect  ... operator designation level location covered  \
# 0        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 1        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 2        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 3        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
# 4        NaN  NaN       NaN  ...      NaN         NaN   NaN      NaN     NaN
#
#   description:de website artwork_type subject:wikidata drinking_water:legal
# 0            NaN     NaN          NaN              NaN                  NaN
# 1            NaN     NaN          NaN              NaN                  NaN
# 2            NaN     NaN          NaN              NaN                  NaN
# 3            NaN     NaN          NaN              NaN                  NaN
# 4            NaN     NaN          NaN              NaN                  NaN
#
# [5 rows x 76 columns]

# %% [markdown]
# ### Rename columns to make them easier to work with

# %%
# remove not needed columns
df = df.drop(columns=['type','id'])

# %%
# rename columns
df = df.rename(index=str, columns=
               {"lat": "Y"})

# %%
# rename columns
df = df.rename(index=str, columns=
               {"lon": "X"})

# %%
df.head()
# Out:
#            Y          X         amenity fountain created_by wheelchair flow  \
# 0  41.824508  12.485546  drinking_water   nasone        NaN        NaN  NaN
# 1  41.852621  12.478328  drinking_water   nasone        NaN        NaN  NaN
# 2  41.854102  12.476834  drinking_water   nasone        NaN        NaN  NaN
# 3  41.863749  12.478948  drinking_water   nasone        NaN        NaN  NaN
# 4  41.904287  12.513278  drinking_water      NaN       JOSM        NaN  NaN
#
#   architect description drinking_water  ... operator designation level  \
# 0       NaN         NaN            NaN  ...      NaN         NaN   NaN
# 1       NaN         NaN            NaN  ...      NaN         NaN   NaN
# 2       NaN         NaN            NaN  ...      NaN         NaN   NaN
# 3       NaN         NaN            NaN  ...      NaN         NaN   NaN
# 4       NaN         NaN            NaN  ...      NaN         NaN   NaN
#
#   location covered description:de website artwork_type  subject:wikidata  \
# 0      NaN     NaN            NaN     NaN          NaN               NaN
# 1      NaN     NaN            NaN     NaN          NaN               NaN
# 2      NaN     NaN            NaN     NaN          NaN               NaN
# 3      NaN     NaN            NaN     NaN          NaN               NaN
# 4      NaN     NaN            NaN     NaN          NaN               NaN
#
#   drinking_water:legal
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 74 columns]

# %%
len(df)
# Out:
# 127

# %% [markdown]
# ## Identify already existing fountains
# ### Query fountains from Wikidata

# %%
# Find the geographic extent of the data

buffer = 0.0003  # in degrees, corresponds to about 20-30 meters)
bounds = {
    'minX': df['X'].min() - buffer,
    'minY': df['Y'].min() - buffer,
    'maxX': df['X'].max() + buffer,
    'maxY': df['Y'].max() + buffer
}
print("bounds: ")
for key,value in bounds.items():
    print(key+ ": "+str(value))
# Out:
# bounds:
# minX: 12.3238906
# minY: 41.802459999999996
# maxX: 12.6220409
# maxY: 41.99526720000001

# %%
# Query fountains (both water wells and fountains) from Wikidata within bounding box found above
# placeLabel 

query_string = """SELECT ?place ?placeLabel ?location ?date ?catalog_code ?catalogLabel ?operator ?water_supply_type
WHERE
{{
  # Enter coordinates
  SERVICE wikibase:box {{
    # ?place wdt:P625 ?location .
    bd:serviceParam wikibase:cornerWest "Point({minX} {minY})"^^geo:wktLiteral.
    bd:serviceParam wikibase:cornerEast "Point({maxX} {maxY})"^^geo:wktLiteral.
  }} .
  # Is a water well or fountain or subclass of fountain
  FILTER (EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q43483 }} || EXISTS {{ ?place wdt:P31/wdt:P279* wd:Q483453 }}).
  SERVICE wikibase:label {{
    bd:serviceParam wikibase:language "[AUTO_LANGUAGE],de" .
  }} 
  OPTIONAL {{ ?place p:P528 ?catalog_code.
            # ?catalog_code pq:P972 ?catalog.}}
  OPTIONAL {{ ?place wdt:P571 ?date.}}
  OPTIONAL {{ ?place wdt:P5623 ?water_supply_type}}
  OPTIONAL {{ ?place wdt:P137 ?operator.}}
  OPTIONAL {{ ?place rdfs:placeLabel ?placeLabel}}
}}
  """.format(**bounds)

print(query_string)
# Out:
# SELECT ?place ?placeLabel ?location ?date ?catalog_code ?catalogLabel ?operator ?water_supply_type
# WHERE
# {
#   # Enter coordinates
#   SERVICE wikibase:box {
#     ?place wdt:P625 ?location .
#     bd:serviceParam wikibase:cornerWest "Point(12.3238906 41.802459999999996)"^^geo:wktLiteral.
#     bd:serviceParam wikibase:cornerEast "Point(12.6220409 41.99526720000001)"^^geo:wktLiteral.
#   } .
#   # Is a water well or fountain or subclass of fountain
#   FILTER (EXISTS { ?place wdt:P31/wdt:P279* wd:Q43483 } || EXISTS { ?place wdt:P31/wdt:P279* wd:Q483453 }).
#   SERVICE wikibase:label {
#     bd:serviceParam wikibase:language "[AUTO_LANGUAGE],de" .
#   }
#   OPTIONAL { ?place p:P528 ?catalog_code.
#             ?catalog_code pq:P972 ?catalog.}
#   OPTIONAL { ?place wdt:P571 ?date.}
#   OPTIONAL { ?place wdt:P5623 ?water_supply_type}
#   OPTIONAL { ?place wdt:P137 ?operator.}
#   OPTIONAL { ?place rdfs:placeLabel ?placeLabel}
# }

# %%
# Perform query
query_result = endpoint.select(query_string)

# %%
#print(query_string)
print("\n\nTotal number of rows incl. duplicates "+str(len(query_result))+" size "+str(query_result.size))
# Out:
# Total number of rows incl. duplicates 47 size 376

# %% [markdown]
# ### Tidy up data

# %%
# Extract coordinates from Wikidata results

query_result['X'] = query_result['location'].apply(lambda l:float(l.split('(')[1].split(' ')[0]))
query_result['Y'] = query_result['location'].apply(lambda l:float(l.split(' ')[1].split(')')[0]))

# %%
query_result.head(100)
# Out:
#            place                    placeLabel  \
# 0     wd:Q185382                 Trevi-Brunnen
# 1     wd:Q267971               Tritonenbrunnen
# 2     wd:Q655470             Vierströmebrunnen
# 3     wd:Q983774                  Mosesbrunnen
# 4    wd:Q1085738                      Q1085738
# 5    wd:Q1114231       Fontana della Barcaccia
# 6    wd:Q1217302              Die Vier Brunnen
# 7    wd:Q1227084              Dioskurenbrunnen
# 8    wd:Q1234446                   Septizodium
# 9    wd:Q1303855               Galeerenbrunnen
# 10   wd:Q1435809                 Fontana Paola
# 11   wd:Q1435824              Fontana del Moro
# 12   wd:Q1714672                Juturna-Quelle
# 13   wd:Q1759793                 Neptunbrunnen
# 14   wd:Q1924755                   Meta Sudans
# 15    wd:Q857540                Bienen-Brunnen
# 16    wd:Q936296           Schildkrötenbrunnen
# 17   wd:Q3747364                      Q3747364
# 18   wd:Q3747367                      Q3747367
# 19   wd:Q3747369                      Q3747369
# 20   wd:Q3747370                      Q3747370
# 21   wd:Q3747378                      Q3747378
# 22   wd:Q3747388                      Q3747388
# 23   wd:Q3747397                      Q3747397
# 24   wd:Q3747399          Fontana delle Anfore
# 25   wd:Q3747400                      Q3747400
# 26   wd:Q3747402                      Q3747402
# 27   wd:Q3747421                      Q3747421
# 28   wd:Q3747429                      Q3747429
# 29   wd:Q3747437                      Q3747437
# 30   wd:Q3747439                      Q3747439
# 31   wd:Q3747440                      Q3747440
# 32   wd:Q3747442                      Q3747442
# 33   wd:Q3747443                      Q3747443
# 34   wd:Q3747444                      Q3747444
# 35   wd:Q3747445                      Q3747445
# 36   wd:Q3747465                      Q3747465
# 37   wd:Q3747467  Fontane di piazza San Pietro
# 38   wd:Q3902380                      Q3902380
# 39  wd:Q18379990                     Q18379990
# 40   wd:Q5465137                      Q5465137
# 41   wd:Q5465141                      Q5465141
# 42   wd:Q7489878               Najaden-Brunnen
# 43  wd:Q12042914                     Q12042914
# 44  wd:Q29582887                     Q29582887
# 45  wd:Q74574057                     Q74574057
# 46  wd:Q56256300                     Q56256300
#
#                             location                  date catalog_code  \
# 0      Point(12.483166666 41.900875)  1735-01-01T00:00:00Z         None
# 1   Point(12.488333333 41.903611111)                  None         None
# 2         Point(12.473075 41.898953)  1640-01-01T00:00:00Z         None
# 3     Point(12.49441667 41.90436111)                  None         None
# 4         Point(12.479643 41.907771)  1581-01-01T00:00:00Z         None
# 5         Point(12.482212 41.905806)  1629-01-01T00:00:00Z         None
# 6         Point(12.490736 41.901962)                  None         None
# 7     Point(12.48669167 41.89911389)  1588-01-01T00:00:00Z         None
# 8         Point(12.488719 41.885633)                  None         None
# 9     Point(12.45516389 41.90633333)                  None         None
# 10       Point(12.46416667 41.88875)                  None         None
# 11            Point(12.4731 41.8981)                  None         None
# 12            Point(12.4859 41.8916)                  None         None
# 13         Point(12.473 41.89980278)  1574-01-01T00:00:00Z         None
# 14    Point(12.49066667 41.89008333)                  None         None
# 15    Point(12.48872222 41.90430556)  1644-01-01T00:00:00Z         None
# 16       Point(12.4775 41.893805555)                  None         None
# 17             Point(12.4675 41.888)                  None         None
# 18            Point(12.4748 41.9032)                  None         None
# 19            Point(12.4751 41.9046)                  None         None
# 20            Point(12.4856 41.9315)                  None         None
# 21      Point(12.5047903 41.8868574)                  None         None
# 22            Point(12.4959 41.8848)  1931-01-01T00:00:00Z         None
# 23             Point(12.4688 41.898)                  None         None
# 24        Point(12.477056 41.879557)                  None         None
# 25            Point(12.4645 41.9094)                  None         None
# 26      Point(12.5023882 41.9187196)                  None         None
# 27              Point(12.47 41.8918)                  None         None
# 28            Point(12.4803 41.9008)                  None         None
# 29            Point(12.4743 41.8966)                  None         None
# 30            Point(12.4993 41.8971)                  None         None
# 31            Point(12.4703 41.8895)                  None         None
# 32             Point(12.481 41.8944)  1589-01-01T00:00:00Z         None
# 33            Point(12.4908 41.8949)                  None         None
# 34            Point(12.4764 41.8928)                  None         None
# 35            Point(12.4767 41.8992)                  None         None
# 36            Point(12.4708 41.8947)                  None         None
# 37           Point(12.45725 41.9028)                  None         None
# 38        Point(12.4645 41.90923611)  1929-01-01T00:00:00Z         None
# 39            Point(12.4843 41.8923)                  None         None
# 40            Point(12.4755 41.9105)  1821-01-01T00:00:00Z         None
# 41            Point(12.4746 41.9031)                  None         None
# 42            Point(12.4963 41.9027)                  None         None
# 43        Point(12.451473 41.903903)                  None         None
# 44            Point(12.4659 41.8986)                  None         None
# 45       Point(12.519195 41.8814447)                  None         None
# 46    Point(12.47352028 41.88727951)                  None         None
#
#    catalogLabel operator water_supply_type          X          Y
# 0          None     None              None  12.483167  41.900875
# 1          None     None              None  12.488333  41.903611
# 2          None     None              None  12.473075  41.898953
# 3          None     None              None  12.494417  41.904361
# 4          None     None              None  12.479643  41.907771
# 5          None     None              None  12.482212  41.905806
# 6          None     None              None  12.490736  41.901962
# 7          None     None              None  12.486692  41.899114
# 8          None     None              None  12.488719  41.885633
# 9          None     None              None  12.455164  41.906333
# 10         None     None              None  12.464167  41.888750
# 11         None     None              None  12.473100  41.898100
# 12         None     None              None  12.485900  41.891600
# 13         None     None              None  12.473000  41.899803
# 14         None     None              None  12.490667  41.890083
# 15         None     None              None  12.488722  41.904306
# 16         None     None              None  12.477500  41.893806
# 17         None     None              None  12.467500  41.888000
# 18         None     None              None  12.474800  41.903200
# 19         None     None              None  12.475100  41.904600
# 20         None     None              None  12.485600  41.931500
# 21         None     None              None  12.504790  41.886857
# 22         None     None              None  12.495900  41.884800
# 23         None     None              None  12.468800  41.898000
# 24         None     None              None  12.477056  41.879557
# 25         None     None              None  12.464500  41.909400
# 26         None     None              None  12.502388  41.918720
# 27         None     None              None  12.470000  41.891800
# 28         None     None              None  12.480300  41.900800
# 29         None     None              None  12.474300  41.896600
# 30         None     None              None  12.499300  41.897100
# 31         None     None              None  12.470300  41.889500
# 32         None     None              None  12.481000  41.894400
# 33         None     None              None  12.490800  41.894900
# 34         None     None              None  12.476400  41.892800
# 35         None     None              None  12.476700  41.899200
# 36         None     None              None  12.470800  41.894700
# 37         None     None              None  12.457250  41.902800
# 38         None     None              None  12.464500  41.909236
# 39         None     None              None  12.484300  41.892300
# 40         None     None              None  12.475500  41.910500
# 41         None     None              None  12.474600  41.903100
# 42         None     None              None  12.496300  41.902700
# 43         None     None              None  12.451473  41.903903
# 44         None     None              None  12.465900  41.898600
# 45         None     None              None  12.519195  41.881445
# 46         None     None              None  12.473520  41.887280

# %%
# show duplicates
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html#pandas.DataFrame.duplicated

ids = query_result['placeLabel']
#ids = query_result['label']
duplicates = query_result[ids.isin(ids[ids.duplicated(keep=False)])]
dupli = duplicates.drop(columns=['catalog_code', 'catalogLabel', 'water_supply_type', 'date', 'catalogLabel', 'location', 'operator'])
dupli.sort_values(by=['placeLabel'],inplace=True)
print ("Duplicates: "+str(len(dupli))+"\n\n")
print(dupli.to_string())
# Out:
# Duplicates: 0
#
#
# Empty DataFrame
# Columns: [place, placeLabel, X, Y]
# Index: []

# %%
def createMerge(dupli, extraText):
    #Create MERGE Command
    linesDup = []
    prevQ= ""
    prevX=0
    prevY=0
    for index, row in dupli.iterrows():
        
        # either create new or edit existing entity
        if row['X'] == prevX:
            if row['Y'] == prevY:
                lineDup = "MERGE\t"+prevQ[3:]+"\t"+row['place'][3:]+"\n"
                linesDup.append(lineDup)
            else:
                prevX=row['X']
                prevY=row['Y']
                prevQ=row['place']
        else:
            prevX=row['X']
            prevY=row['Y']
            prevQ=row['place']
            
    print("Merge commands"+extraText+" total: "+str(len(linesDup))+"\n\n")
    print(linesDup)
    
createMerge(dupli, "")
# Out:
# Merge commands total: 0
#
#
# []

# %%
#write MERGE command to File
quickStatDupliFileName = "quickstatement_commands_Hamburg_drink_DUPLI_"+dt.now().strftime(dtFmt)+".txt"
with io.open(quickStatDupliFileName, "w", encoding='utf8') as f:
    f.writelines(linesDup)
print("wrote '"+quickStatDupliFileName+"' with "+str(len(linesDup))+" lines")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-cf9cdb649497> in <module>
#       2 quickStatDupliFileName = "quickstatement_commands_Hamburg_drink_DUPLI_"+dt.now().strftime(dtFmt)+".txt"
#       3 with io.open(quickStatDupliFileName, "w", encoding='utf8') as f:
# ----> 4     f.writelines(linesDup)
#       5 print("wrote '"+quickStatDupliFileName+"' with "+str(len(linesDup))+" lines")
#
# NameError: name 'linesDup' is not defined

# %%
# show duplicates STRICT
#idsS = query_result['placeLabel','X','Y'] #this does not work yet
#duplicatesS = query_result[ids.isin(ids[ids.duplicated(keep=False)])]
#dupliS = duplicatesS.drop(columns=['catalog_code', 'catalogLabel', 'water_supply_type', 'date', 'catalogLabel', 'location', 'operator'])
#dupliS.sort_values(by=['placeLabel'],inplace=True)
#print(dupliS.to_string())
#createMerge(dupliS, " - strict")

# %%
# remove duplicate entries

# duplicate entries are caused when e.g. a fountain has catalog codes from two catalogs
query_result = query_result.drop_duplicates('place')
print("\n\nTotal number of rows without duplicates "+str(len(query_result)))
# Out:
# Total number of rows without duplicates 130

# %%
query_result.head(100)
# Out:
#            place            placeLabel                       location  date  \
# 0    wd:Q1454814        Minervabrunnen  Point(9.95166667 53.54583333)  None
# 1     wd:Q814528           Behnbrunnen  Point(9.94194444 53.54805556)  None
# 2    wd:Q2358953      Stuhlmannbrunnen  Point(9.93527778 53.54972222)  None
# 3    wd:Q2651496         Alsterfontäne  Point(9.99495278 53.55461667)  None
# 4   wd:Q18632417  Vierländerin-Brunnen        Point(9.99014 53.54766)  None
# ..           ...                   ...                            ...   ...
# 95  wd:Q76308142             Q76308142   Point(10.2961728 53.4268728)  None
# 96  wd:Q76308157             Q76308157     Point(9.9418923 53.548183)  None
# 97  wd:Q76308173             Q76308173    Point(10.0831994 53.626006)  None
# 98  wd:Q76308188             Q76308188    Point(9.9919829 53.5509746)  None
# 99  wd:Q76308203             Q76308203    Point(9.9788922 53.5623873)  None
#
#    catalog_code catalogLabel operator water_supply_type          X          Y
# 0          None         None     None              None   9.951667  53.545833
# 1          None         None     None              None   9.941944  53.548056
# 2          None         None     None              None   9.935278  53.549722
# 3          None         None     None              None   9.994953  53.554617
# 4          None         None     None              None   9.990140  53.547660
# ..          ...          ...      ...               ...        ...        ...
# 95         None         None     None              None  10.296173  53.426873
# 96         None         None     None              None   9.941892  53.548183
# 97         None         None     None              None  10.083199  53.626006
# 98         None         None     None              None   9.991983  53.550975
# 99         None         None     None              None   9.978892  53.562387
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Compute distances between fountains

# %%
# helper function to compute distances on the globe, returns distances in meters
def spherical_dist(pos1, pos2, r=6371000):
    pos1 = pos1 * np.pi / 180
    pos2 = pos2 * np.pi / 180
    cos_lat1 = np.cos(pos1[..., 0])
    cos_lat2 = np.cos(pos2[..., 0])
    cos_lat_d = np.cos(pos1[..., 0] - pos2[..., 0])
    cos_lon_d = np.cos(pos1[..., 1] - pos2[..., 1])
    return r * np.arccos(cos_lat_d - cos_lat1 * cos_lat2 * (1 - cos_lon_d))


# compute distances from each ODZ fountain to each Wikidata fountain
distances = spherical_dist(df[['X','Y']].values[:, None], query_result[['X','Y']].values)

# %% [markdown]
# ### Identify nearest and second nearest matches for each osm hamburg fountain

# %%
# indexes of nearest fountains
nearest_idx = np.argmin(distances, axis=1).tolist()

# QID of nearest fountains
df['nearest_qid'] = query_result.iloc[nearest_idx]['place'].apply(lambda id:id[3:]).tolist()

# distance to nearest fountain
df['nearest_distance'] = np.min(distances, axis=1).tolist()


# then remove nearest
i_line=0
for i_col in nearest_idx:
    distances[i_line, i_col] = 100000
    i_line += 1
# find distance to second nearest
df['2nd_nearest_distance'] = np.min(distances, axis=1).tolist()

df.head(100)
# Out:
#             Y          X         amenity fountain created_by wheelchair  \
# 0   41.824508  12.485546  drinking_water   nasone        NaN        NaN
# 1   41.852621  12.478328  drinking_water   nasone        NaN        NaN
# 2   41.854102  12.476834  drinking_water   nasone        NaN        NaN
# 3   41.863749  12.478948  drinking_water   nasone        NaN        NaN
# 4   41.904287  12.513278  drinking_water      NaN       JOSM        NaN
# ..        ...        ...             ...      ...        ...        ...
# 95  41.901662  12.485754  drinking_water      NaN        NaN        NaN
# 96  41.911419  12.487827  drinking_water      NaN       JOSM        NaN
# 97  41.892383  12.512610  drinking_water   nasone        NaN        NaN
# 98  41.893211  12.509447  drinking_water   nasone        NaN        NaN
# 99  41.892285  12.508577  drinking_water   nasone        NaN        NaN
#
#            flow architect description drinking_water  ... location covered  \
# 0           NaN       NaN         NaN            NaN  ...      NaN     NaN
# 1           NaN       NaN         NaN            NaN  ...      NaN     NaN
# 2           NaN       NaN         NaN            NaN  ...      NaN     NaN
# 3           NaN       NaN         NaN            NaN  ...      NaN     NaN
# 4           NaN       NaN         NaN            NaN  ...      NaN     NaN
# ..          ...       ...         ...            ...  ...      ...     ...
# 95          NaN       NaN         NaN            NaN  ...      NaN     NaN
# 96          NaN       NaN         NaN            NaN  ...      NaN     NaN
# 97          NaN       NaN         NaN            NaN  ...      NaN     NaN
# 98  push-button       NaN         NaN            NaN  ...      NaN     NaN
# 99     constant       NaN         NaN            NaN  ...      NaN     NaN
#
#    description:de website artwork_type subject:wikidata drinking_water:legal  \
# 0             NaN     NaN          NaN              NaN                  NaN
# 1             NaN     NaN          NaN              NaN                  NaN
# 2             NaN     NaN          NaN              NaN                  NaN
# 3             NaN     NaN          NaN              NaN                  NaN
# 4             NaN     NaN          NaN              NaN                  NaN
# ..            ...     ...          ...              ...                  ...
# 95            NaN     NaN          NaN              NaN                  NaN
# 96            NaN     NaN          NaN              NaN                  NaN
# 97            NaN     NaN          NaN              NaN                  NaN
# 98            NaN     NaN          NaN              NaN                  NaN
# 99            NaN     NaN          NaN              NaN                  NaN
#
#    nearest_qid  nearest_distance 2nd_nearest_distance
# 0     Q3747399       6050.595665          6645.370926
# 1     Q3747399       2927.877099          3765.661694
# 2     Q3747399       2763.708809          3620.838026
# 3     Q3747399       1729.133230          2612.556528
# 4     Q3747439       1739.133915          1895.744243
# ..         ...               ...                  ...
# 95    Q1227084        295.652129           300.123782
# 96     Q857540        778.610155           849.481370
# 97    Q3747378       1056.359741          1395.008816
# 98    Q3747378        862.456277          1204.654015
# 99    Q3747378        724.187013          1156.443075
#
# [100 rows x 77 columns]

# %% [markdown]
# ### Find out what information already exists for the nearest fountains

# %%
# does nearest have label in german?
df['nearest_has_label_de'] = (query_result.iloc[nearest_idx]['place'].apply(lambda p:p[3:]) != query_result.iloc[nearest_idx]['placeLabel']).tolist()

# does nearest have date?
df['nearest_has_date'] = query_result.iloc[nearest_idx]['date'].apply(lambda d:d is not None).tolist()

# does nearest have operator?
df['nearest_has_operator'] = query_result.iloc[nearest_idx]['operator'].apply(lambda id:id is not None).tolist()

# does nearest have catalog code?
df['nearest_has_code'] = query_result.iloc[nearest_idx]['catalog_code'].apply(lambda id:id is not None).tolist()

# does nearest have water type?
df['nearest_has_water_type'] = query_result.iloc[nearest_idx]['water_supply_type'].apply(lambda id:id is not None).tolist()

# %% [markdown]
# ### Decide on whether nearest fountain should be considered a match

# %%
# The nearest fountain is a match if: 
# - no further than x m away
# - 2nd nearest fountain at nearest least ratio_min further away than the nearest fountain
def validate_proposal(qid, d1, d2, dmax=10, ratio_min=0.5):
    
    if d1 == 0 or (d1<=dmax and d2/d1-1 >= ratio_min):
        return 'match'
    elif d1<=dmax and d2/d1-1 < ratio_min:
        return 'unclear'
    else:
        print("Q-# "+qid+"\td1 "+str(d1)+"\td2 "+str(d2))
        return 'no match'
    
for index, row in df.iterrows():
    df.loc[index, 'match_found'] = validate_proposal(
        row['nearest_qid'], 
        row['nearest_distance'], 
        row['2nd_nearest_distance'],
        dmax=15
    )
dffinal = df.drop(columns=['nearest_distance', '2nd_nearest_distance'])
# Out:
# Q-# Q3747399	d1 6050.595665472956	d2 6645.370926107748
# Q-# Q3747399	d1 2927.877099271093	d2 3765.6616937942076
# Q-# Q3747399	d1 2763.7088094028068	d2 3620.838025695476
# Q-# Q3747399	d1 1729.133230091919	d2 2612.556528112138
# Q-# Q3747439	d1 1739.1339154385607	d2 1895.7442430742722
# Q-# Q3747439	d1 2060.63955208273	d2 2158.642702567936
# Q-# Q7489878	d1 509.65950843993915	d2 683.2036843705455
# Q-# Q74574057	d1 893.9491792650444	d2 1116.0454057674542
# Q-# Q3747378	d1 1004.3358321320073	d2 1103.2445450044297
# Q-# Q3747378	d1 762.6829404459017	d2 776.3531453657797
# Q-# Q3747378	d1 772.1528659300075	d2 780.1462213885712
# Q-# Q3747439	d1 465.26849091468034	d2 939.219047380278
# Q-# Q3747439	d1 461.37868195931287	d2 934.2749619591492
# Q-# Q3747439	d1 300.1468141026485	d2 960.1098778500419
# Q-# Q3747443	d1 124.12821975323716	d2 528.8911228977391
# Q-# Q3747443	d1 16.26333372481265	d2 522.412253708795
# Q-# Q3747443	d1 343.14870038838325	d2 375.2712475047008
# Q-# Q3747388	d1 3268.845123603653	d2 3498.396092621199
# Q-# Q3747388	d1 3212.9022729054627	d2 3451.209246290935
# Q-# Q3747399	d1 6286.938334838236	d2 6636.4370777485865
# Q-# Q3747439	d1 645.1685299876183	d2 886.7903903422426
# Q-# Q3747439	d1 657.2458992412647	d2 880.8783103748876
# Q-# Q3747439	d1 436.7991217821536	d2 947.1981952821986
# Q-# Q3747443	d1 296.4988944891108	d2 427.70707673788786
# Q-# Q3747439	d1 174.44727176961334	d2 608.2642343564864
# Q-# Q3747399	d1 1964.7255234392003	d2 2182.6860740263055
# Q-# Q74574057	d1 1020.527589390476	d2 2111.0701425695297
# Q-# Q74574057	d1 1060.9787042669498	d2 2259.8455677007
# Q-# Q74574057	d1 1125.9331956682893	d2 2395.1517263390188
# Q-# Q74574057	d1 1951.042337688054	d2 3317.2774633439735
# Q-# Q74574057	d1 754.3472459182717	d2 1895.0921354267846
# Q-# Q74574057	d1 1634.0850247003991	d2 3089.654581666644
# Q-# Q56256300	d1 74.86742298536585	d2 356.82622363238113
# Q-# Q56256300	d1 217.12314922176938	d2 233.20577206602388
# Q-# Q3747440	d1 158.0795865682326	d2 171.04687884390174
# Q-# Q56256300	d1 274.4469946756053	d2 298.30453251019213
# Q-# Q56256300	d1 224.62664505462283	d2 399.29935301982135
# Q-# Q56256300	d1 156.92106938377546	d2 421.74835971791094
# Q-# Q56256300	d1 391.812915232768	d2 586.182769612705
# Q-# Q3747399	d1 6303.310723828466	d2 6703.739530358005
# Q-# Q3747399	d1 3040.915656633662	d2 3783.311361679926
# Q-# Q3747399	d1 1774.2345834737564	d2 2239.103048228911
# Q-# Q185382	d1 42.627428821445214	d2 361.3998140445478
# Q-# Q1227084	d1 274.52640559447883	d2 511.70101839566547
# Q-# Q1227084	d1 332.53691111892283	d2 437.53919752949867
# Q-# Q1714672	d1 292.85480626168794	d2 372.21201779745394
# Q-# Q3747399	d1 1899.6571838823347	d2 2458.6613398357076
# Q-# Q74574057	d1 1311.8212776022135	d2 1384.804975595273
# Q-# Q3747378	d1 1317.5495095844803	d2 1571.2590092498644
# Q-# Q74574057	d1 1900.7128703555165	d2 1986.0853727498734
# Q-# Q3747378	d1 1724.3024105283826	d2 1764.4287251657192
# Q-# Q3747378	d1 1339.4028017045644	d2 1364.0023546728723
# Q-# Q7489878	d1 439.5184211608677	d2 561.4562454433542
# Q-# Q74574057	d1 1490.737585773265	d2 2840.6970442487127
# Q-# Q74574057	d1 2049.9361611739605	d2 3535.3588054478796
# Q-# Q74574057	d1 2734.147897372217	d2 4295.599523205197
# Q-# Q74574057	d1 2783.722749976019	d2 4145.174303594962
# Q-# Q29582887	d1 434.2802624678435	d2 541.4078226198711
# Q-# Q3747399	d1 179.6364744871192	d2 1053.5707189446794
# Q-# Q29582887	d1 616.077443166641	d2 851.1987816721661
# Q-# Q1435809	d1 229.44066437774197	d2 600.0911776800762
# Q-# Q3747364	d1 195.59420164569988	d2 258.2619120174822
# Q-# Q3747465	d1 171.9686036959621	d2 275.04515526861206
# Q-# Q3747399	d1 2595.910277812773	d2 3371.4906524633457
# Q-# Q7489878	d1 914.0172695560493	d2 1017.1121721401068
# Q-# Q3747378	d1 1585.060518682363	d2 1728.4964104730677
# Q-# Q3747378	d1 1849.3200803150007	d2 1922.78384100348
# Q-# Q3747402	d1 2291.8337248153434	d2 3011.678647924096
# Q-# Q3747402	d1 2135.219613729483	d2 2983.8662036706974
# Q-# Q3747399	d1 2302.2378860398703	d2 3072.1071271236065
# Q-# Q3747399	d1 2216.069699714928	d2 3044.407136424452
# Q-# Q3747399	d1 630.0510493345935	d2 1344.3088224293394
# Q-# Q3747399	d1 148.2667193885858	d2 1032.3259903220542
# Q-# Q3747399	d1 43.3435521779413	d2 955.7960254764307
# Q-# Q3747399	d1 26.538958360876247	d2 952.5606183041101
# Q-# Q74574057	d1 4958.094672236663	d2 6481.433987328883
# Q-# Q74574057	d1 6154.526333171731	d2 7652.918001669038
# Q-# Q3747443	d1 126.88868816242447	d2 532.9354100295656
# Q-# Q3747399	d1 5487.8176266064565	d2 6232.559228084178
# Q-# Q3747399	d1 2287.082723039724	d2 2553.2902653713695
# Q-# Q3747399	d1 2421.6869474448745	d2 2562.8935365143957
# Q-# Q3747399	d1 2626.3656379027234	d2 2671.3849324591993
# Q-# Q3747388	d1 2677.428391079267	d2 2756.2957300152307
# Q-# Q3747388	d1 2712.429345613073	d2 2848.589407009476
# Q-# Q3747399	d1 2946.647621667771	d2 3799.134632560715
# Q-# Q3747399	d1 2958.6499729873353	d2 3769.7658640025325
# Q-# Q3747399	d1 1737.1340256259102	d2 2260.5933526958643
# Q-# Q3747399	d1 1790.2765846832297	d2 2319.573853426282
# Q-# Q3747399	d1 2073.03735887527	d2 2440.7794544011017
# Q-# Q3747399	d1 2171.9545616721493	d2 2456.884138774197
# Q-# Q3747378	d1 1255.3709549648156	d2 1416.4103100554205
# Q-# Q3747399	d1 4321.494287399244	d2 4531.710419008789
# Q-# Q1234446	d1 382.30241753728234	d2 677.4965536550935
# Q-# Q18379990	d1 599.8453955758266	d2 608.4638101520362
# Q-# Q185382	d1 203.1548832035574	d2 312.2052751797417
# Q-# Q1227084	d1 295.65212882785585	d2 300.12378199269324
# Q-# Q857540	d1 778.6101553017086	d2 849.4813704238397
# Q-# Q3747378	d1 1056.3597408406588	d2 1395.0088161189958
# Q-# Q3747378	d1 862.4562772119631	d2 1204.6540148086335
# Q-# Q3747378	d1 724.187013170451	d2 1156.4430751657012
# Q-# Q3747402	d1 1949.3023519072406	d2 3368.2330148389487
# Q-# Q3747402	d1 3048.2716617150104	d2 4462.282829393802
# Q-# Q3747399	d1 203.67867611421661	d2 800.8265588072812
# Q-# Q3747399	d1 33.75480557380306	d2 905.586220661676
# Q-# Q18379990	d1 409.8985269494056	d2 411.20291450408035
# Q-# Q3747399	d1 328.3278640256937	d2 701.5403713803988
# Q-# Q3747439	d1 598.9430783197537	d2 801.3007236198691
# Q-# Q3747439	d1 611.6794042942965	d2 794.0046500372613
# Q-# Q3747443	d1 268.8844183769661	d2 678.214420199593
# Q-# Q3747439	d1 293.1926632680352	d2 692.572499831129
# Q-# Q3747369	d1 203.9620307931628	d2 278.01791881010155
# Q-# Q3747378	d1 606.2586192753938	d2 662.2315945986877
# Q-# Q74574057	d1 1403.6427638002554	d2 1600.2056780657538
# Q-# Q3747399	d1 3294.3970981675034	d2 3637.24834846559
# Q-# Q3747399	d1 4643.549880874284	d2 5355.641070829095
# Q-# Q3747399	d1 1475.9682158373996	d2 2376.7511051165475
# Q-# Q3747399	d1 1373.5381391024398	d2 2270.5092167965636
# Q-# Q3747399	d1 1375.4969246988937	d2 2277.168368138108
# Q-# Q3747378	d1 412.7835118853552	d2 807.0538634489862
# Q-# Q3747369	d1 315.1421652115174	d2 343.4861676589231
# Q-# Q1234446	d1 1861.9107198735758	d2 1878.262711064062
# Q-# Q3747399	d1 5151.409062321419	d2 5988.977952542872
# Q-# Q74574057	d1 562.0213340342392	d2 1156.8143162374802
# Q-# Q74574057	d1 567.3920051445745	d2 1159.897393150959
# Q-# Q74574057	d1 602.9494814135727	d2 1132.9589810099835
# Q-# Q74574057	d1 565.8746233197123	d2 1180.4676265340695
# Q-# Q74574057	d1 582.4843462844788	d2 1180.6005229641708
# Q-# Q3747388	d1 1613.3765087843913	d2 1709.1421138490034
# Q-# Q74574057	d1 726.4493854012068	d2 1990.3629790083587
# Q-# Q74574057	d1 614.4426131452943	d2 1601.933003855291
# Q-# Q3747378	d1 374.1963736781037	d2 1364.5976474292577
# Q-# Q3747378	d1 2036.5804917347648	d2 2055.615840185984
# Q-# Q74574057	d1 2302.224599302833	d2 2358.467803612504
# Q-# Q3747388	d1 675.4967678034582	d2 712.6283729586446
# Q-# Q3747399	d1 2403.04693814228	d2 2424.485242710383
# Q-# Q3747399	d1 2625.9173809304575	d2 3295.5093673100114
# Q-# Q7489878	d1 347.3126362506668	d2 439.3431737545952
# Q-# Q1217302	d1 323.4026349294924	d2 397.8509884579717
# Q-# Q3747439	d1 606.3605922535435	d2 1116.360809396664
# Q-# Q3747388	d1 2738.5294217921005	d2 2976.374903820379
# Q-# Q3747388	d1 2701.2617329751774	d2 2934.6460989570205
# Q-# Q3747388	d1 2046.5525097313941	d2 2131.513698378771
# Q-# Q3747388	d1 1421.1408387006913	d2 1520.980796411776
# Q-# Q3747439	d1 415.7443787064934	d2 619.7643035306049
# Q-# Q3747378	d1 514.2417344103749	d2 791.02460244812
# Q-# Q3747378	d1 689.3036972102251	d2 1363.0399330390871
# Q-# Q3747378	d1 1151.4956606717772	d2 1346.0175021896503
# Q-# Q3747364	d1 209.44951525632723	d2 230.0083222304869
# Q-# Q3747440	d1 196.25135382392415	d2 289.2855962794401
# Q-# Q3747465	d1 204.57003767648555	d2 239.47458551193762
# Q-# Q3747378	d1 1378.6362692123732	d2 1579.2349318714078
# Q-# Q3747378	d1 1469.8573921476018	d2 1622.1915207289505
# Q-# Q3747402	d1 983.6463066219558	d2 1188.7152637504762
# Q-# Q3747402	d1 688.0151386500495	d2 1408.1188484294335
# Q-# Q3747402	d1 604.8208029162695	d2 1542.5610882226558
# Q-# Q857540	d1 1186.855061913647	d2 1198.9586084081634
# Q-# Q857540	d1 1198.5260819871287	d2 1274.0611290144016
# Q-# Q857540	d1 1191.950327421354	d2 1271.6027840786371
# Q-# Q983774	d1 1059.5158063893448	d2 1077.7219032579444
# Q-# Q983774	d1 1068.7095638825642	d2 1080.7954863855653
# Q-# Q1085738	d1 801.2455016199145	d2 810.3157748475412
# Q-# Q1085738	d1 790.6598624303776	d2 800.9192660403681
# Q-# Q1085738	d1 663.093997735081	d2 724.8856529313101
# Q-# Q1085738	d1 85.84319261722445	d2 299.787392847002
# Q-# Q3747399	d1 2684.9832649182467	d2 3535.111892719691
# Q-# Q3747399	d1 3008.0184571641967	d2 3862.891178866476
# Q-# Q936296	d1 208.75505706028426	d2 330.4726085763334
# Q-# Q3747378	d1 1513.3244072399457	d2 1652.990414895357
# Q-# Q3747402	d1 3167.2585519612812	d2 3276.9931448993466
# Q-# Q3747402	d1 2912.872656321022	d2 3074.5164719006925
# Q-# Q3747402	d1 1807.54289936686	d2 2511.927725141852
# Q-# Q3747402	d1 1753.1918959817629	d2 2386.5595401655787
# Q-# Q3747402	d1 1534.0893344922138	d2 1542.8102677178229
# Q-# Q3747402	d1 2316.497541377431	d2 3847.1226257702947
# Q-# Q1435824	d1 126.83135522554747	d2 138.86243506266726
# Q-# Q74574057	d1 2681.4614158269837	d2 3849.7326199987133
# Q-# Q3747399	d1 2673.7622886335566	d2 3522.9045869045494
# Q-# Q3747399	d1 350.59324052425	d2 1240.2764860846742
# Q-# Q74574057	d1 1439.748471900917	d2 2632.2864450483776
# Q-# Q74574057	d1 1844.2979879101636	d2 3099.577568496743
# Q-# Q74574057	d1 1438.3628509504288	d2 1795.640116738921
# Q-# Q74574057	d1 3626.47790271389	d2 5264.536579610539
# Q-# Q74574057	d1 3647.803661179442	d2 5313.778453281661
# Q-# Q74574057	d1 1790.9683516478476	d2 3495.638594223772
# Q-# Q3747400	d1 871.9419623250923	d2 889.4571061860222
# Q-# Q3747378	d1 1272.6810360554412	d2 1407.0871526299395
# Q-# Q3747399	d1 2420.3137172267484	d2 3286.3239770421137
# Q-# Q3747399	d1 2040.9700309694363	d2 2918.0647724612686
# Q-# Q3747399	d1 2908.543140561035	d2 3701.5169837487733
# Q-# Q74574057	d1 4810.625126417127	d2 6457.632254713836
# Q-# Q74574057	d1 4026.949845997117	d2 5624.568253543453
# Q-# Q74574057	d1 4227.398602126797	d2 5893.430454048746
# Q-# Q74574057	d1 1201.3697382312034	d2 2775.6251079902677
# Q-# Q3747378	d1 1134.12803223091	d2 1418.0088407668075
# Q-# Q3747439	d1 1097.4359453232878	d2 1388.2783465970654
# Q-# Q74574057	d1 3258.145035022648	d2 4248.123918025154
# Q-# Q3747399	d1 3360.362280128461	d2 4093.691647335856
# Q-# Q3747399	d1 3732.555580780321	d2 4371.083602404867
# Q-# Q3747399	d1 3863.136533479628	d2 4494.114068356454
# Q-# Q3747399	d1 3525.3845792034335	d2 4139.164217382995
# Q-# Q74574057	d1 5637.624751702487	d2 6948.405698015429
# Q-# Q3747399	d1 4290.0224435602495	d2 4746.016293978359
# Q-# Q3747399	d1 4384.499407121486	d2 4801.971009872038
# Q-# Q3747399	d1 4560.01750970872	d2 4875.548562298573
# Q-# Q3747399	d1 4515.6629187218305	d2 4832.343740852831
# Q-# Q3747399	d1 4447.699566721638	d2 4814.915615001855
# Q-# Q3747399	d1 4420.815886645879	d2 4846.889306660766
# Q-# Q3747399	d1 4574.366745313418	d2 4959.513616984284
# Q-# Q74574057	d1 5123.4671209685575	d2 5489.6134233006205
# Q-# Q74574057	d1 4444.155921171953	d2 5010.608769876672
# Q-# Q74574057	d1 3388.075953696482	d2 5087.382364698026
# Q-# Q74574057	d1 8763.009508610654	d2 10428.71022265078
# Q-# Q74574057	d1 8437.551694879958	d2 10100.57567460093
# Q-# Q3747439	d1 669.3239064046525	d2 890.8431842396833
# Q-# Q3747378	d1 1045.6289920078632	d2 1328.0307986935738
# Q-# Q74574057	d1 2435.474624725843	d2 3686.7066305330754
# Q-# Q74574057	d1 2359.879207255961	d2 3618.8089662764164
# Q-# Q3747442	d1 123.31974617825855	d2 450.71096377943314
# Q-# Q18379990	d1 571.5420803501823	d2 656.0994723464371
# Q-# Q3747399	d1 1520.1772813560349	d2 1992.3129990775312
# Q-# Q3747399	d1 2218.8696915997175	d2 2912.8665253609793
# Q-# Q3747399	d1 2194.5320734455204	d2 2648.9763855943324
# Q-# Q3747378	d1 922.4538541000771	d2 1002.8752709700132
# Q-# Q3747378	d1 558.6488563439218	d2 1171.9420755298959
# Q-# Q3747378	d1 110.55255191409528	d2 903.3300189470114
# Q-# Q3747443	d1 351.97418883589177	d2 391.98740850909337
# Q-# Q1924755	d1 401.46370769634643	d2 406.2521005930794
# Q-# Q3747443	d1 191.38979616112275	d2 349.4555036368518
# Q-# Q1924755	d1 154.2072476178941	d2 382.67543674980936
# Q-# Q1234446	d1 613.9955792725375	d2 847.8102963517549
# Q-# Q3747399	d1 699.5227601581726	d2 794.3078612752321
# Q-# Q3747399	d1 439.77289719916627	d2 1331.4028634415492
# Q-# Q3747399	d1 837.1439959571013	d2 1753.4270358413794
# Q-# Q1234446	d1 837.0538633503022	d2 1056.9094632267436
# Q-# Q1234446	d1 923.2830879585024	d2 955.7399416793121
# Q-# Q1234446	d1 497.37610127824524	d2 1026.8052228914312
# Q-# Q1234446	d1 281.4716955819019	d2 810.5839209768894
# Q-# Q3747399	d1 2299.043475924254	d2 2332.3033766069107
# Q-# Q3747421	d1 106.31638671770584	d2 251.3731089115183
# Q-# Q29582887	d1 282.7635698341497	d2 521.6544661043825
# Q-# Q3747437	d1 269.9186995750099	d2 327.3490219118119
# Q-# Q74574057	d1 919.9500829853349	d2 944.1916438194575
# Q-# Q74574057	d1 879.7315483982785	d2 1012.8992463337195
# Q-# Q3747378	d1 662.070552969001	d2 1085.148970375882
# Q-# Q3747378	d1 455.9787526986064	d2 1256.4572546575603
# Q-# Q5465137	d1 282.8228327006642	d2 441.6541584725299
# Q-# Q3747402	d1 728.6961440817146	d2 1272.3456781981213
# Q-# Q3747378	d1 1041.4414011283293	d2 1426.967571827024
# Q-# Q3747378	d1 785.4144145761351	d2 1379.199682118059
# Q-# Q3747402	d1 543.4482387679265	d2 1737.705976548954
# Q-# Q3747402	d1 1093.4868566898056	d2 1348.807704084475
# Q-# Q74574057	d1 1400.5932206600867	d2 1481.010502685473
# Q-# Q74574057	d1 1481.6297751354418	d2 2702.6511538440013
# Q-# Q3747402	d1 1183.5567318485387	d2 1472.9479549799485
# Q-# Q3747402	d1 1803.9960821575005	d2 1942.0941499575406
# Q-# Q3747402	d1 1339.3025406691845	d2 1753.670431379723
# Q-# Q3747439	d1 2145.1359622075584	d2 2284.6455289045607
# Q-# Q3747439	d1 1702.841615113112	d2 1811.4918831823009
# Q-# Q3747388	d1 188.65970361745534	d2 627.1380014136595
# Q-# Q3747388	d1 167.75067151077386	d2 704.433607661253
# Q-# Q3747388	d1 304.71768443496234	d2 502.78624722660396
# Q-# Q3747402	d1 635.0517853575956	d2 1201.7292229473794
# Q-# Q3747402	d1 775.4925840349886	d2 1120.2996516589778
# Q-# Q3747399	d1 2004.1542017961658	d2 2673.9196277722713
# Q-# Q3747388	d1 2176.3222997318153	d2 2316.3776241529176
# Q-# Q3747388	d1 2185.699109614448	d2 2305.6533596900026
# Q-# Q3747388	d1 2046.2514491862828	d2 2269.6677006041773
# Q-# Q3747388	d1 2313.500630807966	d2 2424.027016710053
# Q-# Q3747388	d1 2967.777132267946	d2 3206.178317368415
# Q-# Q3747388	d1 3387.780982020091	d2 3620.8453710900603
# Q-# Q3747399	d1 3994.060742543068	d2 4266.84907255433
# Q-# Q3747399	d1 4066.825227082342	d2 4337.387104618042
# Q-# Q3747378	d1 803.0025624038227	d2 1039.1997252987087
# Q-# Q3747402	d1 1075.1532573110546	d2 1631.9149786117023
# Q-# Q3747378	d1 1347.2837685621662	d2 1595.0395768935186
# Q-# Q3747439	d1 1281.5833037996345	d2 1477.6024541766103
# Q-# Q74574057	d1 3134.089480346904	d2 3295.56192653218
# Q-# Q74574057	d1 1012.5835028653557	d2 2072.3245732977407
# Q-# Q74574057	d1 661.9188400572385	d2 1189.2627436225675
# Q-# Q3747378	d1 716.4495162282414	d2 1245.5297977065763
# Q-# Q3747378	d1 1258.9638629178091	d2 1448.6926830482907
# Q-# Q3747388	d1 2490.1734121231034	d2 2602.1315489147837
# Q-# Q3747399	d1 3327.942279760048	d2 3697.752097366475
# Q-# Q74574057	d1 1158.377356843926	d2 1268.31576075828
# Q-# Q3747378	d1 394.367249782931	d2 1271.9602079650078
# Q-# Q74574057	d1 1401.0441075551068	d2 2453.8030763830275
# Q-# Q74574057	d1 372.5584424826092	d2 1405.853865606119
# Q-# Q74574057	d1 1059.513530913392	d2 1847.2729895972643
# Q-# Q3747364	d1 717.774994250493	d2 892.2998611270237
# Q-# Q3747378	d1 516.398038015515	d2 752.054805255719
# Q-# Q74574057	d1 872.2638600200494	d2 2557.8729336003057
# Q-# Q74574057	d1 3744.327945413889	d2 5424.819586498409
# Q-# Q74574057	d1 819.8311180027508	d2 1644.714979530448
# Q-# Q74574057	d1 832.6319134917895	d2 1743.7505121591125
# Q-# Q74574057	d1 789.1193406451998	d2 2061.3743960207057
# Q-# Q74574057	d1 779.3647823967315	d2 2116.971463961671
# Q-# Q74574057	d1 1048.5116478180832	d2 2155.8894019993236
# Q-# Q74574057	d1 1328.961135798286	d2 2269.2069574597826
# Q-# Q74574057	d1 1274.1329599418998	d2 2201.4986719400044
# Q-# Q3747429	d1 296.58110728552805	d2 342.5578917899654
# Q-# Q3747465	d1 199.15803221874432	d2 284.1026627471357
# Q-# Q3747437	d1 158.71279593617285	d2 338.90475988789797
# Q-# Q936296	d1 130.42838547294906	d2 268.19426669625574
# Q-# Q3747437	d1 107.96723106397278	d2 229.25492647899597
# Q-# Q3747444	d1 40.21997511093612	d2 128.69700853610138
# Q-# Q3747388	d1 422.00508340098384	d2 850.1894771686138
# Q-# Q3747388	d1 1029.9311020071266	d2 1269.823517327749
# Q-# Q3747388	d1 1145.592380842534	d2 1263.6537375244325
# Q-# Q3747443	d1 221.28157411659785	d2 633.8691147195831
# Q-# Q3747399	d1 2130.5710302680586	d2 2330.4706304097285
# Q-# Q3747399	d1 3465.255967186838	d2 3638.50001778883
# Q-# Q74574057	d1 1048.9749578249562	d2 2754.5127703157177
# Q-# Q74574057	d1 335.22835344892343	d2 2022.6105190274145
# Q-# Q3747439	d1 608.393514615665	d2 710.0363132966156
# Q-# Q3747388	d1 2537.385172935263	d2 2771.4613019568396
# Q-# Q74574057	d1 6062.716158887654	d2 7548.436843356177
# Q-# Q74574057	d1 6100.2898121764965	d2 7607.593979948096
# Q-# Q3747378	d1 1214.2957663964748	d2 1338.9465582404496
# Q-# Q74574057	d1 3185.6346596117883	d2 4534.951154991187
# Q-# Q74574057	d1 8460.88777920617	d2 9927.527124231887
# Q-# Q74574057	d1 10307.341648942687	d2 11825.375151896002
# Q-# Q3747399	d1 4496.267117863556	d2 5189.292697810357
# Q-# Q3747399	d1 3437.7578341202725	d2 3984.3142357007387
# Q-# Q3747399	d1 3569.204047394773	d2 4071.0338496792447
# Q-# Q3747399	d1 2995.1094957091045	d2 3389.3252194605716
# Q-# Q3747399	d1 2687.719186042026	d2 3530.3245597020373
# Q-# Q3747378	d1 1398.7966635114235	d2 1505.4660526589978
# Q-# Q7489878	d1 565.205961289112	d2 686.3679641837143
# Q-# Q3747402	d1 238.5755393289491	d2 1567.6726877007613
# Q-# Q3747378	d1 1351.2647901663645	d2 1559.2554032461808
# Q-# Q74574057	d1 4109.21360875845	d2 5107.162243121869
# Q-# Q74574057	d1 4251.8054843104	d2 5398.802256507593
# Q-# Q74574057	d1 4559.812057551398	d2 5712.327858401766
# Q-# Q74574057	d1 5165.425483103824	d2 6407.351651222928
# Q-# Q74574057	d1 5376.691682682072	d2 6633.842972301759
# Q-# Q74574057	d1 5490.524350796227	d2 6753.40001884811
# Q-# Q74574057	d1 5579.654689755218	d2 6975.09661714729
# Q-# Q74574057	d1 5566.620963271456	d2 6978.215322563416
# Q-# Q74574057	d1 5091.011153203333	d2 6553.405464238484
# Q-# Q74574057	d1 4496.190464603244	d2 6140.246563505626
# Q-# Q74574057	d1 3472.3529744831867	d2 5176.174408316042
# Q-# Q74574057	d1 3441.36677067464	d2 5133.982310442985
# Q-# Q74574057	d1 2539.4990294123445	d2 4211.843595575021
# Q-# Q74574057	d1 2074.252531619609	d2 3751.7424479883593
# Q-# Q3747402	d1 556.188609647947	d2 1409.019365066866
# Q-# Q74574057	d1 4093.244554139302	d2 4811.356229973714
# Q-# Q3747378	d1 521.0573191767216	d2 814.1420514870031
# Q-# Q3747378	d1 778.8100828009617	d2 1093.9228097309424
# Q-# Q3747388	d1 2583.474623132248	d2 2752.3232153044896
# Q-# Q74574057	d1 1662.3694374993452	d2 3031.5338323683636
# Q-# Q74574057	d1 1683.4578319716697	d2 3077.7514767773755
# Q-# Q74574057	d1 1694.4720336063642	d2 3185.348686712821
# Q-# Q3747399	d1 3776.674711906706	d2 4416.6680910969335
# Q-# Q3747399	d1 3818.2373795231097	d2 4431.203268739229
# Q-# Q3747399	d1 4063.7936792984274	d2 4703.985377686101
# Q-# Q74574057	d1 2127.233924345109	d2 3822.1848539737202
# Q-# Q74574057	d1 2210.5700550670554	d2 3836.2901680475125
# Q-# Q74574057	d1 2434.44053229368	d2 4119.300838708206
# Q-# Q74574057	d1 2095.8080661528024	d2 3644.2365147157766
# Q-# Q3747402	d1 4122.166875766264	d2 5609.90425008747
# Q-# Q74574057	d1 4720.29339408817	d2 6386.521139988238
# Q-# Q74574057	d1 1450.8217983049103	d2 3130.9265360724617
# Q-# Q74574057	d1 1779.2213565698403	d2 3383.8584444348653
# Q-# Q56256300	d1 355.9892533031371	d2 538.5027687382324
# Q-# Q3747439	d1 591.9991934492607	d2 723.28610516794
# Q-# Q74574057	d1 445.4252896164873	d2 1834.1000402475431
# Q-# Q74574057	d1 726.3552882385328	d2 2183.4718854586226
# Q-# Q74574057	d1 2546.3744175685056	d2 4230.056944516988
# Q-# Q74574057	d1 1225.015676703325	d2 1852.5016255528094
# Q-# Q3747400	d1 1971.642818692314	d2 1989.4188888193996
# Q-# Q3747370	d1 1887.408083192342	d2 2103.230179594287
# Q-# Q5465137	d1 1192.7278759503279	d2 1507.6353597933596
# Q-# Q3902380	d1 571.9069636161408	d2 581.3121249973308
# Q-# Q3747369	d1 326.44800865646215	d2 431.4066561792859
# Q-# Q3747399	d1 1045.7677295366186	d2 1221.236616043356
# Q-# Q3747388	d1 3586.596173974891	d2 3625.940923031223
# Q-# Q3747388	d1 820.2249215404607	d2 829.7806188377117
# Q-# Q3747439	d1 409.3744457736582	d2 859.1605082062154
# Q-# Q74574057	d1 814.0878555461837	d2 979.3916869871487
# Q-# Q74574057	d1 932.9230200852187	d2 1013.3199867473116
# Q-# Q74574057	d1 930.6387181653677	d2 1002.2285469332516
# Q-# Q3747378	d1 945.0201144073304	d2 1028.6785748776115
# Q-# Q74574057	d1 473.4254453403009	d2 1535.9066458034483
# Q-# Q74574057	d1 3904.772100722861	d2 5577.201716590983
# Q-# Q3747402	d1 2387.822825107336	d2 3432.3951896633803
# Q-# Q74574057	d1 5982.94955741472	d2 6913.061631811064
# Q-# Q74574057	d1 107.0002093877011	d2 1689.827118843527
# Q-# Q74574057	d1 592.9730301722292	d2 1859.562324361271
# Q-# Q74574057	d1 1073.2143625856781	d2 2647.4106929422637
# Q-# Q74574057	d1 1041.0777843331737	d2 2531.355164780032
# Q-# Q3747388	d1 3045.8886343115237	d2 3286.9674914624447
# Q-# Q3747388	d1 2854.970338047426	d2 3000.6257379593867
# Q-# Q3747388	d1 3121.239938676547	d2 3164.3290150889984
# Q-# Q3747388	d1 3036.7909039749557	d2 3180.6158940489977
# Q-# Q3747388	d1 3114.096351854425	d2 3351.738684669574
# Q-# Q3747388	d1 2591.885074938885	d2 2871.3239040719563
# Q-# Q3747402	d1 1983.1907454140587	d2 2522.712584720483
# Q-# Q3747399	d1 2748.8791773218077	d2 3482.7727243936324
# Q-# Q1759793	d1 17.180928499889124	d2 109.60460028404832
# Q-# Q1759793	d1 165.64639860516425	d2 238.28737097148243
# Q-# Q74574057	d1 3668.080288169993	d2 5278.743748287169
# Q-# Q74574057	d1 3832.889716209519	d2 5437.939819428721
# Q-# Q74574057	d1 2749.753927572525	d2 4164.360847411091
# Q-# Q74574057	d1 7494.964251020467	d2 8927.177356278251
# Q-# Q74574057	d1 7395.478141905039	d2 8430.744124651163
# Q-# Q1435809	d1 7066.124745216508	d2 7286.426106143907
# Q-# Q1435809	d1 7059.1851546734315	d2 7227.486224016967
# Q-# Q1435809	d1 6939.499954136823	d2 7074.157044826393
# Q-# Q1435809	d1 6618.873350563839	d2 6839.893435320224
# Q-# Q74574057	d1 7566.0039505053965	d2 7685.420597546085
# Q-# Q1435809	d1 6700.835795883652	d2 6843.79981849631
# Q-# Q1435809	d1 6766.611815852107	d2 6921.968971378003
# Q-# Q3747399	d1 6725.638778561682	d2 7055.124807348871
# Q-# Q12042914	d1 783.753162814599	d2 1004.0667480423599
# Q-# Q74574057	d1 5503.874170618687	d2 7159.325317139664
# Q-# Q3747402	d1 1094.463616919921	d2 2209.5403520504797
# Q-# Q3747402	d1 1104.5344673177763	d2 2401.5704747446543
# Q-# Q3747402	d1 2699.245673798006	d2 4235.0041218997085
# Q-# Q3747402	d1 3191.7768012064107	d2 4681.916750192691
# Q-# Q3747402	d1 3482.8262137613565	d2 4820.269123882351
# Q-# Q3747439	d1 949.2559089798929	d2 1098.7093128117638
# Q-# Q3747439	d1 837.7202696497645	d2 948.5639539264489
# Q-# Q3747399	d1 2382.383728936421	d2 2752.8286842923576
# Q-# Q3747399	d1 2105.240033718312	d2 2895.3738361662936
# Q-# Q3747402	d1 2837.0048054911304	d2 2938.592927249994
# Q-# Q3747378	d1 982.1084344468686	d2 1295.7878677577107
# Q-# Q3747388	d1 255.1720062623349	d2 585.610538428976
# Q-# Q3747388	d1 354.31657998575645	d2 498.13459128465524
# Q-# Q1234446	d1 1160.7671697296407	d2 1292.6684038895603
# Q-# Q74574057	d1 1928.5521794721744	d2 2243.925577750905
# Q-# Q74574057	d1 2599.8759644367115	d2 3088.856153267219
# Q-# Q3747444	d1 22.0489145596231	d2 147.37306902498113
# Q-# Q3747388	d1 859.6760276632426	d2 938.0932796692828
# Q-# Q3747378	d1 956.1164863193859	d2 1000.0539858522812
# Q-# Q74574057	d1 758.5951049350039	d2 1117.3004846098686
# Q-# Q18379990	d1 131.61929137196915	d2 136.84006912397604
# Q-# Q3747429	d1 109.46134543490332	d2 350.9363129267426
# Q-# Q74574057	d1 1310.401236182135	d2 2627.5996635683077
# Q-# Q3747364	d1 380.56243171504826	d2 555.9963191310479
# Q-# Q3747402	d1 1081.1459702695681	d2 1281.5059160368182
# Q-# Q3747402	d1 2380.1439986039686	d2 3702.014450188625
# Q-# Q3747402	d1 2299.9257633252414	d2 3591.0556269607887
# Q-# Q3747402	d1 2124.6437404020003	d2 3701.9665246931277
# Q-# Q3747402	d1 2763.5828272528797	d2 4200.634125874639
# Q-# Q3747402	d1 2854.626340710208	d2 4245.56409829012
# Q-# Q3747402	d1 4180.140822639084	d2 5620.284299482994
# Q-# Q74574057	d1 1889.0046526765225	d2 3361.0346535791145
# Q-# Q74574057	d1 4781.324090402252	d2 6446.337737468577
# Q-# Q3747399	d1 7334.4411250071	d2 7925.3115993763895
# Q-# Q74574057	d1 340.5331520429138	d2 1787.3271594798312
# Q-# Q3747399	d1 6977.919885270938	d2 7794.265676422333
# Q-# Q12042914	d1 786.3359615285365	d2 799.0386807014
# Q-# Q3747399	d1 3755.130217598251	d2 4309.185792087429
# Q-# Q3747399	d1 5771.395125813415	d2 6529.905975778603
# Q-# Q5465137	d1 871.0004674882478	d2 1058.3962263104397
# Q-# Q3747402	d1 3303.571116621535	d2 4359.185312854181
# Q-# Q3747402	d1 3440.86508522269	d2 4715.5932467169605
# Q-# Q3747402	d1 1908.8102103452268	d2 3406.9378884310117
# Q-# Q3747402	d1 887.815644926657	d2 2515.764274025957
# Q-# Q74574057	d1 5067.377135680266	d2 6758.472071534569
# Q-# Q74574057	d1 5766.875362936765	d2 7457.647698526263
# Q-# Q74574057	d1 5780.464133453533	d2 7469.532725044462
# Q-# Q74574057	d1 974.0135158405594	d2 1145.941265760593
# Q-# Q983774	d1 858.3550546544687	d2 899.667874828717
# Q-# Q5465137	d1 1496.8425614487187	d2 1708.7523851331337
# Q-# Q3747370	d1 1120.6447774665642	d2 1429.6306708300776
# Q-# Q3747370	d1 775.5218416603451	d2 1889.83360952649
# Q-# Q3747370	d1 985.9555873334825	d2 1738.0844165498347
# Q-# Q3747370	d1 896.7461869639613	d2 1791.371648535606
# Q-# Q3747402	d1 1126.7817819420736	d2 1345.5284031193098
# Q-# Q74574057	d1 2360.552769380032	d2 3923.2306302991396
# Q-# Q74574057	d1 2205.6260393307302	d2 3764.962100834083
# Q-# Q7489878	d1 88.42645884115588	d2 362.97346353224873
# Q-# Q74574057	d1 728.1848768780349	d2 2300.947647951278
# Q-# Q3747399	d1 2146.704297383434	d2 2745.0872700581485
# Q-# Q3747399	d1 2146.522772133315	d2 2705.4364297628777
# Q-# Q3747399	d1 2572.1724797667084	d2 3427.740135997349
# Q-# Q3747399	d1 3342.2582681299123	d2 4162.74109997058
# Q-# Q3747445	d1 109.11126536579245	d2 383.0440574772807
# Q-# Q3747388	d1 2003.3126381485565	d2 2055.5286407229964
# Q-# Q3747402	d1 8502.954342435129	d2 9044.799354715735
# Q-# Q74574057	d1 344.9690350614619	d2 1899.3538770317753
# Q-# Q3902380	d1 428.09941839807715	d2 432.2486791250741
# Q-# Q3902380	d1 251.06376816669027	d2 261.9464609519885
# Q-# Q3747429	d1 269.01949914534015	d2 395.98081803912396
# Q-# Q3747378	d1 432.4667959559733	d2 836.0425694278355
# Q-# Q3747402	d1 9048.06098105233	d2 9460.511432828182
# Q-# Q1435809	d1 3852.949106782867	d2 3878.3043457454078
# Q-# Q3747399	d1 4338.922842386863	d2 4342.251324345495
# Q-# Q3747402	d1 8973.856742104674	d2 9344.016516313266
# Q-# Q3747402	d1 9151.65560934018	d2 9285.636751796415
# Q-# Q3747467	d1 81.9687547886068	d2 444.8618225318973
# Q-# Q3747444	d1 237.26663392356016	d2 363.61490691352765
# Q-# Q185382	d1 232.719007110058	d2 325.90572938199233
# Q-# Q3747378	d1 375.5938548912154	d2 1277.9437599795624
# Q-# Q74574057	d1 637.7868207935447	d2 1940.372081581596
# Q-# Q74574057	d1 637.9935624753095	d2 2111.6762181571266
# Q-# Q3747399	d1 2047.5483875469083	d2 2067.465265011972
# Q-# Q1924755	d1 335.62101164072925	d2 485.33023745747346
# Q-# Q29582887	d1 375.78458582884366	d2 385.1397855960553
# Q-# Q3747399	d1 637.250343332922	d2 799.6124178701353
# Q-# Q3747399	d1 637.3304803079736	d2 804.1551284699902
# Q-# Q3747399	d1 385.2222423935718	d2 1131.9752339497084
# Q-# Q1234446	d1 1108.5195521218031	d2 1171.7623484863689
# Q-# Q3747444	d1 304.69641765086453	d2 427.0664564458201
# Q-# Q3747421	d1 300.2510370791026	d2 320.59815988749295
# Q-# Q74574057	d1 5149.535685628509	d2 6674.761309508061
# Q-# Q3747397	d1 178.16952801904208	d2 395.4476933787395
# Q-# Q1759793	d1 258.80365192682905	d2 266.0285924778234
# Q-# Q3747388	d1 476.4345782482046	d2 703.4085016864286
# Q-# Q3747378	d1 918.501118287398	d2 1189.4788600036948
# Q-# Q3747378	d1 884.3022438519997	d2 1050.8092630019075
# Q-# Q7489878	d1 713.9567287465185	d2 856.2760608965685
# Q-# Q3747399	d1 2844.7025711291385	d2 2973.410184317612
# Q-# Q74574057	d1 3316.157306901887	d2 5019.208344923677
# Q-# Q74574057	d1 3192.635710446619	d2 4898.6621120611
# Q-# Q3747402	d1 932.9260004134889	d2 1436.9059217786173
# Q-# Q3747402	d1 697.5864561029866	d2 1759.0625896460713
# Q-# Q74574057	d1 2551.6858134447334	d2 4213.820470280689
# Q-# Q3747402	d1 2049.821901833602	d2 3016.1224722916086
# Q-# Q3747402	d1 934.5409378721067	d2 2421.688776643234
# Q-# Q3747402	d1 1223.0578529346071	d2 2778.633384651787
# Q-# Q3747402	d1 1528.1278962639171	d2 2482.6296355231093
# Q-# Q3747402	d1 1101.9228137653213	d2 2361.841845789924
# Q-# Q3747402	d1 1782.963380750002	d2 2291.56670798874
# Q-# Q3747399	d1 1138.4884180709475	d2 1989.8484213053903
# Q-# Q3747402	d1 4539.026471054662	d2 5444.882289149096
# Q-# Q3747402	d1 4703.990426273726	d2 5446.836367055594
# Q-# Q3747402	d1 4362.961363640176	d2 4940.177681297878
# Q-# Q12042914	d1 922.1680070950238	d2 1206.4945317236595
# Q-# Q12042914	d1 665.3448367848323	d2 697.5565201733791
# Q-# Q1303855	d1 449.8143919426394	d2 663.4182349150956
# Q-# Q1303855	d1 194.79284256048695	d2 593.9320835645336
# Q-# Q1303855	d1 253.7116664852885	d2 663.8058382829563
# Q-# Q12042914	d1 417.1711824422413	d2 649.0332172298907
# Q-# Q12042914	d1 448.3992110741034	d2 791.0504543705929
# Q-# Q3747400	d1 1288.8859449583092	d2 1306.3728265393877
# Q-# Q12042914	d1 840.855482990305	d2 1221.5256743912387
# Q-# Q12042914	d1 703.8488077090838	d2 1115.1060146021966
# Q-# Q3747400	d1 1062.9574992753837	d2 1078.0018682408718
# Q-# Q1303855	d1 1660.5434708284881	d2 1668.58898102855
# Q-# Q12042914	d1 418.3015136373022	d2 498.30515120963514
# Q-# Q3747364	d1 321.9449402673939	d2 342.9540365950345
# Q-# Q3747421	d1 358.60539319897947	d2 493.3106292223207
# Q-# Q3747397	d1 181.55593279159265	d2 243.99453891024726
# Q-# Q29582887	d1 151.79171512205323	d2 242.86787233635405
# Q-# Q3747397	d1 131.01332532969124	d2 198.02979776661974
# Q-# Q29582887	d1 85.47599076543509	d2 353.2282957132787
# Q-# Q1435809	d1 966.3362328922904	d2 1067.672008994999
# Q-# Q1435809	d1 864.5178808584902	d2 958.811425957262
# Q-# Q1435809	d1 679.0688686403325	d2 922.4653390926138
# Q-# Q3747364	d1 728.3663746684337	d2 749.336118468244
# Q-# Q3747364	d1 172.7475509234005	d2 342.8844935998888
# Q-# Q1303855	d1 248.46334076389974	d2 557.7085001837336
# Q-# Q1435809	d1 6117.623188387951	d2 6343.827771591037
# Q-# Q12042914	d1 866.1349532488568	d2 1311.5495087403451
# Q-# Q12042914	d1 590.5949076353276	d2 626.5027683117343
# Q-# Q3747402	d1 991.6865076163195	d2 2223.030241005177
# Q-# Q3902380	d1 527.2068752396439	d2 533.7622965511463
# Q-# Q3902380	d1 394.3041116627513	d2 402.3299125499777
# Q-# Q12042914	d1 664.0230128796846	d2 831.9482528422017
# Q-# Q3747400	d1 1476.109957723437	d2 1493.5646629357168
# Q-# Q3747370	d1 2156.480193924941	d2 2951.413155880712
# Q-# Q3747370	d1 1004.2585961358013	d2 3039.749604622501
# Q-# Q1227084	d1 198.89814957073983	d2 289.1378524007489
# Q-# Q5465137	d1 123.75062802848772	d2 523.6742304534373
# Q-# Q5465137	d1 86.62693781554808	d2 548.0804357468343
# Q-# Q74574057	d1 1987.9534758290006	d2 3309.423290427082
# Q-# Q1714672	d1 170.9363227650294	d2 347.5638567155073
# Q-# Q1714672	d1 327.2639356755524	d2 358.9180957640289
# Q-# Q1234446	d1 741.1427740890463	d2 786.8658042933145
# Q-# Q1234446	d1 429.9168841850612	d2 518.1899470674011
# Q-# Q3747467	d1 503.50470010040453	d2 672.5009992766711
# Q-# Q1303855	d1 681.7314855271994	d2 705.0136975193811
# Q-# Q1303855	d1 561.7078503055166	d2 947.2709736903053
# Q-# Q3747388	d1 2737.0372754078126	d2 2940.2460162808147
# Q-# Q12042914	d1 5380.376405688616	d2 5482.516948204355
# Q-# Q12042914	d1 5409.183640786025	d2 5510.990987997311
# Q-# Q1303855	d1 563.7988268475592	d2 738.1906464151529
# Q-# Q1303855	d1 789.6571371353601	d2 1033.1708040071253
# Q-# Q1303855	d1 1059.913229429034	d2 1144.2512648074874
# Q-# Q1303855	d1 452.3443302637173	d2 713.7571026394122
# Q-# Q3747467	d1 81.5215102833185	d2 527.7080138466183
# Q-# Q3747467	d1 50.09067375997027	d2 498.17590476115527
# Q-# Q3747467	d1 51.116641506014886	d2 478.51462435721345
# Q-# Q3747467	d1 81.3452589581886	d2 507.67318782848736
# Q-# Q12042914	d1 5517.237293263686	d2 5647.400110051592
# Q-# Q1303855	d1 2611.6088225447384	d2 2739.379457322256
# Q-# Q3747402	d1 4621.694157194648	d2 5244.4758788921645
# Q-# Q1303855	d1 481.5435846361103	d2 804.4819563655757
# Q-# Q74574057	d1 6641.435895043035	d2 6995.441225510803
# Q-# Q12042914	d1 5577.57704147736	d2 5686.838260190395
# Q-# Q12042914	d1 5347.891013157072	d2 5450.03722535384
# Q-# Q12042914	d1 5415.519884822971	d2 5529.024224144979
# Q-# Q12042914	d1 5457.606831665387	d2 5554.755189655564
# Q-# Q3747400	d1 1601.7758944295206	d2 1617.8560364790353
# Q-# Q1303855	d1 186.50640323879412	d2 422.5734343209771
# Q-# Q74574057	d1 5781.265249163745	d2 7148.138892210507
# Q-# Q3747388	d1 2149.420164325957	d2 2202.0456858972993
# Q-# Q12042914	d1 10722.311269201657	d2 10965.279788255932
# Q-# Q12042914	d1 8428.4415634453	d2 8485.133483431111
# Q-# Q3747399	d1 8407.892670014617	d2 8643.163964732907
# Q-# Q1303855	d1 112.39377056061268	d2 524.0922106697273
# Q-# Q1435824	d1 221.7346141231961	d2 229.43198306235607
# Q-# Q1114231	d1 127.44889614518432	d2 396.5379552703828
# Q-# Q1924755	d1 332.4619767409187	d2 354.0787288503958
# Q-# Q1924755	d1 272.92511251200784	d2 283.2447714359692
# Q-# Q3747445	d1 199.10888023737624	d2 287.72035290868104
# Q-# Q3747388	d1 467.14265611480675	d2 700.7172417084493
# Q-# Q3747439	d1 745.7574220450721	d2 1166.2956311586463
# Q-# Q3747402	d1 8437.462453870308	d2 9006.54549216634
# Q-# Q3747400	d1 1133.7395728437978	d2 1148.737431549177
# Q-# Q74574057	d1 2306.1762960276856	d2 3992.7894027956922
# Q-# Q185382	d1 106.54257358354008	d2 330.4003293763274
# Q-# Q74574057	d1 3229.943450287221	d2 4903.753895088826
# Q-# Q74574057	d1 5341.471087868905	d2 6849.41373990294
# Q-# Q3747402	d1 9108.1365552301	d2 9343.410615531242
# Q-# Q12042914	d1 1437.628651291373	d2 1566.501065731932
# Q-# Q1085738	d1 991.0798484289305	d2 1095.2725002416175
# Q-# Q5465141	d1 161.7406071085827	d2 168.89827309214488
# Q-# Q3747399	d1 2959.5928286689773	d2 3299.4503841671085
# Q-# Q3747399	d1 2874.0885857046023	d2 2892.642402208052
# Q-# Q3747439	d1 1990.2924740821775	d2 2196.9685363304034
# Q-# Q3747439	d1 1757.5991762226631	d2 1977.6926524088606
# Q-# Q3747439	d1 2020.361318143815	d2 2099.2627464531743
# Q-# Q3747439	d1 1999.828036331476	d2 2178.702283542425
# Q-# Q3747439	d1 2098.090645128653	d2 2259.108410581624
# Q-# Q3747364	d1 139.93041051016226	d2 212.7739788119666
# Q-# Q1303855	d1 1273.4982147521732	d2 1284.3336850684316
# Q-# Q1234446	d1 1075.1903124950163	d2 1228.135099067824
# Q-# Q3747400	d1 1104.2796746191414	d2 1122.0608509444457
# Q-# Q56256300	d1 392.896368768692	d2 533.7102452243234
# Q-# Q3747465	d1 111.21567846687816	d2 226.30275207414593
# Q-# Q1303855	d1 928.4325551326923	d2 1158.3464368758114
# Q-# Q1303855	d1 967.8540123643355	d2 980.621086306273
# Q-# Q12042914	d1 1834.0332704770294	d2 2057.477335883278
# Q-# Q74574057	d1 1576.809121488837	d2 2976.7105812336617
# Q-# Q74574057	d1 458.8041936578073	d2 1397.4696908104117
# Q-# Q3747388	d1 217.58934197948315	d2 644.7896834378221
# Q-# Q3747369	d1 223.326183178582	d2 305.71079335569823
# Q-# Q3747397	d1 327.05981751424275	d2 433.3554588772538
# Q-# Q1924755	d1 392.65963418317045	d2 599.6194813631475
# Q-# Q12042914	d1 5322.818935204181	d2 5403.215928106852
# Q-# Q3747400	d1 966.7624242404456	d2 982.0770076501975
# Q-# Q5465137	d1 963.5150323164809	d2 1420.1347484972653
# Q-# Q3747439	d1 1593.5888248854112	d2 1829.7272746528113
# Q-# Q3747439	d1 1554.9002095338144	d2 1773.4688937535382
# Q-# Q3747439	d1 1757.2331298770375	d2 1982.8618471833624
# Q-# Q3747402	d1 1282.4227423352388	d2 2895.9418083313117
# Q-# Q3747400	d1 534.1767867460154	d2 543.3667788535352
# Q-# Q1303855	d1 2058.784065328015	d2 2133.626960426713
# Q-# Q12042914	d1 1949.322189178505	d2 2215.894117168742
# Q-# Q3747402	d1 1406.731246086064	d2 1426.6119057663345
# Q-# Q7489878	d1 709.3755856649527	d2 734.2125937233101
# Q-# Q12042914	d1 2541.063187944867	d2 3004.2690743122653
# Q-# Q12042914	d1 4505.024546283105	d2 4968.45804535188
# Q-# Q29582887	d1 618.8242544100268	d2 628.5962952790434
# Q-# Q1303855	d1 246.84141412292811	d2 391.644085873153
# Q-# Q1303855	d1 1166.47683406544	d2 1264.6762080680164
# Q-# Q1303855	d1 443.67236291389077	d2 584.4092337073696
# Q-# Q12042914	d1 4720.676226021673	d2 4806.114472448308
# Q-# Q12042914	d1 4784.094731054716	d2 4903.06081025441
# Q-# Q12042914	d1 4851.129331412338	d2 4919.716921486064
# Q-# Q12042914	d1 4622.457725286382	d2 4789.432349097709
# Q-# Q12042914	d1 15260.41784753737	d2 15509.65483476182
# Q-# Q12042914	d1 3041.6710318238675	d2 3402.8542446108877
# Q-# Q12042914	d1 2801.775355983583	d2 3204.8792629102404
# Q-# Q3747388	d1 850.9110501185522	d2 947.5321649281603
# Q-# Q3747388	d1 741.9441716268927	d2 928.9692946695711
# Q-# Q3747388	d1 533.4998098682258	d2 873.5773884811797
# Q-# Q3747388	d1 627.9030801123542	d2 893.9127677230733
# Q-# Q74574057	d1 2195.983961380391	d2 2220.804651460933
# Q-# Q12042914	d1 10118.151910165298	d2 10462.377087928853
# Q-# Q12042914	d1 4229.114336694546	d2 4571.354789873454
# Q-# Q3747402	d1 889.9415359639856	d2 2607.9951315087797
# Q-# Q3747370	d1 1986.441731434551	d2 2571.8086094934974
# Q-# Q3747370	d1 1920.2943031904924	d2 2243.480084391409
# Q-# Q3747400	d1 267.16550477992024	d2 268.35782353757986
# Q-# Q1303855	d1 1813.3575371430227	d2 1977.6747425914023
# Q-# Q12042914	d1 484.48751144790356	d2 901.7693680029997
# Q-# Q185382	d1 180.71706376632713	d2 256.2134322668594
# Q-# Q1303855	d1 406.6734418397162	d2 627.6079568070953
# Q-# Q1435809	d1 3239.715710931799	d2 3445.460873985969
# Q-# Q1435809	d1 2409.9421813789377	d2 2720.7781050948047
# Q-# Q3747429	d1 213.5955807195244	d2 331.2375535524583
# Q-# Q3747402	d1 304.56465769052204	d2 2094.741350565276
# Q-# Q3747402	d1 180.24465775152933	d2 1972.92802943831
# Q-# Q1435809	d1 2689.9544237676273	d2 2994.849575769986
# Q-# Q1435809	d1 788.477532215304	d2 1140.5384909593552
# Q-# Q1435809	d1 1404.9335215859596	d2 1767.6269622850186
# Q-# Q12042914	d1 2642.091169368666	d2 2660.215785217457
# Q-# Q1435809	d1 1283.468647424164	d2 1615.9095483561969
# Q-# Q5465137	d1 433.4397325578318	d2 906.6128357022175
# Q-# Q74574057	d1 559.9930744139424	d2 2034.873451910077
# Q-# Q3747402	d1 1306.8759969376886	d2 2954.413333832029
# Q-# Q3747400	d1 1635.0703712616946	d2 1651.6339909221253
# Q-# Q1435809	d1 2432.3356906492927	d2 2629.4355921018864
# Q-# Q74574057	d1 982.5778078969968	d2 2680.334826154137
# Q-# Q3747402	d1 2455.996439456542	d2 3096.2670494663707
# Q-# Q3747402	d1 4362.561178798609	d2 5843.610688416315
# Q-# Q12042914	d1 1480.608457283471	d2 1674.5967957817795
# Q-# Q12042914	d1 1371.259423128185	d2 1597.7591651710338
# Q-# Q12042914	d1 1822.6858196734784	d2 2165.5564882161857
# Q-# Q3902380	d1 216.00171273567838	d2 227.33426166869543
# Q-# Q12042914	d1 2751.8157636870856	d2 2850.9557740267082
# Q-# Q12042914	d1 2654.653613732312	d2 2834.2087994323856
# Q-# Q12042914	d1 2792.5102545192635	d2 3152.1954044060253
# Q-# Q3747402	d1 1076.5929898548209	d2 1335.819949444924
# Q-# Q3747400	d1 1119.5415122354962	d2 1135.7217080811256
# Q-# Q1085738	d1 951.1830501644658	d2 1008.4805885669448
# Q-# Q1114231	d1 251.4539823406695	d2 293.49805874139724
# Q-# Q1114231	d1 22.71653103513098	d2 334.69665161109515
# Q-# Q3747402	d1 819.1225471306107	d2 1515.1637276501565
# Q-# Q3747402	d1 528.7604722347244	d2 1932.9309010905695
# Q-# Q1435809	d1 2406.316738188483	d2 2667.259204187494
# Q-# Q12042914	d1 1369.753719060569	d2 1692.5546829624252
# Q-# Q12042914	d1 2059.15621602187	d2 2086.637348755534
# Q-# Q1303855	d1 541.512346146477	d2 754.0873985360573
# Q-# Q74574057	d1 7696.823774638453	d2 7917.609016145836
# Q-# Q3747467	d1 356.1489321050206	d2 639.5352268766787
# Q-# Q29582887	d1 568.5058573763047	d2 580.0121425506138
# Q-# Q3747402	d1 515.4392295780142	d2 1731.0971591807704
# Q-# Q12042914	d1 2685.5162928555796	d2 3149.5393516067047
# Q-# Q983774	d1 486.6456159339237	d2 680.6771691190628
# Q-# Q857540	d1 1317.6330432470377	d2 1334.6358881379222
# Q-# Q3747467	d1 415.66700097110544	d2 699.0737216231839
# Q-# Q1435824	d1 75.86981693027494	d2 135.00236653810674
# Q-# Q1435824	d1 170.92986376372053	d2 223.3209771018538
# Q-# Q1435824	d1 208.53564136427627	d2 220.94552372725298
# Q-# Q3747402	d1 1060.1348478130321	d2 2593.5115232528656
# Q-# Q3747378	d1 688.869637391493	d2 1018.0495612906635
# Q-# Q3747370	d1 5665.928205668071	d2 5914.030518073982
# Q-# Q3747440	d1 91.84149850206457	d2 268.0899528009039
# Q-# Q74574057	d1 6353.6449563503475	d2 7580.600802867389
# Q-# Q74574057	d1 6235.427682181965	d2 7507.153112695988
# Q-# Q12042914	d1 4226.774322049101	d2 4569.36251672909
# Q-# Q12042914	d1 4073.463724762525	d2 4430.140210732276
# Q-# Q1303855	d1 1842.2250847052655	d2 1962.15779763492
# Q-# Q1303855	d1 1864.4255762294147	d2 1992.3821749465897
# Q-# Q12042914	d1 4230.476629153807	d2 4572.434200342028
# Q-# Q12042914	d1 3285.0323476731555	d2 3709.857078581325
# Q-# Q3747369	d1 121.8145287611445	d2 260.14028234673015
# Q-# Q1303855	d1 1921.5271384185673	d2 1967.7975438081744
# Q-# Q3747402	d1 1520.6493182558766	d2 2091.9057346435548
# Q-# Q1085738	d1 641.9338192919224	d2 777.8136740995145
# Q-# Q3747444	d1 97.89297798871826	d2 260.20810954875844
# Q-# Q857540	d1 166.51951654903277	d2 246.67292607083232
# Q-# Q3747443	d1 134.75402588237841	d2 577.7723472634046
# Q-# Q185382	d1 316.1427385187923	d2 334.4035466507241
# Q-# Q185382	d1 182.65598204761415	d2 362.78998391143085
# Q-# Q655470	d1 236.87937777748428	d2 242.39911634586056
# Q-# Q3747378	d1 257.99980302112454	d2 1269.5909925617545
# Q-# Q74574057	d1 2664.750267312055	d2 4287.563128981389
# Q-# Q3747388	d1 2596.879259018111	d2 2773.581803288253
# Q-# Q74574057	d1 2650.466433506075	d2 4225.528369974407
# Q-# Q74574057	d1 2622.2502984422495	d2 4191.249223949546
# Q-# Q74574057	d1 3376.3111160514804	d2 4963.033784154244
# Q-# Q267971	d1 73.34917628176109	d2 88.69390864739472
# Q-# Q3747397	d1 153.86648485774643	d2 327.39905826130894
# Q-# Q74574057	d1 6006.4186689256385	d2 7658.402898091052
# Q-# Q3747367	d1 53.18088636384987	d2 76.66711577051862
# Q-# Q5465141	d1 193.3261484793884	d2 217.93856990113773
# Q-# Q3747399	d1 480.712716017672	d2 1128.6132835600495
# Q-# Q3747402	d1 5875.618884034002	d2 6632.993647354922
# Q-# Q29582887	d1 244.81216200555207	d2 331.87750808336233
# Q-# Q74574057	d1 4706.869365419846	d2 6141.919038953757
# Q-# Q74574057	d1 5223.814488170414	d2 6783.4988106927685
# Q-# Q74574057	d1 4419.658442335876	d2 5840.002295987354
# Q-# Q74574057	d1 3641.716227127506	d2 5044.358873785122
# Q-# Q3747400	d1 1105.5651283480497	d2 1122.4375178825853
# Q-# Q74574057	d1 6133.798247741492	d2 7817.242095965601
# Q-# Q74574057	d1 6188.754127041872	d2 7881.64605394401
# Q-# Q74574057	d1 6131.201575464291	d2 7828.299969575064
# Q-# Q74574057	d1 3816.89468818691	d2 4941.105114871174
# Q-# Q3747378	d1 847.6409875414395	d2 859.5808290732347
# Q-# Q1435809	d1 1929.0016241891847	d2 2231.559668577487
# Q-# Q3747364	d1 196.900865952532	d2 240.83369313595892
# Q-# Q1435809	d1 1804.89792913815	d2 2044.221977523264
# Q-# Q1435809	d1 1759.4132770557583	d2 2017.8565311931566
# Q-# Q1435809	d1 1919.3919538296605	d2 2171.5375879023422
# Q-# Q1435809	d1 1644.1669601817682	d2 1837.300095028191
# Q-# Q3747364	d1 890.110008018149	d2 993.3893772030965
# Q-# Q3747400	d1 985.6277744094687	d2 1000.8623800794799
# Q-# Q1435809	d1 3022.0216285964143	d2 3175.823239562164
# Q-# Q3747399	d1 3172.181929742107	d2 3204.368566108153
# Q-# Q3747402	d1 3427.446424267575	d2 4897.9216794863605
# Q-# Q3747402	d1 6286.792574357336	d2 6562.338339587392
# Q-# Q1435809	d1 1219.5213244878196	d2 1484.0398012403034
# Q-# Q3747400	d1 615.706854914521	d2 632.6417242379556
# Q-# Q3747400	d1 614.986727729596	d2 632.6183814855791
# Q-# Q3747444	d1 291.350474699209	d2 377.1644498395234
# Q-# Q1435809	d1 3045.392928519632	d2 3131.7676805308397
# Q-# Q3747397	d1 163.00738993174085	d2 264.0266017528072
# Q-# Q3747399	d1 2661.4937344510513	d2 2701.788897402648
# Q-# Q12042914	d1 2602.0306613057824	d2 3089.578874252698
# Q-# Q12042914	d1 2973.0921470627545	d2 3098.372094775275
# Q-# Q3747402	d1 7229.292896861713	d2 8071.04584450847
# Q-# Q3747402	d1 7108.99091309741	d2 7985.912152167926
# Q-# Q3747465	d1 205.914267374449	d2 249.7652427780763
# Q-# Q3747397	d1 160.60709722573108	d2 187.31407918496527
# Q-# Q3747399	d1 2078.8060414100087	d2 2805.9692973771507
# Q-# Q12042914	d1 1988.3385890585478	d2 2055.9284046091648
# Q-# Q3747400	d1 875.2757751966727	d2 892.3722740134233
# Q-# Q3747400	d1 962.6480932558771	d2 979.0010288834483
# Q-# Q3747465	d1 164.4468179133404	d2 191.1502834331946
# Q-# Q1435809	d1 530.7290226138268	d2 798.4203167037749
# Q-# Q3747399	d1 2353.4908173279396	d2 2520.286166792433
# Q-# Q3747364	d1 340.8438325562765	d2 401.2728067979009
# Q-# Q56256300	d1 191.91970596560418	d2 286.14364994222103
# Q-# Q3747364	d1 275.92426232699034	d2 402.91279761980996
# Q-# Q3747364	d1 537.7558900414338	d2 656.2049487972356
# Q-# Q56256300	d1 312.70707234893916	d2 370.55949062951913
# Q-# Q56256300	d1 327.3308362431625	d2 356.80606719239216
# Q-# Q74574057	d1 1853.9800603049623	d2 1966.9480380138286
# Q-# Q74574057	d1 1170.3432029573173	d2 2767.664605951417
# Q-# Q74574057	d1 1191.8070281240389	d2 2831.6384563675265
# Q-# Q74574057	d1 1086.88894922428	d2 2708.233783436772
# Q-# Q3747402	d1 4799.044161498711	d2 5959.121275059925
# Q-# Q12042914	d1 1807.3564619505248	d2 2270.2859312479873
# Q-# Q12042914	d1 1732.0489346928862	d2 2187.9843042647453
# Q-# Q74574057	d1 3653.4350760452994	d2 5032.451571468764
# Q-# Q3747440	d1 173.62838084849042	d2 272.36066706810254
# Q-# Q3747399	d1 228.3087333548638	d2 712.2357291807367
# Q-# Q3747399	d1 118.92051067715633	d2 818.4634402310187
# Q-# Q12042914	d1 1546.6368598226252	d2 2031.1806480202158
# Q-# Q12042914	d1 2628.614073593833	d2 3077.72445537625
# Q-# Q12042914	d1 14322.003562882686	d2 14522.995113123287
# Q-# Q12042914	d1 1713.7092079211363	d2 1796.0291870282854
# Q-# Q74574057	d1 1065.8380630083125	d2 1793.5406048491695
# Q-# Q3747467	d1 398.57684618337817	d2 686.433090948422
# Q-# Q3747467	d1 452.790288545001	d2 641.8615937893842
# Q-# Q936296	d1 99.41847233837262	d2 177.442782981748
# Q-# Q3747399	d1 899.4473104933346	d2 1797.064696124063
# Q-# Q3747399	d1 988.4027059632623	d2 1896.289079479357
# Q-# Q7489878	d1 709.2062505054851	d2 875.8100622390028
# Q-# Q3747402	d1 8816.155124801353	d2 9439.572831125437
# Q-# Q185382	d1 45.649467988207405	d2 360.28557216188335
# Q-# Q12042914	d1 4366.151854138835	d2 4652.9863087850945
# Q-# Q12042914	d1 4336.251969026637	d2 4600.83059846003
# Q-# Q74574057	d1 2341.4364203688465	d2 3633.1697026097754
# Q-# Q3747402	d1 1714.151955557535	d2 3368.9330245125198
# Q-# Q3747402	d1 2117.8651337408382	d2 3709.0248770847775
# Q-# Q12042914	d1 4233.052839356128	d2 4522.175459205166
# Q-# Q12042914	d1 4455.122560151154	d2 4756.985894858358
# Q-# Q3747402	d1 8323.793061014045	d2 9086.302655521244
# Q-# Q3747399	d1 2107.0456695076587	d2 2718.1633849244936
# Q-# Q3747399	d1 2084.9794690296144	d2 2724.5867275392648
# Q-# Q3747399	d1 1855.2174282098742	d2 2540.7414065363855
# Q-# Q1924755	d1 265.6953558520632	d2 289.6948401020666
# Q-# Q12042914	d1 2871.9340794190557	d2 3345.34372730403
# Q-# Q74574057	d1 8498.029003409285	d2 10203.776369154413
# Q-# Q12042914	d1 6389.369032711739	d2 6793.618841434971
# Q-# Q12042914	d1 7057.250301924668	d2 7468.981615844085
# Q-# Q12042914	d1 6470.45602008121	d2 6887.756716252672
# Q-# Q12042914	d1 6793.060926323557	d2 7204.392650586896
# Q-# Q12042914	d1 6740.051534246392	d2 7145.532083183469
# Q-# Q12042914	d1 4933.556756448616	d2 5215.323219232282
# ...
# Q-# Q74574057	d1 10044.992017181869	d2 11737.274647512435
# Q-# Q74574057	d1 10127.040102670668	d2 11819.232157242714
# Q-# Q74574057	d1 10355.65558885338	d2 12047.452844030842
# Q-# Q12042914	d1 5411.31374479982	d2 5484.124700238342
# Q-# Q1435809	d1 2989.05593614991	d2 3286.5219418461083
# Q-# Q74574057	d1 7735.120483449744	d2 9439.183962758114
# Q-# Q74574057	d1 8810.259228031771	d2 10512.34277781708
# Q-# Q74574057	d1 5657.460212301415	d2 7354.353096029793
# Q-# Q74574057	d1 6524.4665082268575	d2 8164.464184093298
# Q-# Q74574057	d1 8219.357984724607	d2 9921.565048108281
# Q-# Q3747370	d1 2428.3682059891157	d2 2440.025560216736
# Q-# Q3747467	d1 169.7599222169687	d2 602.2063093324592
# Q-# Q3747467	d1 169.5105568241184	d2 599.8201754887209
# Q-# Q3747467	d1 165.16128191056168	d2 598.0057615104557
# Q-# Q3747467	d1 164.9503192660792	d2 595.6433142323194
# Q-# Q3747467	d1 40.8363055856975	d2 410.3122029857393
# Q-# Q3747467	d1 40.50745768663102	d2 413.083674689683
# Q-# Q3747467	d1 45.217912633332624	d2 409.133455810922
# Q-# Q74574057	d1 9006.79324682454	d2 10711.305625285811
# Q-# Q3747402	d1 2039.629160799633	d2 2392.0483788262068
# Q-# Q74574057	d1 8678.017769888957	d2 10368.602293850949
# Q-# Q74574057	d1 8213.387725271412	d2 9686.013116479033
# Q-# Q74574057	d1 8222.542731876441	d2 9634.914030719756
# Q-# Q74574057	d1 4950.349427823426	d2 6650.016832003721
# Q-# Q3747399	d1 704.7841600859224	d2 706.9717992694402
# Q-# Q3747467	d1 266.23105941793773	d2 553.1368700798763
# Q-# Q3747402	d1 1146.9097882788358	d2 1237.2847438178906
# Q-# Q3747429	d1 154.4729454829342	d2 203.37571679466564
# Q-# Q983774	d1 753.5103713665934	d2 911.181260684492
# Q-# Q3747399	d1 2917.190020081522	d2 3628.3815546538594
# Q-# Q3747402	d1 2581.577518084667	d2 3522.676183076209
# Q-# Q12042914	d1 15452.243924896955	d2 15934.249607710242
# Q-# Q56256300	d1 257.75947421438127	d2 531.3320587920812
# Q-# Q74574057	d1 9793.936914870275	d2 11482.76561471485
# Q-# Q7489878	d1 210.89382317510447	d2 457.0448212611821
# Q-# Q3747399	d1 6883.220906015904	d2 7494.488231321462
# Q-# Q3747399	d1 7162.49721586582	d2 7727.586950822099
# Q-# Q3747399	d1 6952.9362767239245	d2 7507.213997143255
# Q-# Q3747399	d1 560.5898558962634	d2 781.031346735119
# Q-# Q74574057	d1 2735.386199408374	d2 3690.599459383283
# Q-# Q3747399	d1 6191.151440145478	d2 6901.093518107377
# Q-# Q12042914	d1 1982.0509831433972	d2 2462.812825276723
# Q-# Q3747370	d1 506.24331105887063	d2 1890.383870630756
# Q-# Q74574057	d1 2991.856483130536	d2 4674.736331050124
# Q-# Q3747370	d1 2970.9666981954674	d2 3818.655308726734
# Q-# Q3747370	d1 2301.506976141686	d2 3083.765249197963
# Q-# Q74574057	d1 12406.783345946862	d2 14107.154548288425
# Q-# Q1435809	d1 2421.8135998849148	d2 2595.5413669177856
# Q-# Q3747399	d1 1596.579333344368	d2 2315.8736654416657
# Q-# Q74574057	d1 514.4732211246801	d2 1381.8195097793366
# Q-# Q74574057	d1 4314.267667743832	d2 5957.871964370563
# Q-# Q12042914	d1 1500.1333460700318	d2 1961.3850307132436
# Q-# Q74574057	d1 2802.683744830308	d2 4276.338965068086
# Q-# Q3747388	d1 2832.639916026653	d2 2887.379788126457
# Q-# Q3747402	d1 4325.1517750012745	d2 5734.238972309324
# Q-# Q5465137	d1 130.40430160716411	d2 478.85857424277145
# Q-# Q74574057	d1 2363.175514206608	d2 3991.210924218565
# Q-# Q74574057	d1 1152.4954182702324	d2 2706.277578978433
# Q-# Q74574057	d1 2625.8866178139333	d2 4277.5633833996635
# Q-# Q74574057	d1 4961.769808278086	d2 6638.753840405593
# Q-# Q74574057	d1 4574.16816397325	d2 6253.299329344652
# Q-# Q857540	d1 944.2096033664101	d2 945.3707555585611
# Q-# Q12042914	d1 2890.109258736049	d2 3364.2371860313224
# Q-# Q12042914	d1 2780.9766852897587	d2 3256.7913734573767
# Q-# Q857540	d1 381.9723926283855	d2 457.48726134546587
# Q-# Q74574057	d1 7654.484150061854	d2 9134.94240379223
# Q-# Q74574057	d1 8088.794836498252	d2 9548.991373486015
# Q-# Q3747399	d1 1692.8094210693266	d2 2238.30488102673
# Q-# Q3747378	d1 495.34003526180305	d2 1000.1638478442721
# Q-# Q74574057	d1 4705.300877459251	d2 4942.196762304757
# Q-# Q74574057	d1 4778.909552515881	d2 4991.203102098531
# Q-# Q74574057	d1 4385.048367109508	d2 4639.191658615015
# Q-# Q74574057	d1 4267.875707878576	d2 4488.157238290831
# Q-# Q3747402	d1 1462.4961368107047	d2 2926.4285101380347
# Q-# Q3747402	d1 1308.9258514370163	d2 2847.9217620587106
# Q-# Q74574057	d1 6482.604269001972	d2 8108.592384516812
# Q-# Q74574057	d1 4999.388984789702	d2 6656.1436380965115
# Q-# Q74574057	d1 3764.1477916868034	d2 4778.519440417409
# Q-# Q74574057	d1 11388.384076488306	d2 13060.714767453534
# Q-# Q3747467	d1 467.83598557568394	d2 594.2576195533951
# Q-# Q3747399	d1 5320.618300564631	d2 5992.10378892788
# Q-# Q3747399	d1 5506.946950417233	d2 6164.960341513815
# Q-# Q3747402	d1 4926.878929225882	d2 5158.209707291159
# Q-# Q3747402	d1 4975.986818598894	d2 5207.624913860941
# Q-# Q3747402	d1 5022.347398045193	d2 5220.659826768517
# Q-# Q74574057	d1 7568.668946130639	d2 7926.213618631239
# Q-# Q267971	d1 234.35191250869158	d2 306.7505652710595
# Q-# Q3747399	d1 3139.566493808506	d2 3695.622589263499
# Q-# Q3747399	d1 3560.8253738543954	d2 3587.018002604345
# Q-# Q74574057	d1 5357.153093555594	d2 6918.11480846353
# Q-# Q74574057	d1 5407.640674779289	d2 6962.7341149219465
# Q-# Q74574057	d1 3877.293995903509	d2 5574.931357330933
# Q-# Q74574057	d1 4078.07389306016	d2 5765.908338550352
# Q-# Q3747402	d1 6394.800436113146	d2 7680.50909637052
# Q-# Q3747402	d1 6252.815795946387	d2 7519.795682252993
# Q-# Q12042914	d1 937.2071381034002	d2 1109.1742343133203
# Q-# Q3747402	d1 775.2468926451551	d2 1411.1225798275243
# Q-# Q3747442	d1 157.0126796685957	d2 250.54337058300476
# Q-# Q1759793	d1 248.62265864835513	d2 294.8840426063344
# Q-# Q3747467	d1 466.0121203614704	d2 698.7544725442893
# Q-# Q3747402	d1 7435.652588762839	d2 7876.5821967717675
# Q-# Q74574057	d1 7515.612831302961	d2 7583.8225747277675
# Q-# Q3747399	d1 6787.719192743862	d2 7579.235659980289
# Q-# Q3747399	d1 6858.678722229787	d2 7673.028933529998
# Q-# Q3747402	d1 7342.904184979805	d2 7679.599715378587
# Q-# Q3747402	d1 7623.850489940765	d2 7687.282914524203
# Q-# Q3747402	d1 7636.526488465791	d2 7734.926881412433
# Q-# Q3747402	d1 6249.658560499001	d2 7371.278183260918
# Q-# Q74574057	d1 2888.8091657741634	d2 4562.118764059581
# Q-# Q74574057	d1 1632.4541008705137	d2 3249.6510877010173
# Q-# Q74574057	d1 3513.6639394966583	d2 4980.089372490207
# Q-# Q1435809	d1 1363.251418195338	d2 1518.5137643960718
# Q-# Q3747399	d1 1453.240163664157	d2 2170.8180912589614
# Q-# Q74574057	d1 2851.2768976343336	d2 4498.334185452677
# Q-# Q1435809	d1 3222.595230121075	d2 3398.784112014286
# Q-# Q3747467	d1 502.15263754584606	d2 634.1566271518072
# Q-# Q3747421	d1 25.679603264215867	d2 243.8343963447151
# Q-# Q3747465	d1 101.63673861378582	d2 321.86422179745534
# Q-# Q3747465	d1 102.50379145891975	d2 321.77104701261356
# Q-# Q3747370	d1 2828.325501206507	d2 4149.389952178465
# Q-# Q12042914	d1 327.68712438727783	d2 418.14890803170533
# Q-# Q3747467	d1 315.51754494620553	d2 394.3027287962182
# Q-# Q74574057	d1 2897.1139551254205	d2 4470.731457591012
# Q-# Q3747388	d1 334.41663139678576	d2 782.6585731434857
# Q-# Q74574057	d1 3616.8710392884213	d2 5213.088696009307
# Q-# Q1435809	d1 439.63884593333233	d2 555.8822456312364
# Q-# Q1435809	d1 486.3806141813964	d2 679.6028962863398
# Q-# Q3747443	d1 275.6262082887844	d2 658.6881080219378
# Q-# Q1435809	d1 607.1404528703551	d2 625.2801029857732
# Q-# Q3747378	d1 1036.1272181506658	d2 1211.6908928827213
# Q-# Q3747402	d1 7363.8305953980025	d2 7383.092419844383
# Q-# Q12042914	d1 8022.271819100989	d2 8474.203985057782
# Q-# Q74574057	d1 10539.263942484455	d2 12243.692978855464
# Q-# Q74574057	d1 4127.552400992681	d2 5629.714705422849
# Q-# Q3747402	d1 542.7412045641754	d2 1479.1093696299308
# Q-# Q3747399	d1 4019.9333757900877	d2 4578.575448245645
# Q-# Q3747388	d1 1664.1126701646965	d2 1744.9732145985793
# Q-# Q74574057	d1 1146.7795813714224	d2 2619.889951136934
# Q-# Q74574057	d1 1106.6861830259916	d2 2580.804411435632
# Q-# Q74574057	d1 1154.3105168353145	d2 2627.8808773146216
# Q-# Q1759793	d1 226.48382773720564	d2 261.6361868951958
# Q-# Q74574057	d1 8225.527081299448	d2 9667.816313480724
# Q-# Q74574057	d1 3335.1981817358574	d2 5002.981080710767
# Q-# Q3747378	d1 864.4343194074892	d2 1124.6939889247947
# Q-# Q1303855	d1 366.9956607920521	d2 563.6576555691851
# Q-# Q1234446	d1 174.68244451935814	d2 409.4688827141888
# Q-# Q185382	d1 251.24626159930634	d2 311.78155328038076
# Q-# Q1435824	d1 117.65210863527584	d2 130.6863601819383
# Q-# Q3747445	d1 20.29418255124107	d2 405.4500636288523
# Q-# Q3747439	d1 655.9408686255542	d2 732.321012572446
# Q-# Q3747439	d1 655.2936710327223	d2 734.2232056799335
# Q-# Q3747402	d1 216.46253478602722	d2 1832.6240910389915
# Q-# Q983774	d1 718.442116419792	d2 757.0395142302409
# Q-# Q3747399	d1 1530.5598499221949	d2 1993.7608283235695
# Q-# Q3747399	d1 1355.3791660472723	d2 2115.5758796454
# Q-# Q3747399	d1 1050.1509065262405	d2 1368.7828078244813
# Q-# Q3747399	d1 2779.782766273108	d2 3531.9736413854635
# Q-# Q12042914	d1 5458.282296533223	d2 5586.844862386925
# Q-# Q3747370	d1 6499.6047734355125	d2 7195.321923372745
# Q-# Q3747444	d1 501.47131226537266	d2 531.6532396199974
# Q-# Q56256300	d1 348.5044531403162	d2 531.8409779069494
# Q-# Q3747439	d1 1853.5448301178799	d2 2046.9140383152608
# Q-# Q3747402	d1 2737.726289474312	d2 3086.709951334907
# Q-# Q936296	d1 184.8233482111667	d2 274.50655912248044
# Q-# Q3747402	d1 3697.5250696449034	d2 5088.695142609242
# Q-# Q3747399	d1 4865.69576346862	d2 5642.34047043091
# Q-# Q3747400	d1 922.6411183332496	d2 939.2216478825368
# Q-# Q3747400	d1 691.810667814873	d2 708.8749792664827
# Q-# Q3747399	d1 1962.4377050254218	d2 2641.3137150104217
# Q-# Q3747370	d1 1234.9162778794184	d2 2078.8700500829705
# Q-# Q1924755	d1 208.63703020078077	d2 345.2664314011933
# Q-# Q74574057	d1 5642.547173068242	d2 7194.485699053912
# Q-# Q74574057	d1 2732.7586813511903	d2 3036.1882271190048
# Q-# Q3747399	d1 1334.8422993035185	d2 1757.7771396209428
# Q-# Q983774	d1 1033.5707925096633	d2 1123.7877481774149
# Q-# Q1303855	d1 9396.581812048025	d2 9445.79703800169
# Q-# Q3747402	d1 11585.980606607482	d2 11833.975580522088
# Q-# Q74574057	d1 11240.6992048052	d2 11279.594706137626
# Q-# Q3747402	d1 11463.915431282605	d2 11652.243238158073
# Q-# Q3747402	d1 11185.661433586121	d2 11240.935006486316
# Q-# Q3747402	d1 11080.023389988015	d2 11282.44716738008
# Q-# Q74574057	d1 11122.779111266716	d2 11149.851689709461
# Q-# Q74574057	d1 8898.895429925304	d2 10560.09620596139
# Q-# Q74574057	d1 2543.3496692321764	d2 2960.464664508093
# Q-# Q74574057	d1 2656.0843482632417	d2 3207.110856929606
# Q-# Q74574057	d1 2668.264057545888	d2 3228.067687542395
# Q-# Q74574057	d1 11352.268995159551	d2 13004.586700076838
# Q-# Q7489878	d1 311.9310106959028	d2 522.4061205496319
# Q-# Q3747399	d1 5793.662422994939	d2 6542.8390545692555
# Q-# Q74574057	d1 5750.870115048296	d2 7333.549583550529
# Q-# Q3747443	d1 215.16016634262104	d2 430.49310857302953
# Q-# Q74574057	d1 1988.4118284465808	d2 3605.1131329623704
# Q-# Q12042914	d1 32.83677331848073	d2 460.6982986509668
# Q-# Q3747399	d1 615.6363543181733	d2 629.4861883917074
# Q-# Q3747399	d1 4561.745920314292	d2 4738.3637013113375
# Q-# Q74574057	d1 5097.703111728399	d2 5624.909895236947
# Q-# Q1714672	d1 55.157163018139094	d2 172.61806185633733
# Q-# Q3747402	d1 3891.063801895329	d2 5295.17491178399
# Q-# Q3747400	d1 2794.7858281503045	d2 2812.346796869539
# Q-# Q3747400	d1 2854.0208319142566	d2 2871.5364086613313
# Q-# Q3747400	d1 2745.443884457385	d2 2763.0463514995417
# Q-# Q1234446	d1 269.62520477778594	d2 321.4740771665869
# Q-# Q3747402	d1 1279.6456104345737	d2 2892.7783136666403
# Q-# Q18379990	d1 221.5733315757397	d2 277.39942989713137
# Q-# Q3747399	d1 530.0725604397562	d2 692.4289213131256
# Q-# Q3747399	d1 1306.3279406514885	d2 1591.6282906745523
# Q-# Q74574057	d1 2416.580012052585	d2 2479.267641258861
# Q-# Q3747378	d1 817.794495153441	d2 1172.800548788552
# Q-# Q74574057	d1 3613.4295520395713	d2 5187.048245849579
# Q-# Q74574057	d1 3133.176164842299	d2 4686.802857752363
# Q-# Q3747399	d1 2268.134817631123	d2 3076.602294754071
# Q-# Q3747399	d1 3574.165058325714	d2 4262.495504359497
# Q-# Q3747402	d1 1038.9625551208344	d2 1363.2346851768343
# Q-# Q3747370	d1 2686.9782156384545	d2 3239.284753411062
# Q-# Q74574057	d1 2409.7343028966493	d2 2697.023494957091
# Q-# Q3747467	d1 905.9158223142922	d2 984.5994969817492
# Q-# Q74574057	d1 2552.5013403020503	d2 2826.0920472635726
# Q-# Q3747388	d1 1621.021723874398	d2 1887.6832590703598
# Q-# Q3747370	d1 1896.8043571875298	d2 2968.6354771618044
# Q-# Q3747402	d1 6958.760206558041	d2 8196.064274092143
# Q-# Q3747378	d1 1452.5976914883286	d2 1636.8233701609233
# Q-# Q3747400	d1 2449.205977261296	d2 2466.518663528697
# Q-# Q3747370	d1 2347.965117758128	d2 2371.8985190827866
# Q-# Q74574057	d1 5387.247575414505	d2 7049.441061828145
# Q-# Q74574057	d1 2302.8453689641597	d2 2631.058276037891
# Q-# Q3747370	d1 1144.333248502365	d2 2625.8611434977665
# Q-# Q3902380	d1 571.7711832764425	d2 588.6743316324876
# Q-# Q1303855	d1 359.48753303876964	d2 384.1698153913772
# Q-# Q3747467	d1 285.54053676803915	d2 651.9936549330384
# Q-# Q1085738	d1 837.6420347192073	d2 928.9254316184584
# Q-# Q1085738	d1 862.7454077438271	d2 956.8642002314638
# Q-# Q936296	d1 186.23673022662882	d2 281.2318600055644
# Q-# Q3747400	d1 1150.7900161798186	d2 1167.7437184616142
# Q-# Q3747402	d1 5425.8854145452615	d2 6455.337782291216
# Q-# Q74574057	d1 6592.993958754739	d2 8213.97436881564
# Q-# Q74574057	d1 7229.7438374072635	d2 8880.430085790762
# Q-# Q3747402	d1 2276.009245699174	d2 2597.137610994302
# Q-# Q3747402	d1 2550.443011050991	d2 3395.739853205705
# Q-# Q74574057	d1 2052.4000546127672	d2 3679.5584850815776
# Q-# Q3747443	d1 336.92803412242307	d2 540.8669640976924
# Q-# Q74574057	d1 2747.4275247424844	d2 2939.718886024694
# Q-# Q74574057	d1 3685.438386551	d2 5320.696406730029
# Q-# Q74574057	d1 2543.031568831231	d2 3676.3331121238516
# Q-# Q12042914	d1 1279.1552195138406	d2 1727.4881532699349
# Q-# Q3747444	d1 134.53989805186674	d2 229.6765643591122
# Q-# Q3747399	d1 1031.1042167529592	d2 1610.409796802547
# Q-# Q3747400	d1 2289.4017950660023	d2 2306.5502060085314
# Q-# Q3747370	d1 4829.911587481153	d2 4887.28600370394
# Q-# Q12042914	d1 1204.3357102435548	d2 1656.7561185718214
# Q-# Q3747378	d1 589.3704796797505	d2 1135.8283743264813
# Q-# Q3747402	d1 11534.387252487422	d2 11820.737278943214
# Q-# Q3747402	d1 1878.1671719057567	d2 2418.4549704519955
# Q-# Q3747370	d1 1104.1342331382818	d2 2096.322034873792
# Q-# Q7489878	d1 239.59463102027556	d2 468.9207358310482
# Q-# Q3747443	d1 441.4674791986324	d2 574.0216142062571
# Q-# Q1714672	d1 146.6039856576064	d2 301.2450189855946
# Q-# Q3747388	d1 181.1411011827839	d2 641.5502459162094
# Q-# Q3747370	d1 6789.730230291464	d2 8452.07761610215
# Q-# Q3747370	d1 6803.869225277243	d2 8494.811615382272
# Q-# Q3747370	d1 6848.056106903899	d2 8533.261592287434
# Q-# Q5465137	d1 1074.8558894218397	d2 1491.151019282698
# Q-# Q3747439	d1 597.6038563379489	d2 713.2952923773721
# Q-# Q1435809	d1 186.65771637476197	d2 279.52666336069973
# Q-# Q3747399	d1 4991.081960338403	d2 5137.894003433509
# Q-# Q3747439	d1 282.5441779828316	d2 947.0365718236889
# Q-# Q3747402	d1 4246.403081810112	d2 4953.312091316808
# Q-# Q74574057	d1 6646.459041978479	d2 6943.695489684265
# Q-# Q3747442	d1 130.12526792416307	d2 301.957904220897
# Q-# Q3747442	d1 128.31312427420752	d2 303.90560896380634
# Q-# Q3747467	d1 286.4427638214035	d2 652.6880861792985
# Q-# Q12042914	d1 560.1283952470246	d2 1042.0670239132958
# Q-# Q3747467	d1 437.4094171726308	d2 619.9145349054486
# Q-# Q1435809	d1 2678.1907513629353	d2 2683.535961498403
# Q-# Q74574057	d1 6328.785048269775	d2 8022.012029599477
# Q-# Q74574057	d1 6107.505249476501	d2 7797.723501096973
# Q-# Q1924755	d1 226.9673466430172	d2 505.59482651040184
# Q-# Q74574057	d1 3116.1182962356206	d2 4802.274524227562
# Q-# Q74574057	d1 2781.7885067400503	d2 4476.534280789936
# Q-# Q29582887	d1 490.4249804054449	d2 575.7513225185791
# Q-# Q3747378	d1 944.7049670283445	d2 1208.2827289180702
# Q-# Q3747400	d1 538.92226746831	d2 553.4911959898866
# Q-# Q74574057	d1 8222.313884238567	d2 9655.148311021198
# Q-# Q1435809	d1 296.59535923787354	d2 656.0727880591861
# Q-# Q3747439	d1 1640.2621617958973	d2 1827.1794071994407
# Q-# Q3747399	d1 326.37753057941353	d2 1073.8677108713075

# %%
len(dffinal)
# Out:
# 1645

# %%
dffinal
# Out:
#               Y          X         amenity fountain created_by wheelchair  \
# 0     41.824508  12.485546  drinking_water   nasone        NaN        NaN
# 1     41.852621  12.478328  drinking_water   nasone        NaN        NaN
# 2     41.854102  12.476834  drinking_water   nasone        NaN        NaN
# 3     41.863749  12.478948  drinking_water   nasone        NaN        NaN
# 4     41.904287  12.513278  drinking_water      NaN       JOSM        NaN
# ...         ...        ...             ...      ...        ...        ...
# 1640  41.913437  12.461680  drinking_water   nasone        NaN        NaN
# 1641  41.902114  12.590335  drinking_water      NaN        NaN        yes
# 1642  41.888007  12.461600  drinking_water   nasone        NaN        NaN
# 1643  41.903375  12.512719  drinking_water      NaN        NaN        NaN
# 1644  41.877493  12.474922  drinking_water   nasone        NaN        NaN
#
#      flow architect description drinking_water  ... artwork_type  \
# 0     NaN       NaN         NaN            NaN  ...          NaN
# 1     NaN       NaN         NaN            NaN  ...          NaN
# 2     NaN       NaN         NaN            NaN  ...          NaN
# 3     NaN       NaN         NaN            NaN  ...          NaN
# 4     NaN       NaN         NaN            NaN  ...          NaN
# ...   ...       ...         ...            ...  ...          ...
# 1640  NaN       NaN         NaN            NaN  ...          NaN
# 1641  NaN       NaN         NaN            NaN  ...          NaN
# 1642  NaN       NaN         NaN            NaN  ...          NaN
# 1643  NaN       NaN         NaN            NaN  ...          NaN
# 1644  NaN       NaN         NaN            NaN  ...          NaN
#
#      subject:wikidata drinking_water:legal nearest_qid nearest_has_label_de  \
# 0                 NaN                  NaN    Q3747399                 True
# 1                 NaN                  NaN    Q3747399                 True
# 2                 NaN                  NaN    Q3747399                 True
# 3                 NaN                  NaN    Q3747399                 True
# 4                 NaN                  NaN    Q3747439                False
# ...               ...                  ...         ...                  ...
# 1640              NaN                  NaN    Q3747400                False
# 1641              NaN                  NaN   Q74574057                False
# 1642              NaN                  NaN    Q1435809                 True
# 1643              NaN                  NaN    Q3747439                False
# 1644              NaN                  NaN    Q3747399                 True
#
#      nearest_has_date nearest_has_operator nearest_has_code  \
# 0               False                False            False
# 1               False                False            False
# 2               False                False            False
# 3               False                False            False
# 4               False                False            False
# ...               ...                  ...              ...
# 1640            False                False            False
# 1641            False                False            False
# 1642            False                False            False
# 1643            False                False            False
# 1644            False                False            False
#
#       nearest_has_water_type match_found
# 0                      False    no match
# 1                      False    no match
# 2                      False    no match
# 3                      False    no match
# 4                      False    no match
# ...                      ...         ...
# 1640                   False    no match
# 1641                   False    no match
# 1642                   False    no match
# 1643                   False    no match
# 1644                   False    no match
#
# [1645 rows x 81 columns]

# %%
print("\n\nTotal number of rows "+str(len(dffinal)))
# Out:
# Total number of rows 1645

# %% [markdown]
# ## Create Quickstatement commands from data
# ### Helper functions to format content according to Quickstatements v1 syntax

# %%
def process_coordinates(x, y):
    # format geographic coordinates
    return '@{1:1.8f}/{0:1.8f}'.format(x,y)


def process_year(date):
    # format date
    if np.isnan(date):
        return ''
    else:
        return '+{0:4d}-00-00T00:00:00Z/9'.format(int(date))

    
fountain_type_map = {
    'öffentlicher Brunnen': 'Q53628296',
    'Notwasserbrunnen': 'Q53628522',
    'privater Brunnen': 'Q53629707',
    'Brunnen in städtischer Liegenschaft': 'Q53628618',
    'Brunnen des Verschönerungsvereins': 'Q53628761',
    'Brunnen mit eigener Versorgung': 'Q53630002'
}

water_type_map = {
    'Verteilnetz': 'Q53633635',
    'Quellwasser': 'Q1881858',
    'eigene Versorgung': 'Q53634173',
    'Grundwasser': 'Q161598'
}

def process_fountain_type(type):
    # translate fountain types to wikidata values
    return fountain_type_map[type]


def process_water_type(type):
    # translate water types to wikidata values
    return water_type_map[type]


def process_label(text, dfltLabel):
    # process German language labels
    #print (text + ' '+dfltLabel)
    if text is None:
        return dfltLabel
    elif 'nan' == text.lower():
        return '"'+dfltLabel+'"'
    elif 'none' == text.lower():
        return '"'+dfltLabel+'"'.format(text)
    elif 'brunnen' in text.lower():
        return '"{}"'.format(text)
    elif 'fountain' in text.lower():
        return '"{}"'.format(text)
    else:
        return '"'+dfltLabel+' ({})"'.format(text)

    
def process_label_de(text):
    dfltLabel = 'Brunnen'
    return process_label(text, dfltLabel)
    
def process_label_en(text):
    dfltLabel = 'Fountain'
    return process_label(text, dfltLabel)
    

def createline(lines, item, prop, value, extra, qualifiers=[]):
    # general function to create Quickstatement v1 commands
    if value != '' and value != '""':
        statement = '{}\t{}\t{}'.format(item, prop, value)
        if len(qualifiers):
            # append qualifiers if applicable
            for q in qualifiers:
                statement += '\t{}\t{}'.format(q['prop'], q['value'])
        statement += extra
        statement += '\n'
        lines.append(statement)
    return lines

# %% [markdown]
# ### Create statements, taking care not to overwrite existing data

# %%
# initialize command storage list
lines = []
statedId = "\tS248\tQ1224853"
i=0
for index, row in dffinal.iterrows():
    i+=1
    # either create new or edit existing entity
    if row['match_found'] == 'no match':
        # create a new fountain
        lines.append('CREATE\n')
        item = 'LAST'
    elif row['match_found'] == 'unclear':
        print('unclear match')
        print(row)
        continue
    elif row['match_found'] == 'match':
        # update existing fountain
        item = row['nearest_qid']
        
        
    # Add this basic information only if creating a new entity
    if item == 'LAST':
        # instance of  fountain
        lines = createline(lines, item, 'P31', 'Q483453',statedId)

        # coordinates
        lines = createline(lines, item, 'P625', process_coordinates(row['X'], row['Y']),statedId)
        
    # For other properties, add information if the entity is new or if property does not yet exist
    
    # label in german
    if item == 'LAST' or not row['nearest_has_label_de']:
        lines = createline(lines, item, 'Lde', process_label_de(str(row['name'])),statedId)

    # label in english
    #if item == 'LAST' or not row['nearest_has_label_en']:
    #    lines = createline(lines, item, 'Len', process_label_en(str(row['name'])),statedId)
        
    # creation date
    #if item == 'LAST' or not row['nearest_has_date']:
    #    lines = createline(lines, item, 'P571', process_year(row['date']))

    # operated by  Hamburg Wasser
    #print(str(i)+": "+str(row['operator']))
    if  pd.isna(row['operator']):
        print(str(i)+": "+"operator none")
    else:
         lines = createline(lines, item, 'P137', 'Q1572943',statedId)
            
    # catalog number can always be added (it is hard to check for)
    #lines = createline(lines, item, 'P528', '"{}"'.format(row['operator_id']), [{
    #    'prop': 'P972',
    #    'value': 'Q53629101'
    #}])
# Out:
# 1: operator none
# 2: operator none
# 3: operator none
# 4: operator none
# 5: operator none
# 6: operator none
# 7: operator none
# 8: operator none
# 9: operator none
# 10: operator none
# 11: operator none
# 12: operator none
# 13: operator none
# 14: operator none
# 15: operator none
# 16: operator none
# 17: operator none
# 18: operator none
# 19: operator none
# 20: operator none
# 21: operator none
# 22: operator none
# 23: operator none
# 24: operator none
# 25: operator none
# 26: operator none
# 27: operator none
# 28: operator none
# 29: operator none
# 30: operator none
# 31: operator none
# 32: operator none
# 33: operator none
# 34: operator none
# 35: operator none
# 36: operator none
# 37: operator none
# 38: operator none
# 39: operator none
# 40: operator none
# 41: operator none
# 42: operator none
# 43: operator none
# 44: operator none
# 45: operator none
# 46: operator none
# 47: operator none
# 48: operator none
# 49: operator none
# 50: operator none
# 51: operator none
# 52: operator none
# 53: operator none
# 54: operator none
# 55: operator none
# 56: operator none
# 57: operator none
# 58: operator none
# 59: operator none
# 60: operator none
# 61: operator none
# 62: operator none
# 63: operator none
# 64: operator none
# 65: operator none
# 66: operator none
# 67: operator none
# 68: operator none
# 69: operator none
# 70: operator none
# 71: operator none
# 72: operator none
# 73: operator none
# 74: operator none
# 75: operator none
# 76: operator none
# 77: operator none
# 78: operator none
# 79: operator none
# 80: operator none
# 81: operator none
# 82: operator none
# 83: operator none
# 84: operator none
# 85: operator none
# 86: operator none
# 87: operator none
# 88: operator none
# 89: operator none
# 90: operator none
# 91: operator none
# 92: operator none
# 93: operator none
# 94: operator none
# 95: operator none
# 96: operator none
# 97: operator none
# 98: operator none
# 99: operator none
# 100: operator none
# 101: operator none
# 102: operator none
# 103: operator none
# 104: operator none
# 105: operator none
# 106: operator none
# 107: operator none
# 108: operator none
# 109: operator none
# 110: operator none
# 111: operator none
# 112: operator none
# 113: operator none
# 114: operator none
# 115: operator none
# 116: operator none
# 117: operator none
# 118: operator none
# 119: operator none
# 120: operator none
# 121: operator none
# 122: operator none
# 123: operator none
# 124: operator none
# 125: operator none
# 126: operator none
# 127: operator none
# 128: operator none
# 129: operator none
# 130: operator none
# 131: operator none
# 132: operator none
# 133: operator none
# 134: operator none
# 135: operator none
# 136: operator none
# 137: operator none
# 138: operator none
# 139: operator none
# 140: operator none
# 141: operator none
# 142: operator none
# 143: operator none
# 144: operator none
# 145: operator none
# 146: operator none
# 147: operator none
# 148: operator none
# 149: operator none
# 150: operator none
# 151: operator none
# 152: operator none
# 153: operator none
# 154: operator none
# 155: operator none
# 156: operator none
# 157: operator none
# 158: operator none
# 159: operator none
# 160: operator none
# 161: operator none
# 162: operator none
# 163: operator none
# 164: operator none
# 165: operator none
# 166: operator none
# 167: operator none
# 168: operator none
# 169: operator none
# 170: operator none
# 171: operator none
# 172: operator none
# 173: operator none
# 174: operator none
# 175: operator none
# 176: operator none
# 177: operator none
# 178: operator none
# 179: operator none
# 180: operator none
# 181: operator none
# 182: operator none
# 183: operator none
# 184: operator none
# 185: operator none
# 186: operator none
# 187: operator none
# 188: operator none
# 189: operator none
# 190: operator none
# 191: operator none
# 192: operator none
# 193: operator none
# 194: operator none
# 195: operator none
# 196: operator none
# 197: operator none
# 198: operator none
# 199: operator none
# 200: operator none
# 201: operator none
# 202: operator none
# 203: operator none
# 204: operator none
# 205: operator none
# 206: operator none
# 207: operator none
# 208: operator none
# 209: operator none
# 210: operator none
# 211: operator none
# 212: operator none
# 213: operator none
# 214: operator none
# 215: operator none
# 216: operator none
# 217: operator none
# 218: operator none
# 219: operator none
# 220: operator none
# 221: operator none
# 222: operator none
# 223: operator none
# 224: operator none
# 225: operator none
# 226: operator none
# 227: operator none
# 228: operator none
# 229: operator none
# 230: operator none
# 231: operator none
# 232: operator none
# 233: operator none
# 234: operator none
# 235: operator none
# 236: operator none
# 237: operator none
# 238: operator none
# 239: operator none
# 240: operator none
# 241: operator none
# 242: operator none
# 243: operator none
# 244: operator none
# 245: operator none
# 246: operator none
# 247: operator none
# 248: operator none
# 249: operator none
# 250: operator none
# 251: operator none
# 252: operator none
# 253: operator none
# 254: operator none
# 255: operator none
# 256: operator none
# 257: operator none
# 258: operator none
# 259: operator none
# 260: operator none
# 261: operator none
# 262: operator none
# 263: operator none
# 264: operator none
# 265: operator none
# 266: operator none
# 267: operator none
# 268: operator none
# 269: operator none
# 270: operator none
# 271: operator none
# 272: operator none
# 273: operator none
# 274: operator none
# 275: operator none
# 276: operator none
# 277: operator none
# 278: operator none
# 279: operator none
# 280: operator none
# 281: operator none
# 282: operator none
# 283: operator none
# 284: operator none
# 285: operator none
# 286: operator none
# 287: operator none
# 288: operator none
# 289: operator none
# 290: operator none
# 291: operator none
# 292: operator none
# 293: operator none
# 294: operator none
# 295: operator none
# 296: operator none
# 297: operator none
# 298: operator none
# 299: operator none
# 300: operator none
# 301: operator none
# 302: operator none
# 303: operator none
# 304: operator none
# 305: operator none
# 306: operator none
# 307: operator none
# 308: operator none
# 309: operator none
# 310: operator none
# 311: operator none
# 312: operator none
# 313: operator none
# 314: operator none
# 315: operator none
# 316: operator none
# 317: operator none
# 318: operator none
# 319: operator none
# 320: operator none
# 321: operator none
# 322: operator none
# 323: operator none
# 324: operator none
# 325: operator none
# 326: operator none
# 327: operator none
# 328: operator none
# 329: operator none
# 330: operator none
# 331: operator none
# 332: operator none
# 333: operator none
# 334: operator none
# 335: operator none
# 336: operator none
# 337: operator none
# 338: operator none
# 339: operator none
# 340: operator none
# 341: operator none
# 342: operator none
# 343: operator none
# 344: operator none
# 345: operator none
# 346: operator none
# 347: operator none
# 348: operator none
# 349: operator none
# 350: operator none
# 351: operator none
# 352: operator none
# 353: operator none
# 354: operator none
# 355: operator none
# 356: operator none
# 357: operator none
# 358: operator none
# 359: operator none
# 360: operator none
# 361: operator none
# 362: operator none
# 363: operator none
# 364: operator none
# 365: operator none
# 366: operator none
# 367: operator none
# 368: operator none
# 369: operator none
# 370: operator none
# 371: operator none
# 372: operator none
# 373: operator none
# 374: operator none
# 375: operator none
# 376: operator none
# 377: operator none
# 378: operator none
# 379: operator none
# 380: operator none
# 381: operator none
# 382: operator none
# 383: operator none
# 384: operator none
# 385: operator none
# 386: operator none
# 387: operator none
# 388: operator none
# 389: operator none
# 390: operator none
# 391: operator none
# 392: operator none
# 393: operator none
# 394: operator none
# 395: operator none
# 396: operator none
# 397: operator none
# 398: operator none
# 399: operator none
# 400: operator none
# 401: operator none
# 402: operator none
# 403: operator none
# 404: operator none
# 405: operator none
# 406: operator none
# 407: operator none
# 408: operator none
# 409: operator none
# 410: operator none
# 411: operator none
# 412: operator none
# 413: operator none
# 414: operator none
# 415: operator none
# 416: operator none
# 417: operator none
# 418: operator none
# 419: operator none
# 420: operator none
# 421: operator none
# 422: operator none
# 423: operator none
# 424: operator none
# 425: operator none
# 426: operator none
# 427: operator none
# 428: operator none
# 429: operator none
# 430: operator none
# 431: operator none
# 432: operator none
# 433: operator none
# 434: operator none
# 435: operator none
# 436: operator none
# 437: operator none
# 438: operator none
# 439: operator none
# 440: operator none
# 441: operator none
# 442: operator none
# 443: operator none
# 444: operator none
# 445: operator none
# 446: operator none
# 447: operator none
# 448: operator none
# 449: operator none
# 450: operator none
# 451: operator none
# 452: operator none
# 453: operator none
# 454: operator none
# 455: operator none
# 456: operator none
# 457: operator none
# 458: operator none
# 459: operator none
# 460: operator none
# 461: operator none
# 462: operator none
# 463: operator none
# 464: operator none
# 465: operator none
# 466: operator none
# 467: operator none
# 468: operator none
# 469: operator none
# 470: operator none
# 471: operator none
# 472: operator none
# 473: operator none
# 474: operator none
# 475: operator none
# 476: operator none
# 477: operator none
# 478: operator none
# 479: operator none
# 480: operator none
# 481: operator none
# 482: operator none
# 483: operator none
# 484: operator none
# 485: operator none
# 486: operator none
# 487: operator none
# 488: operator none
# 489: operator none
# 490: operator none
# 491: operator none
# 492: operator none
# 493: operator none
# 494: operator none
# 495: operator none
# 496: operator none
# 497: operator none
# 498: operator none
# 499: operator none
# 500: operator none
# 501: operator none
# 502: operator none
# 503: operator none
# 504: operator none
# 505: operator none
# 506: operator none
# 507: operator none
# 508: operator none
# 509: operator none
# 510: operator none
# 511: operator none
# 512: operator none
# 513: operator none
# 514: operator none
# 515: operator none
# 516: operator none
# 517: operator none
# 518: operator none
# 519: operator none
# 520: operator none
# 521: operator none
# 522: operator none
# 523: operator none
# 524: operator none
# 525: operator none
# 526: operator none
# 527: operator none
# 528: operator none
# 529: operator none
# 530: operator none
# 531: operator none
# 532: operator none
# 533: operator none
# 534: operator none
# 535: operator none
# 536: operator none
# 537: operator none
# 538: operator none
# 539: operator none
# 540: operator none
# 541: operator none
# 542: operator none
# 543: operator none
# 544: operator none
# 545: operator none
# 546: operator none
# 547: operator none
# 548: operator none
# 549: operator none
# 550: operator none
# 551: operator none
# 552: operator none
# 553: operator none
# 554: operator none
# 555: operator none
# 556: operator none
# 557: operator none
# 558: operator none
# 559: operator none
# 560: operator none
# 561: operator none
# 562: operator none
# 563: operator none
# 564: operator none
# 565: operator none
# 566: operator none
# 567: operator none
# 568: operator none
# 569: operator none
# 570: operator none
# 571: operator none
# 572: operator none
# 573: operator none
# 574: operator none
# 575: operator none
# 576: operator none
# 577: operator none
# 578: operator none
# 579: operator none
# 580: operator none
# 581: operator none
# 582: operator none
# 583: operator none
# 584: operator none
# 585: operator none
# 586: operator none
# 587: operator none
# 588: operator none
# 589: operator none
# 590: operator none
# 591: operator none
# 592: operator none
# 593: operator none
# 594: operator none
# 595: operator none
# 596: operator none
# 597: operator none
# 598: operator none
# 599: operator none
# 600: operator none
# 601: operator none
# 602: operator none
# 603: operator none
# 604: operator none
# 605: operator none
# 606: operator none
# 607: operator none
# 608: operator none
# 609: operator none
# 610: operator none
# 611: operator none
# 612: operator none
# 613: operator none
# 614: operator none
# 615: operator none
# 616: operator none
# 617: operator none
# 618: operator none
# 619: operator none
# 620: operator none
# 621: operator none
# 622: operator none
# 623: operator none
# 624: operator none
# 625: operator none
# 626: operator none
# 627: operator none
# 628: operator none
# 629: operator none
# 630: operator none
# 631: operator none
# 632: operator none
# 633: operator none
# 634: operator none
# 635: operator none
# 636: operator none
# 637: operator none
# 638: operator none
# 639: operator none
# 640: operator none
# 641: operator none
# 642: operator none
# 643: operator none
# 644: operator none
# 645: operator none
# 646: operator none
# 647: operator none
# 648: operator none
# 649: operator none
# 650: operator none
# 651: operator none
# 652: operator none
# 653: operator none
# 654: operator none
# 655: operator none
# 656: operator none
# 657: operator none
# 658: operator none
# 659: operator none
# 660: operator none
# 661: operator none
# 662: operator none
# 663: operator none
# 664: operator none
# 665: operator none
# 666: operator none
# 667: operator none
# 668: operator none
# 669: operator none
# 670: operator none
# 671: operator none
# 672: operator none
# 673: operator none
# 674: operator none
# 675: operator none
# 676: operator none
# 677: operator none
# 678: operator none
# 679: operator none
# 680: operator none
# 681: operator none
# 682: operator none
# 683: operator none
# 684: operator none
# 685: operator none
# 686: operator none
# 687: operator none
# 688: operator none
# 689: operator none
# 690: operator none
# 691: operator none
# 692: operator none
# 693: operator none
# 694: operator none
# 695: operator none
# 696: operator none
# 697: operator none
# 698: operator none
# 699: operator none
# 700: operator none
# 701: operator none
# 702: operator none
# 703: operator none
# 704: operator none
# 705: operator none
# 706: operator none
# 707: operator none
# 708: operator none
# 709: operator none
# 710: operator none
# 711: operator none
# 712: operator none
# 713: operator none
# 714: operator none
# 715: operator none
# 716: operator none
# 717: operator none
# 718: operator none
# 719: operator none
# 720: operator none
# 721: operator none
# 722: operator none
# 723: operator none
# 724: operator none
# 725: operator none
# 726: operator none
# 727: operator none
# 728: operator none
# 729: operator none
# 730: operator none
# 731: operator none
# 732: operator none
# 733: operator none
# 734: operator none
# 735: operator none
# 736: operator none
# 737: operator none
# 738: operator none
# 739: operator none
# 740: operator none
# 741: operator none
# 742: operator none
# 743: operator none
# 744: operator none
# 745: operator none
# 746: operator none
# 747: operator none
# 748: operator none
# 749: operator none
# 750: operator none
# 751: operator none
# 752: operator none
# 753: operator none
# 754: operator none
# 755: operator none
# 756: operator none
# 757: operator none
# 758: operator none
# 759: operator none
# 760: operator none
# 761: operator none
# 762: operator none
# 763: operator none
# 764: operator none
# 765: operator none
# 766: operator none
# 767: operator none
# 768: operator none
# 769: operator none
# 770: operator none
# 771: operator none
# 772: operator none
# 773: operator none
# 774: operator none
# 775: operator none
# 776: operator none
# 777: operator none
# 778: operator none
# 779: operator none
# 780: operator none
# 781: operator none
# 782: operator none
# 783: operator none
# 784: operator none
# 785: operator none
# 786: operator none
# 787: operator none
# 788: operator none
# 789: operator none
# 790: operator none
# 791: operator none
# 792: operator none
# 793: operator none
# 794: operator none
# 795: operator none
# 796: operator none
# 797: operator none
# 798: operator none
# 799: operator none
# 800: operator none
# 801: operator none
# 802: operator none
# 803: operator none
# 804: operator none
# 805: operator none
# 806: operator none
# 807: operator none
# 808: operator none
# 809: operator none
# 810: operator none
# 811: operator none
# 812: operator none
# 813: operator none
# 814: operator none
# 815: operator none
# 816: operator none
# 817: operator none
# 818: operator none
# 819: operator none
# 820: operator none
# 821: operator none
# 822: operator none
# 823: operator none
# 824: operator none
# 825: operator none
# 826: operator none
# 827: operator none
# 828: operator none
# 829: operator none
# 830: operator none
# 831: operator none
# 832: operator none
# 833: operator none
# 834: operator none
# 835: operator none
# 836: operator none
# 837: operator none
# 838: operator none
# 839: operator none
# 840: operator none
# 841: operator none
# 842: operator none
# 843: operator none
# 844: operator none
# 845: operator none
# 846: operator none
# 847: operator none
# 848: operator none
# 849: operator none
# 850: operator none
# 851: operator none
# 852: operator none
# 853: operator none
# 854: operator none
# 855: operator none
# 856: operator none
# 857: operator none
# 858: operator none
# 859: operator none
# 860: operator none
# 861: operator none
# 862: operator none
# 863: operator none
# 864: operator none
# 865: operator none
# 866: operator none
# 867: operator none
# 868: operator none
# 869: operator none
# 870: operator none
# 871: operator none
# 872: operator none
# 873: operator none
# 874: operator none
# 875: operator none
# 876: operator none
# 877: operator none
# 878: operator none
# 879: operator none
# 880: operator none
# 881: operator none
# 882: operator none
# 883: operator none
# 884: operator none
# 885: operator none
# 886: operator none
# 887: operator none
# 888: operator none
# 889: operator none
# 890: operator none
# 891: operator none
# 892: operator none
# 893: operator none
# 894: operator none
# 895: operator none
# 896: operator none
# 897: operator none
# 898: operator none
# 899: operator none
# 900: operator none
# 901: operator none
# 902: operator none
# 903: operator none
# 904: operator none
# 905: operator none
# 906: operator none
# 907: operator none
# 908: operator none
# 909: operator none
# 910: operator none
# 911: operator none
# 912: operator none
# 913: operator none
# 914: operator none
# 915: operator none
# 916: operator none
# 917: operator none
# 918: operator none
# 919: operator none
# 920: operator none
# 921: operator none
# 922: operator none
# 923: operator none
# 924: operator none
# 925: operator none
# 926: operator none
# 927: operator none
# 928: operator none
# 929: operator none
# 930: operator none
# 931: operator none
# 932: operator none
# 933: operator none
# 934: operator none
# 935: operator none
# 936: operator none
# 937: operator none
# 938: operator none
# 939: operator none
# 940: operator none
# 941: operator none
# 942: operator none
# 943: operator none
# 944: operator none
# 945: operator none
# 946: operator none
# 947: operator none
# 948: operator none
# 949: operator none
# 950: operator none
# 951: operator none
# 952: operator none
# 953: operator none
# 954: operator none
# 955: operator none
# 956: operator none
# 957: operator none
# 958: operator none
# 959: operator none
# 960: operator none
# 961: operator none
# 962: operator none
# 963: operator none
# 964: operator none
# 965: operator none
# 966: operator none
# 967: operator none
# 968: operator none
# 969: operator none
# 970: operator none
# 971: operator none
# 972: operator none
# 973: operator none
# 974: operator none
# 975: operator none
# 976: operator none
# 977: operator none
# 978: operator none
# 979: operator none
# 980: operator none
# 981: operator none
# 982: operator none
# 983: operator none
# 984: operator none
# 985: operator none
# 986: operator none
# 987: operator none
# 988: operator none
# 989: operator none
# 990: operator none
# 991: operator none
# 992: operator none
# 993: operator none
# 994: operator none
# 995: operator none
# 996: operator none
# 997: operator none
# 998: operator none
# 999: operator none
# 1000: operator none
# 1001: operator none
# 1002: operator none
# 1003: operator none
# 1004: operator none
# 1005: operator none
# 1006: operator none
# 1007: operator none
# 1008: operator none
# 1009: operator none
# 1010: operator none
# 1011: operator none
# 1012: operator none
# 1013: operator none
# 1014: operator none
# 1015: operator none
# 1016: operator none
# 1017: operator none
# 1018: operator none
# 1019: operator none
# 1020: operator none
# 1021: operator none
# 1022: operator none
# 1023: operator none
# 1024: operator none
# 1025: operator none
# 1026: operator none
# 1027: operator none
# 1028: operator none
# 1029: operator none
# 1030: operator none
# 1031: operator none
# 1032: operator none
# 1033: operator none
# 1034: operator none
# 1035: operator none
# 1036: operator none
# 1037: operator none
# 1038: operator none
# 1039: operator none
# 1040: operator none
# 1041: operator none
# 1042: operator none
# 1043: operator none
# 1044: operator none
# 1045: operator none
# 1046: operator none
# 1047: operator none
# 1048: operator none
# 1049: operator none
# 1050: operator none
# 1051: operator none
# 1052: operator none
# 1053: operator none
# 1054: operator none
# 1055: operator none
# 1056: operator none
# 1057: operator none
# 1058: operator none
# 1059: operator none
# 1060: operator none
# 1061: operator none
# 1062: operator none
# 1063: operator none
# 1064: operator none
# 1065: operator none
# 1066: operator none
# 1067: operator none
# 1068: operator none
# 1069: operator none
# 1070: operator none
# 1071: operator none
# 1072: operator none
# 1073: operator none
# 1074: operator none
# 1075: operator none
# 1076: operator none
# 1077: operator none
# 1078: operator none
# 1079: operator none
# 1080: operator none
# 1081: operator none
# 1082: operator none
# 1083: operator none
# 1084: operator none
# 1085: operator none
# 1086: operator none
# 1087: operator none
# 1088: operator none
# 1089: operator none
# 1090: operator none
# 1091: operator none
# 1092: operator none
# 1093: operator none
# 1094: operator none
# 1095: operator none
# 1096: operator none
# 1097: operator none
# 1098: operator none
# 1099: operator none
# 1100: operator none
# 1101: operator none
# 1102: operator none
# 1103: operator none
# 1104: operator none
# 1105: operator none
# 1106: operator none
# 1107: operator none
# 1108: operator none
# 1109: operator none
# 1110: operator none
# 1111: operator none
# 1112: operator none
# 1113: operator none
# 1114: operator none
# 1115: operator none
# 1116: operator none
# 1117: operator none
# 1118: operator none
# 1119: operator none
# 1120: operator none
# 1121: operator none
# 1122: operator none
# 1123: operator none
# 1124: operator none
# 1125: operator none
# 1126: operator none
# 1127: operator none
# 1128: operator none
# 1129: operator none
# 1130: operator none
# 1131: operator none
# 1132: operator none
# 1133: operator none
# 1134: operator none
# 1135: operator none
# 1136: operator none
# 1137: operator none
# 1138: operator none
# 1139: operator none
# 1140: operator none
# 1141: operator none
# 1142: operator none
# 1143: operator none
# 1144: operator none
# 1145: operator none
# 1146: operator none
# 1147: operator none
# 1148: operator none
# 1149: operator none
# 1150: operator none
# 1151: operator none
# 1152: operator none
# 1153: operator none
# 1154: operator none
# 1155: operator none
# 1156: operator none
# 1157: operator none
# 1158: operator none
# 1159: operator none
# 1160: operator none
# 1161: operator none
# 1162: operator none
# 1163: operator none
# 1164: operator none
# 1165: operator none
# 1166: operator none
# 1167: operator none
# 1168: operator none
# 1169: operator none
# 1170: operator none
# 1171: operator none
# 1172: operator none
# 1173: operator none
# 1174: operator none
# 1175: operator none
# 1176: operator none
# 1177: operator none
# 1178: operator none
# 1179: operator none
# 1180: operator none
# 1181: operator none
# 1182: operator none
# 1183: operator none
# 1184: operator none
# 1185: operator none
# 1186: operator none
# 1187: operator none
# 1188: operator none
# 1189: operator none
# 1190: operator none
# 1191: operator none
# 1192: operator none
# 1193: operator none
# 1194: operator none
# 1195: operator none
# 1196: operator none
# 1197: operator none
# 1198: operator none
# 1199: operator none
# 1200: operator none
# 1201: operator none
# 1202: operator none
# 1203: operator none
# 1204: operator none
# 1205: operator none
# 1206: operator none
# 1207: operator none
# 1208: operator none
# 1209: operator none
# 1210: operator none
# 1211: operator none
# 1212: operator none
# 1213: operator none
# 1214: operator none
# 1215: operator none
# 1216: operator none
# 1217: operator none
# 1218: operator none
# 1219: operator none
# 1220: operator none
# 1221: operator none
# 1222: operator none
# 1223: operator none
# 1224: operator none
# 1225: operator none
# 1226: operator none
# 1227: operator none
# 1228: operator none
# 1229: operator none
# 1230: operator none
# 1231: operator none
# 1232: operator none
# 1233: operator none
# 1234: operator none
# 1235: operator none
# 1236: operator none
# 1237: operator none
# 1238: operator none
# 1239: operator none
# 1240: operator none
# 1241: operator none
# 1242: operator none
# 1243: operator none
# 1244: operator none
# 1245: operator none
# 1246: operator none
# 1247: operator none
# 1248: operator none
# 1249: operator none
# 1250: operator none
# 1251: operator none
# 1252: operator none
# 1253: operator none
# 1254: operator none
# 1255: operator none
# 1256: operator none
# 1257: operator none
# 1258: operator none
# 1259: operator none
# 1260: operator none
# 1261: operator none
# 1262: operator none
# 1263: operator none
# 1264: operator none
# 1265: operator none
# 1266: operator none
# 1267: operator none
# 1268: operator none
# 1269: operator none
# 1270: operator none
# 1271: operator none
# 1272: operator none
# 1273: operator none
# 1274: operator none
# 1275: operator none
# 1276: operator none
# 1277: operator none
# 1278: operator none
# 1279: operator none
# 1280: operator none
# 1281: operator none
# 1282: operator none
# 1283: operator none
# 1284: operator none
# 1285: operator none
# 1286: operator none
# 1287: operator none
# 1288: operator none
# 1289: operator none
# 1290: operator none
# 1291: operator none
# 1292: operator none
# 1293: operator none
# 1294: operator none
# 1295: operator none
# 1296: operator none
# 1297: operator none
# 1298: operator none
# 1299: operator none
# 1300: operator none
# 1301: operator none
# 1302: operator none
# 1303: operator none
# 1304: operator none
# 1305: operator none
# 1306: operator none
# 1307: operator none
# 1308: operator none
# 1309: operator none
# 1310: operator none
# 1311: operator none
# 1312: operator none
# 1313: operator none
# 1314: operator none
# 1315: operator none
# 1316: operator none
# 1317: operator none
# 1318: operator none
# 1319: operator none
# 1320: operator none
# 1321: operator none
# 1322: operator none
# 1323: operator none
# 1324: operator none
# 1325: operator none
# 1326: operator none
# 1327: operator none
# 1328: operator none
# 1329: operator none
# 1330: operator none
# 1331: operator none
# 1332: operator none
# 1333: operator none
# 1334: operator none
# 1335: operator none
# 1336: operator none
# 1337: operator none
# 1338: operator none
# 1339: operator none
# 1340: operator none
# 1341: operator none
# 1342: operator none
# 1343: operator none
# 1344: operator none
# 1345: operator none
# 1346: operator none
# 1347: operator none
# 1348: operator none
# 1349: operator none
# 1350: operator none
# 1351: operator none
# 1352: operator none
# 1353: operator none
# 1354: operator none
# 1355: operator none
# 1356: operator none
# 1357: operator none
# 1358: operator none
# 1359: operator none
# 1360: operator none
# 1361: operator none
# 1362: operator none
# 1363: operator none
# 1364: operator none
# 1365: operator none
# 1366: operator none
# 1367: operator none
# 1368: operator none
# 1369: operator none
# 1370: operator none
# 1371: operator none
# 1372: operator none
# 1373: operator none
# 1374: operator none
# 1375: operator none
# 1376: operator none
# 1378: operator none
# 1379: operator none
# 1380: operator none
# 1381: operator none
# 1382: operator none
# 1383: operator none
# 1384: operator none
# 1385: operator none
# 1386: operator none
# 1387: operator none
# 1388: operator none
# 1389: operator none
# 1390: operator none
# 1391: operator none
# 1392: operator none
# 1393: operator none
# 1394: operator none
# 1395: operator none
# 1396: operator none
# 1397: operator none
# 1398: operator none
# 1399: operator none
# 1400: operator none
# 1401: operator none
# 1402: operator none
# 1403: operator none
# 1404: operator none
# 1405: operator none
# 1406: operator none
# 1407: operator none
# 1408: operator none
# 1409: operator none
# 1410: operator none
# 1411: operator none
# 1412: operator none
# 1413: operator none
# 1414: operator none
# 1415: operator none
# 1416: operator none
# 1417: operator none
# 1418: operator none
# 1419: operator none
# 1420: operator none
# 1421: operator none
# 1422: operator none
# 1423: operator none
# 1425: operator none
# 1426: operator none
# 1427: operator none
# 1428: operator none
# 1429: operator none
# 1430: operator none
# 1431: operator none
# 1432: operator none
# 1433: operator none
# 1434: operator none
# 1435: operator none
# 1436: operator none
# 1437: operator none
# 1438: operator none
# 1439: operator none
# 1440: operator none
# 1441: operator none
# 1442: operator none
# 1443: operator none
# 1444: operator none
# 1445: operator none
# 1446: operator none
# 1447: operator none
# 1448: operator none
# 1449: operator none
# 1450: operator none
# 1451: operator none
# 1452: operator none
# 1453: operator none
# 1454: operator none
# 1455: operator none
# 1456: operator none
# 1457: operator none
# 1458: operator none
# 1459: operator none
# 1460: operator none
# 1461: operator none
# 1462: operator none
# 1463: operator none
# 1464: operator none
# 1465: operator none
# 1466: operator none
# 1467: operator none
# 1468: operator none
# 1469: operator none
# 1470: operator none
# 1471: operator none
# 1472: operator none
# 1473: operator none
# 1474: operator none
# 1475: operator none
# 1476: operator none
# 1477: operator none
# 1478: operator none
# 1479: operator none
# 1480: operator none
# 1481: operator none
# 1482: operator none
# 1483: operator none
# 1484: operator none
# 1485: operator none
# 1486: operator none
# 1487: operator none
# 1488: operator none
# 1489: operator none
# 1490: operator none
# 1491: operator none
# 1492: operator none
# 1493: operator none
# 1494: operator none
# 1495: operator none
# 1496: operator none
# 1497: operator none
# 1498: operator none
# 1499: operator none
# 1500: operator none
# 1501: operator none
# 1502: operator none
# 1503: operator none
# 1504: operator none
# 1505: operator none
# 1506: operator none
# 1507: operator none
# 1508: operator none
# 1509: operator none
# 1510: operator none
# 1511: operator none
# 1512: operator none
# 1513: operator none
# 1514: operator none
# 1515: operator none
# 1516: operator none
# 1517: operator none
# 1518: operator none
# 1519: operator none
# 1520: operator none
# 1521: operator none
# 1522: operator none
# 1523: operator none
# 1524: operator none
# 1525: operator none
# 1526: operator none
# 1527: operator none
# 1528: operator none
# 1529: operator none
# 1530: operator none
# 1531: operator none
# 1532: operator none
# 1533: operator none
# 1534: operator none
# 1535: operator none
# 1536: operator none
# 1537: operator none
# 1538: operator none
# 1539: operator none
# 1540: operator none
# 1541: operator none
# 1542: operator none
# 1543: operator none
# 1544: operator none
# 1545: operator none
# 1546: operator none
# 1547: operator none
# 1548: operator none
# 1549: operator none
# 1550: operator none
# 1551: operator none
# 1552: operator none
# 1553: operator none
# 1554: operator none
# 1555: operator none
# 1556: operator none
# 1557: operator none
# 1558: operator none
# 1559: operator none
# 1560: operator none
# 1561: operator none
# 1562: operator none
# 1563: operator none
# 1564: operator none
# 1565: operator none
# 1566: operator none
# 1567: operator none
# 1568: operator none
# 1569: operator none
# 1570: operator none
# 1571: operator none
# 1572: operator none
# 1573: operator none
# 1574: operator none
# 1575: operator none
# 1576: operator none
# 1577: operator none
# 1578: operator none
# 1579: operator none
# 1580: operator none
# 1581: operator none
# 1582: operator none
# 1583: operator none
# 1584: operator none
# 1585: operator none
# 1586: operator none
# 1587: operator none
# 1588: operator none
# 1589: operator none
# 1590: operator none
# 1591: operator none
# 1592: operator none
# 1593: operator none
# 1594: operator none
# 1595: operator none
# 1596: operator none
# 1597: operator none
# 1598: operator none
# 1599: operator none
# 1600: operator none
# 1602: operator none
# 1603: operator none
# 1604: operator none
# 1605: operator none
# 1606: operator none
# 1607: operator none
# 1608: operator none
# 1609: operator none
# 1610: operator none
# 1611: operator none
# 1612: operator none
# 1613: operator none
# 1614: operator none
# 1615: operator none
# 1616: operator none
# 1617: operator none
# 1618: operator none
# 1619: operator none
# 1620: operator none
# 1621: operator none
# 1622: operator none
# 1623: operator none
# 1624: operator none
# 1625: operator none
# 1626: operator none
# 1627: operator none
# 1628: operator none
# 1629: operator none
# 1630: operator none
# 1631: operator none
# 1632: operator none
# 1633: operator none
# 1634: operator none
# 1635: operator none
# 1636: operator none
# 1637: operator none
# 1638: operator none
# 1639: operator none
# 1640: operator none
# 1641: operator none
# 1643: operator none
# 1644: operator none
# 1645: operator none

# %% [markdown]
# # Write commands to file

# %%
quickStatFileName = "quickstatement_commands_Rome_fountain_"+dt.now().strftime(dtFmt)+".txt"
with io.open(quickStatFileName, "w", encoding='utf8') as f:
    f.writelines(lines)
print("wrote '"+quickStatFileName+"' with "+str(len(lines))+" lines")
# Out:
# wrote 'quickstatement_commands_Rome_fountain_191201_085501.txt' with 8191 lines

# %% [markdown]
# # Import into Wikidata
# - Go to https://tools.wmflabs.org/wikidata-todo/quick_statements.php.
# - Authenticate yourself with your Wikidata account.
# - Copy and paste the contents of quickstatement_commands*.txt into the blank field, and run the commands

# %% [markdown]
# see ../20191030_1600_import.png
#
# ...
# 58. Processing Q72935495 (Q72935495 Lde "Brunnen (Seelöwe-Planschbecken )")
# 59. Processing Q72935495 (Q72935495 P137 Q27229237)
#
# All done!.

# %%
# it may well take half an hour until it works https://query.wikidata.org/
